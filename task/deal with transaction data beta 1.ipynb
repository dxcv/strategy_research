# %%
import pandas as pd

# %%
data = pd.read_csv('td.csv')

# %%
data.head()
# Out:
#       Symbol         Description    Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# 0  000157-CN  ZOOMLION HVY IND S  698700.0   4.530000     3.165111e+06
# 1  000338-CN    WEICHAI POWER CO   34300.0  11.200000     3.841600e+05
# 2  000538-CN   YUNNAN BAIYAO GRP    5100.0  83.140000     4.240140e+05
# 3  000636-CN    FENGHUA ADV TECH  186700.0  16.070008     3.000270e+06
# 4  000656-CN  JINKE PROPERTY GRO  166000.0   6.570000     1.090620e+06
#
#    Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action
# 0         0.031651                   0.0    Buy New    BUY
# 1         0.003842                   0.0    Buy New    BUY
# 2         0.004240                   0.0    Buy New    BUY
# 3         0.030003                   0.0    Buy New    BUY
# 4         0.010906                   0.0    Buy New    BUY

# %%
data.columns
# Out:
# Index(['Symbol', 'Description', 'Shares', 'Price (Ԫ)', 'Trade Value (Ԫ)',
#        'Trade Value (%)', 'Transaction Cost (Ԫ)', 'Trade Type', 'Action'],
#       dtype='object')

# %%
data.index.name = 'ind'

# %%
def output(df):
    ZQDM = df.Symbol[:6]
    try:
        print('Action:', df.Action[0])
    except:
        print(df)
    if df.Action[0] == 'BUY':
        WTFX = 1
    else:
        WTFX = -1
    ZLSL = df.Shares[0]
    ZLJG = df.iloc[0, 6]
    JGMS = ""
    market = df.Symbol[0][0]
    print('market:', market)
    if market == '6':
        JYSC = 1
    elif (market == '0') | (market == '3'):
        JYSC = 2
    res = pd.Series({
        'ZQDM':ZQDM,
        'WTFX':WTFX,
        'ZLSL':ZLSL,
        'ZLJG':ZLJG,
        'JGMS':JGMS,
        'JYSC':JYSC
    })
    return res

# %%
data.groupby('ind').apply(output)
# Out:
# Action: BUY
# market: 0
# Action: BUY
# market: 0
#         Symbol       Description   Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# ind
# 1    000338-CN  WEICHAI POWER CO  34300.0       11.2         384160.0
#
#      Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action
# ind
# 1           0.003842                   0.0    Buy New    BUY
# Action: BUY
# market: 0
#         Symbol       Description   Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# ind
# 1    000338-CN  WEICHAI POWER CO  34300.0       11.2         384160.0
#
#      Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action
# ind
# 1           0.003842                   0.0    Buy New    BUY
# Action: BUY
# market: 0
# Action: BUY
# market: 0
#         Symbol       Description   Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# ind
# 1    000338-CN  WEICHAI POWER CO  34300.0       11.2         384160.0
#
#      Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action
# ind
# 1           0.003842                   0.0    Buy New    BUY
# Action: BUY
# market: 0
#         Symbol       Description   Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# ind
# 1    000338-CN  WEICHAI POWER CO  34300.0       11.2         384160.0
#
#      Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action
# ind
# 1           0.003842                   0.0    Buy New    BUY
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-48-e8d942ba6e6c> in output(df)
#       6         print(df)
# ----> 7     if df.Action[0] == 'BUY':
#       8         WTFX = 1
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-ad183294d415> in <module>()
# ----> 1 data.groupby('ind').apply(output)
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# <ipython-input-48-e8d942ba6e6c> in output(df)
#       5     except:
#       6         print(df)
# ----> 7     if df.Action[0] == 'BUY':
#       8         WTFX = 1
#       9     else:
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
data = data.assign(ZQDM = data.Symbol.apply(lambda x : x[:6]),
                  WTFX = data.Action.apply(lambda x : np.where(x == 'BUY', 1, -1)),
                  JGMS = '',
                  JYSC = data.Symbol.apply(lambda x : np.where(x[0] == '6', 1, 2)))

# %%
data.head()
# Out:
#       Symbol         Description    Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# 0  000157-CN  ZOOMLION HVY IND S  698700.0   4.530000     3.165111e+06
# 1  000338-CN    WEICHAI POWER CO   34300.0  11.200000     3.841600e+05
# 2  000538-CN   YUNNAN BAIYAO GRP    5100.0  83.140000     4.240140e+05
# 3  000636-CN    FENGHUA ADV TECH  186700.0  16.070008     3.000270e+06
# 4  000656-CN  JINKE PROPERTY GRO  166000.0   6.570000     1.090620e+06
#
#    Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action    ZQDM  WTFX JGMS  \
# 0         0.031651                   0.0    Buy New    BUY  000157     1
# 1         0.003842                   0.0    Buy New    BUY  000338     1
# 2         0.004240                   0.0    Buy New    BUY  000538     1
# 3         0.030003                   0.0    Buy New    BUY  000636     1
# 4         0.010906                   0.0    Buy New    BUY  000656     1
#
#    JYSC
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2

# %%
data = data.assign()

# %%
data.head()
# Out:
#       Symbol         Description    Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# 0  000157-CN  ZOOMLION HVY IND S  698700.0   4.530000     3.165111e+06
# 1  000338-CN    WEICHAI POWER CO   34300.0  11.200000     3.841600e+05
# 2  000538-CN   YUNNAN BAIYAO GRP    5100.0  83.140000     4.240140e+05
# 3  000636-CN    FENGHUA ADV TECH  186700.0  16.070008     3.000270e+06
# 4  000656-CN  JINKE PROPERTY GRO  166000.0   6.570000     1.090620e+06
#
#    Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action    ZQDM  WTFX
# 0         0.031651                   0.0    Buy New    BUY  000157     1
# 1         0.003842                   0.0    Buy New    BUY  000338     1
# 2         0.004240                   0.0    Buy New    BUY  000538     1
# 3         0.030003                   0.0    Buy New    BUY  000636     1
# 4         0.010906                   0.0    Buy New    BUY  000656     1

# %%
data = data.assign()

# %%
data.head()
# Out:
#       Symbol         Description    Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# 0  000157-CN  ZOOMLION HVY IND S  698700.0   4.530000     3.165111e+06
# 1  000338-CN    WEICHAI POWER CO   34300.0  11.200000     3.841600e+05
# 2  000538-CN   YUNNAN BAIYAO GRP    5100.0  83.140000     4.240140e+05
# 3  000636-CN    FENGHUA ADV TECH  186700.0  16.070008     3.000270e+06
# 4  000656-CN  JINKE PROPERTY GRO  166000.0   6.570000     1.090620e+06
#
#    Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action    ZQDM  WTFX  JYSC
# 0         0.031651                   0.0    Buy New    BUY  000157     1     2
# 1         0.003842                   0.0    Buy New    BUY  000338     1     2
# 2         0.004240                   0.0    Buy New    BUY  000538     1     2
# 3         0.030003                   0.0    Buy New    BUY  000636     1     2
# 4         0.010906                   0.0    Buy New    BUY  000656     1     2

# %%
data = data.assign(JGMS = '')

# %%
data.head()
# Out:
#       Symbol         Description    Shares  Price (Ԫ)  Trade Value (Ԫ)  \
# 0  000157-CN  ZOOMLION HVY IND S  698700.0   4.530000     3.165111e+06
# 1  000338-CN    WEICHAI POWER CO   34300.0  11.200000     3.841600e+05
# 2  000538-CN   YUNNAN BAIYAO GRP    5100.0  83.140000     4.240140e+05
# 3  000636-CN    FENGHUA ADV TECH  186700.0  16.070008     3.000270e+06
# 4  000656-CN  JINKE PROPERTY GRO  166000.0   6.570000     1.090620e+06
#
#    Trade Value (%)  Transaction Cost (Ԫ) Trade Type Action    ZQDM  WTFX  \
# 0         0.031651                   0.0    Buy New    BUY  000157     1
# 1         0.003842                   0.0    Buy New    BUY  000338     1
# 2         0.004240                   0.0    Buy New    BUY  000538     1
# 3         0.030003                   0.0    Buy New    BUY  000636     1
# 4         0.010906                   0.0    Buy New    BUY  000656     1
#
#    JYSC JGMS
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2

# %%
output = data.copy()

# %%
output = output.iloc[:, [9, 10, 2, 6, 11, 12]]

# %%
output.columns = ['ZQDM', 'WTFX', 'ZLSL', 'ZLJG', 'JGMS', 'JYSC']

# %%
output
# Out:
#       ZQDM  WTFX       ZLSL  ZLJG JGMS  JYSC
# 0   000157     1   698700.0   0.0          2
# 1   000338     1    34300.0   0.0          2
# 2   000538     1     5100.0   0.0          2
# 3   000636     1   186700.0   0.0          2
# 4   000656     1   166000.0   0.0          2
# 5   000703     1   213000.0   0.0          2
# 6   000858     1    17500.0   0.0          2
# 7   000860     1    53600.0   0.0          2
# 8   002299     1    43900.0   0.0          2
# 9   002353     1    73300.0   0.0          2
# 10  002475     1   146800.0   0.0          2
# 11  002563     1   264100.0   0.0          2
# 12  300033     1    33700.0   0.0          2
# 13  600021     1   275600.0   0.0          1
# 14  600025     1   779300.0   0.0          1
# 15  600153     1    42800.0   0.0          1
# 16  600170     1   825800.0   0.0          1
# 17  600352     1    22800.0   0.0          1
# 18  600390     1   120700.0   0.0          1
# 19  600519     1      400.0   0.0          1
# 20  600585     1    25200.0   0.0          1
# 21  600606     1   432500.0   0.0          1
# 22  600690     1   121200.0   0.0          1
# 23  600782     1   382700.0   0.0          1
# 24  600801     1   146300.0   0.0          1
# 25  600875     1   284100.0   0.0          1
# 26  600999     1   133000.0   0.0          1
# 27  601009     1   436900.0   0.0          1
# 28  601155     1    79300.0   0.0          1
# 29  601211     1   196200.0   0.0          1
# 30  601288     1  1167200.0   0.0          1
# 31  601318     1    79800.0   0.0          1
# 32  601328     1   731800.0   0.0          1
# 33  601360     1    39200.0   0.0          1
# 34  601398     1   241300.0   0.0          1
# 35  601607     1   147800.0   0.0          1
# 36  601633     1   396800.0   0.0          1
# 37  601818     1   892800.0   0.0          1
# 38  603568     1   117900.0   0.0          1
# 39  603806     1    32400.0   0.0          1
# 40  603816     1    51200.0   0.0          1
