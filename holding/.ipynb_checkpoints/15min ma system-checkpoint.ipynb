# %% [markdown]
# 简单的15min, MA3 upper MA60 or MA72

# %% [markdown]
# prepare data
#
# qfq_data calculate the signal, non fq data to backtest

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import statsmodels.api as sm
# import tushare as ts
import QUANTAXIS as QA
import talib as ta
import datetime, time

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %%
code = '002366'
start = '2018-07-01'
end = '2018-12-31'

# %%
data = QA.QA_fetch_stock_min_adv(code, start, end, frequence='15min')

# %%
data_qfq = data.to_qfq()

# %% [markdown]
# calculate ATR

# %%
ind_atr = data_qfq.add_func(QA.QA_indicator_ATR)

# %%
ind_atr.xs(code,level=1)['2018-10'].ATR.plot();

# %%
ind_atr.rolling(14).mean().xs(code,level=1)['2018-10'].ATR.plot();

# %% [markdown]
# 以下的ATR定义为买入信号时的ATR
#
# ---
# 如果从买入价跌去2倍ATR时,便止损,假设此时最多亏损2%的金额,则:
#
# 2 * ATR * 买入的股数 = 2% * 总金额
#
# ==>
#
# 买入的手数 = 1% * 总金额 / ATR // 100

# %%
ind

# %%
initial_asset = 5e4

# %%
initial_asset * 0.01
# Out:
# 500.0

# %%
data.close.iloc[100]
# Out:
# 13.32

# %%
200 * data.close.iloc[100]
# Out:
# 2664.0

# %%
ind_atr.ATR.iloc[100] * 33 * 200
# Out:
# 987.64095665342109

# %%
ind_atr.head(20)
# Out:
#                                   TR       ATR
# datetime            code
# 2018-07-02 09:45:00 002366       NaN       NaN
# 2018-07-02 10:00:00 002366  0.108703       NaN
# 2018-07-02 10:15:00 002366  0.207523       NaN
# 2018-07-02 10:30:00 002366  0.118585       NaN
# 2018-07-02 10:45:00 002366  0.118585       NaN
# 2018-07-02 11:00:00 002366  0.098821       NaN
# 2018-07-02 11:15:00 002366  0.049410       NaN
# 2018-07-02 11:30:00 002366  0.079056       NaN
# 2018-07-02 13:15:00 002366  0.069174       NaN
# 2018-07-02 13:30:00 002366  0.128467       NaN
# 2018-07-02 13:45:00 002366  0.108703       NaN
# 2018-07-02 14:00:00 002366  0.059292       NaN
# 2018-07-02 14:15:00 002366  0.237169       NaN
# 2018-07-02 14:30:00 002366  0.256933       NaN
# 2018-07-02 14:45:00 002366  0.167995  0.129173
# 2018-07-02 15:00:00 002366  0.148231  0.131996
# 2018-07-03 09:45:00 002366  0.266816  0.136231
# 2018-07-03 10:00:00 002366  0.227287  0.143996
# 2018-07-03 10:15:00 002366  0.158113  0.146819
# 2018-07-03 10:30:00 002366  0.158113  0.151054

# %%
not(np.isnan(ind_atr.loc['2018-07-02 10:00'].ATR.iloc[0]))
# Out:
# False

# %%
np.isnan

# %%
ind_atr.loc['2018-07-02 15:00'].ATR.iloc[0]
# Out:
# 0.13199603980430982

# %%
initial_asset * 0.01 / (ind_atr.ATR.iloc[100]) // 100
# Out:
# 33.0

# %%
def MA_system(dataframe):
    """
    Implement:
        根据ATR设定仓位
        RSI设置止损
        什么时候接回来
        当MA3上穿到MA60之上时,并且volume大于5日均量线,记为做多; 这个忘记做了...
        还没有做止损, high / low limit的情况也要考虑到
        试试用rsi做改进?
        
    Arguments:
        
    Returns:
    
    """
    CLOSE = dataframe.close
    MA3 = CLOSE.rolling(3).mean()
    MA60 = CLOSE.rolling(60).mean()
    UCROSS = QA.CROSS(MA3, MA60)
    DCROSS = QA.CROSS(MA60, MA3)
    return pd.DataFrame({'UCROSS':UCROSS, 'DCROSS':DCROSS})

# %%
ind_ma = data_qfq.add_func(MA_system)

# %%
# ind_ma.xs(code, level=1)['2018-10-08 11:00':'2018-10-08']

# %%
ind_ma.xs(code, level=1)['2018-10'].plot();

# %%
ind_ma.UCROSS.iloc[100]
# Out:
# 0

# %% [markdown]
# 回测

# %%
Broker = QA.QA_BacktestBroker()
User = QA.QA_User(username='quantaxis', password='quantaxis')
Portfolio = User.new_portfolio('qatestportfolio')

# %%
Account = Portfolio.new_account(account_cookie='user_mamin_002366',
                           init_cash=200000,
                           frequence=QA.FREQUENCE.FIFTEEN_MIN)

# %%
Account.commission_coeff = 0.00012

# %%
data_backtest = data

# %%
# Account.settle() 结算函数

# %%
# 研究止损的问题

# %%
0.01 * Account.init_cash / cur_atr // 100
# Out:
# 215.0

# %%
_date = None
for items in data_backtest.panel_gen: # 一根bar过去了
    
    # 进行结算
    if _date != items.date[0]:
        print('try to settle')
        _date = items.date[0]
        Account.settle()
    
    for item in items.security_gen:
        daily_ind=ind_ma.loc[item.index] # item.index是index, 然后取到这一天ma的指标值
        if daily_ind.UCROSS.iloc[0] > 0:
            # if Account.sell_available.get(item.code[0], 0) == 0: # 这个是用来判断是否为空仓
            cur_atr = ind_atr.loc[item.index].ATR.iloc[0] # 获取当前日的ATR
            if not(np.isnan(cur_atr)): # 如果ATR不为空
                order_num = 0.01 * Account.init_cash / cur_atr // 100 * 100 # 这里暂时用初始cash进行分配仓位
                order = Account.send_order(
                    code=item.code[0],
                    time=item.datetime[0],
                    amount=order_num,
                    towards=QA.ORDER_DIRECTION.BUY,
                    price=0,
                    order_model=QA.ORDER_MODEL.CLOSE,
                    amount_model=QA.AMOUNT_MODEL.BY_AMOUNT
                )
                if order:
                    Broker.receive_order(QA.QA_Event(order=order, market_data=item))
                    trade_mes = Broker.query_orders(Account.account_cookie, 'filled')
                    res = trade_mes.loc[order.account_cookie, order.realorder_id]
                    print('side : buy, trade_id : %s, ' \
                          'trade_price : %s, trade_amount : %s ' \
                          'trade_time : %s' % 
                          (res.trade_id, res.trade_price,
                                res.trade_amount, res.trade_time))
                    order.trade(res.trade_id, res.trade_price,
                                res.trade_amount, res.trade_time)
                    # 若考虑止损, 还需要判断是否交易成功, 需要记录下成交价格
                    # 但止损的价格判断, 还需要考虑到复权的问题, 因为ATR是复权后计算出来的
                    # 所以需要记录下成交时候的时间点，然后对应时间点上复权后的成交价是多少
                    # 再算出止损价位, 逆向复权成为不复权的止损价
                    # 或者直接使用持仓的市值来判断是否需要止损?
        elif daily_ind.DCROSS.iloc[0] > 0:
            if Account.sell_available.get(item.code[0], 0) > 0:
                _hold = Account.sell_available.get(item.code[0], 0)
                order1 = Account.send_order(
                    code=item.code[0],
                    time=item.datetime[0],
                    amount=_hold,
                    towards=QA.ORDER_DIRECTION.SELL,
                    price=0,
                    order_model=QA.ORDER_MODEL.CLOSE,
                    amount_model=QA.AMOUNT_MODEL.BY_AMOUNT
                )
                if order1:
                    Broker.receive_order(QA.QA_Event(
                        order=order1, market_data=item))
                    trade_mes = Broker.query_orders(
                        Account.account_cookie, 'filled')
                    res = trade_mes.loc[order1.account_cookie, order1.realorder_id]
                    print('side : sell, trade_id : %s, ' \
                          'trade_price : %s, trade_amount : %s ' \
                          'trade_time : %s' % 
                          (res.trade_id, res.trade_price,
                                res.trade_amount, res.trade_time))
                    order1.trade(res.trade_id, res.trade_price,
                                res.trade_amount, res.trade_time)
# Out:
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_h8gwmMLF, trade_price : 13.36, trade_amount : 11800 trade_time : 2018-07-12 11:30:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : sell, trade_id : Trade_3onWiJE4, trade_price : 14.19, trade_amount : 12000 trade_time : 2018-07-19 13:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# side : buy, trade_id : Trade_B13gdbo7, trade_price : 14.39, trade_amount : 19900 trade_time : 2018-07-20 14:30:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# side : buy, trade_id : Trade_6vm7zUBH, trade_price : 14.72, trade_amount : 10400 trade_time : 2018-07-24 10:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# side : sell, trade_id : Trade_fi78vh9W, trade_price : 14.76, trade_amount : 10400 trade_time : 2018-07-27 13:30:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_wV6rPYDT, trade_price : 12.9, trade_amount : 14900 trade_time : 2018-08-08 10:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# side : sell, trade_id : Trade_o4iZCs09, trade_price : 12.43, trade_amount : 14900 trade_time : 2018-08-09 09:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# side : buy, trade_id : Trade_RyJLE63K, trade_price : 12.65, trade_amount : 13000 trade_time : 2018-08-09 10:30:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# side : sell, trade_id : Trade_Q8Jv7H3w, trade_price : 12.6, trade_amount : 13000 trade_time : 2018-08-13 10:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# side : buy, trade_id : Trade_FGYELp89, trade_price : 12.92, trade_amount : 16000 trade_time : 2018-08-13 14:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_C2ErHaZl, trade_price : 12.1, trade_amount : 18000 trade_time : 2018-08-23 14:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_gtHLVYA7, trade_price : 9.93, trade_amount : 21600 trade_time : 2018-09-05 11:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# side : buy, trade_id : Trade_GxX3QCzE, trade_price : 9.83, trade_amount : 24800 trade_time : 2018-09-06 10:30:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# side : buy, trade_id : Trade_HjvUiYEn, trade_price : 9.81, trade_amount : 27700 trade_time : 2018-09-07 09:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_LIl08gn5, trade_price : 9.61, trade_amount : 21100 trade_time : 2018-09-12 10:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_xaTqRep9, trade_price : 8.72, trade_amount : 20100 trade_time : 2018-09-19 10:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : sell, trade_id : Trade_Al3uPzsF, trade_price : 9.27, trade_amount : 20100 trade_time : 2018-09-27 14:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# side : buy, trade_id : Trade_uBKQYdfc, trade_price : 9.48, trade_amount : 18000 trade_time : 2018-10-08 10:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# side : sell, trade_id : Trade_ryW9GBez, trade_price : 9.55, trade_amount : 18000 trade_time : 2018-10-10 14:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# side : buy, trade_id : Trade_SmbM04kc, trade_price : 9.62, trade_amount : 26100 trade_time : 2018-10-10 15:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# side : buy, trade_id : Trade_FJwz0lfh, trade_price : 9.58, trade_amount : 11000 trade_time : 2018-10-12 10:30:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# side : sell, trade_id : Trade_m1MhxbFq, trade_price : 9.24, trade_amount : 11000 trade_time : 2018-10-16 11:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_clgMjKbV, trade_price : 8.29, trade_amount : 14300 trade_time : 2018-10-22 11:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# side : sell, trade_id : Trade_rLQPtFyN, trade_price : 8.2, trade_amount : 14300 trade_time : 2018-10-25 10:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_aG7h1U2X, trade_price : 8.1, trade_amount : 16000 trade_time : 2018-10-31 11:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : sell, trade_id : Trade_vsD05HcX, trade_price : 9.65, trade_amount : 16000 trade_time : 2018-11-09 09:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# side : buy, trade_id : Trade_F8Q6qtf4, trade_price : 10.4, trade_amount : 15900 trade_time : 2018-11-12 10:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : sell, trade_id : Trade_j05sbPJd, trade_price : 10.39, trade_amount : 15900 trade_time : 2018-11-19 10:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# side : buy, trade_id : Trade_ViZyh4gS, trade_price : 10.68, trade_amount : 17200 trade_time : 2018-11-19 14:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# side : sell, trade_id : Trade_AmHJ5DCU, trade_price : 10.43, trade_amount : 17200 trade_time : 2018-11-20 09:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_8osJ1zSF, trade_price : 10.5, trade_amount : 17700 trade_time : 2018-11-27 10:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : sell, trade_id : Trade_uBxlPh3F, trade_price : 11.79, trade_amount : 17700 trade_time : 2018-12-06 09:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_hnBMvs2H, trade_price : 11.59, trade_amount : 16000 trade_time : 2018-12-11 10:15:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# side : buy, trade_id : Trade_gqnoGF9C, trade_price : 11.6, trade_amount : 15800 trade_time : 2018-12-12 09:45:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# side : sell, trade_id : Trade_KDrE39d7, trade_price : 11.58, trade_amount : 16000 trade_time : 2018-12-14 15:00:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# try to settle
# side : buy, trade_id : Trade_C8KVd5p9, trade_price : 10.26, trade_amount : 21500 trade_time : 2018-12-24 13:30:00
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!receive deal
# try to settle
# try to settle
# try to settle
# try to settle

# %%
# Account.history_table
# Out:
#                datetime    code  price  amount        cash        order_id  \
# 0   2018-07-12 11:30:00  002366  13.36     100  198659.000  Order_X6OsJ8ZA
# 1   2018-07-19 13:15:00  002366  14.19    -100  200071.581  Order_w3Mvoqip
# 2   2018-07-20 14:30:00  002366  14.39     100  198627.581  Order_3PbUuDHA
# 3   2018-07-23 09:45:00  002366  13.89    -100  200010.192  Order_ELWgy6CN
# 4   2018-07-24 10:15:00  002366  14.72     100  198533.192  Order_L2VUQ5SJ
# 5   2018-07-27 13:30:00  002366  14.76    -100  200002.716  Order_JmeBvqRh
# 6   2018-08-08 10:45:00  002366  12.90     100  198707.716  Order_aDBCcwOK
# 7   2018-08-09 09:45:00  002366  12.43    -100  199944.473  Order_vt1ZUBCu
# 8   2018-08-09 10:30:00  002366  12.65     100  198674.473  Order_gXUcKRDd
# 9   2018-08-13 10:00:00  002366  12.60    -100  199928.213  Order_8FjcTund
# 10  2018-08-13 14:15:00  002366  12.92     100  198631.213  Order_XMhKfkmW
# 11  2018-08-15 11:15:00  002366  12.82    -100  199906.931  Order_rHBQCJUi
# 12  2018-08-23 14:15:00  002366  12.10     100  198691.931  Order_E1tynpVj
# 13  2018-08-30 09:45:00  002366  11.36    -100  199821.795  Order_r8KgWXa4
# 14  2018-09-05 11:15:00  002366   9.93     200  197830.795  Order_p2IDKvYw
# 15  2018-09-06 10:30:00  002366   9.83     200  195859.795  Order_bT2FBqmf
# 16  2018-09-06 14:15:00  002366   9.66    -200  197784.863  Order_nN7HA6l4
# 17  2018-09-07 09:45:00  002366   9.81     200  195817.863  Order_W8uGPBSw
# 18  2018-09-07 13:15:00  002366   9.76    -200  197762.911  Order_41LlhmN5
# 19  2018-09-12 10:15:00  002366   9.61     200  195835.911  Order_GVRLrjgk
# 20  2018-09-14 09:45:00  002366   8.82    -400  199355.383  Order_CPKneSgx
# 21  2018-09-19 10:15:00  002366   8.72     200  197606.383  Order_S57TMHZ6
# 22  2018-09-27 14:00:00  002366   9.27    -200  199453.529  Order_p1A3TzRh
# 23  2018-10-08 10:15:00  002366   9.48     100  198500.529  Order_4xq3nNo2
# 24  2018-10-10 14:45:00  002366   9.55    -100  199449.574  Order_tro3QsZb
# 25  2018-10-10 15:00:00  002366   9.62     200  197520.574  Order_TrABdfcq
# 26  2018-10-11 09:45:00  002366   9.36    -200  199385.702  Order_93nfUGRQ
# 27  2018-10-12 10:30:00  002366   9.58     100  198422.702  Order_TJjA04zo
# 28  2018-10-16 11:15:00  002366   9.24    -100  199340.778  Order_57FboMV3
# 29  2018-10-22 11:00:00  002366   8.29     100  198506.778  Order_J5AVfH7Z
# 30  2018-10-25 10:15:00  002366   8.20    -100  199320.958  Order_WkYwsczJ
# 31  2018-10-31 11:00:00  002366   8.10     100  198505.958  Order_qO82dKRz
# 32  2018-11-09 09:45:00  002366   9.65    -100  199464.993  Order_bkw0G9zM
# 33  2018-11-12 10:00:00  002366  10.40     100  198419.993  Order_gUsM7yRr
# 34  2018-11-19 10:45:00  002366  10.39    -100  199452.954  Order_PNKZQ5s2
# 35  2018-11-19 14:45:00  002366  10.68     100  198379.954  Order_OlZrCcTX
# 36  2018-11-20 09:45:00  002366  10.43    -100  199416.911  Order_ZS5ODR04
# 37  2018-11-27 10:00:00  002366  10.50     100  198361.911  Order_j1HYNIDL
# 38  2018-12-06 09:45:00  002366  11.79    -100  199534.732  Order_Lv1CHBeR
# 39  2018-12-11 10:15:00  002366  11.59     100  198370.732  Order_aNcQCgRx
# 40  2018-12-12 09:45:00  002366  11.60     100  197205.732  Order_BprJRokT
# 41  2018-12-14 15:00:00  002366  11.58    -200  199514.416  Order_6KMn1CcE
# 42  2018-12-24 13:30:00  002366  10.26     200  197457.416  Order_VP5GvFku
#
#       realorder_id        trade_id     account_cookie  commission    tax  \
# 0   Order_X6OsJ8ZA  Trade_Wlwj5hMk  user_mamin_002366           5  0.000
# 1   Order_w3Mvoqip  Trade_tnaJcTxF  user_mamin_002366           5  1.419
# 2   Order_3PbUuDHA  Trade_QWtADOiR  user_mamin_002366           5  0.000
# 3   Order_ELWgy6CN  Trade_KqbZjLEh  user_mamin_002366           5  1.389
# 4   Order_L2VUQ5SJ  Trade_PnahERXA  user_mamin_002366           5  0.000
# 5   Order_JmeBvqRh  Trade_gcMXkp3j  user_mamin_002366           5  1.476
# 6   Order_aDBCcwOK  Trade_i0ye8ua2  user_mamin_002366           5  0.000
# 7   Order_vt1ZUBCu  Trade_B8ow6LCO  user_mamin_002366           5  1.243
# 8   Order_gXUcKRDd  Trade_JNDoVYRh  user_mamin_002366           5  0.000
# 9   Order_8FjcTund  Trade_QSmC0thM  user_mamin_002366           5  1.260
# 10  Order_XMhKfkmW  Trade_Pj6AQhN1  user_mamin_002366           5  0.000
# 11  Order_rHBQCJUi  Trade_PFE5KhQR  user_mamin_002366           5  1.282
# 12  Order_E1tynpVj  Trade_jgEJYhkB  user_mamin_002366           5  0.000
# 13  Order_r8KgWXa4  Trade_k08HMdql  user_mamin_002366           5  1.136
# 14  Order_p2IDKvYw  Trade_hiCfrEWB  user_mamin_002366           5  0.000
# 15  Order_bT2FBqmf  Trade_Du7nF2N6  user_mamin_002366           5  0.000
# 16  Order_nN7HA6l4  Trade_i3A1OsXU  user_mamin_002366           5  1.932
# 17  Order_W8uGPBSw  Trade_ZhWl9Mjp  user_mamin_002366           5  0.000
# 18  Order_41LlhmN5  Trade_GwcvnohA  user_mamin_002366           5  1.952
# 19  Order_GVRLrjgk  Trade_kMbt3oET  user_mamin_002366           5  0.000
# 20  Order_CPKneSgx  Trade_uSzThXUZ  user_mamin_002366           5  3.528
# 21  Order_S57TMHZ6  Trade_LlYa45jH  user_mamin_002366           5  0.000
# 22  Order_p1A3TzRh  Trade_hEj4JIsr  user_mamin_002366           5  1.854
# 23  Order_4xq3nNo2  Trade_LsKatGJj  user_mamin_002366           5  0.000
# 24  Order_tro3QsZb  Trade_OMwaCxLj  user_mamin_002366           5  0.955
# 25  Order_TrABdfcq  Trade_ovP4kDIx  user_mamin_002366           5  0.000
# 26  Order_93nfUGRQ  Trade_QPtIxZih  user_mamin_002366           5  1.872
# 27  Order_TJjA04zo  Trade_tTUbjDaW  user_mamin_002366           5  0.000
# 28  Order_57FboMV3  Trade_SLxoR8PU  user_mamin_002366           5  0.924
# 29  Order_J5AVfH7Z  Trade_08DAdr7f  user_mamin_002366           5  0.000
# 30  Order_WkYwsczJ  Trade_dnozfpJ7  user_mamin_002366           5  0.820
# 31  Order_qO82dKRz  Trade_7Sc4hIui  user_mamin_002366           5  0.000
# 32  Order_bkw0G9zM  Trade_juz2HqbY  user_mamin_002366           5  0.965
# 33  Order_gUsM7yRr  Trade_oOqFNu9m  user_mamin_002366           5  0.000
# 34  Order_PNKZQ5s2  Trade_jsToE5ZH  user_mamin_002366           5  1.039
# 35  Order_OlZrCcTX  Trade_TbDO5nNv  user_mamin_002366           5  0.000
# 36  Order_ZS5ODR04  Trade_yDAf2TcR  user_mamin_002366           5  1.043
# 37  Order_j1HYNIDL  Trade_4i2ORhjA  user_mamin_002366           5  0.000
# 38  Order_Lv1CHBeR  Trade_0Vl9vaJf  user_mamin_002366           5  1.179
# 39  Order_aNcQCgRx  Trade_1Un0FOMp  user_mamin_002366           5  0.000
# 40  Order_BprJRokT  Trade_Pjm0JF8R  user_mamin_002366           5  0.000
# 41  Order_6KMn1CcE  Trade_PI1NLSRW  user_mamin_002366           5  2.316
# 42  Order_VP5GvFku  Trade_zOolWTcX  user_mamin_002366           5  0.000
#
#    message  frozen
# 0     None       0
# 1     None       0
# 2     None       0
# 3     None       0
# 4     None       0
# 5     None       0
# 6     None       0
# 7     None       0
# 8     None       0
# 9     None       0
# 10    None       0
# 11    None       0
# 12    None       0
# 13    None       0
# 14    None       0
# 15    None       0
# 16    None       0
# 17    None       0
# 18    None       0
# 19    None       0
# 20    None       0
# 21    None       0
# 22    None       0
# 23    None       0
# 24    None       0
# 25    None       0
# 26    None       0
# 27    None       0
# 28    None       0
# 29    None       0
# 30    None       0
# 31    None       0
# 32    None       0
# 33    None       0
# 34    None       0
# 35    None       0
# 36    None       0
# 37    None       0
# 38    None       0
# 39    None       0
# 40    None       0
# 41    None       0
# 42    None       0

# %%
r = QA.QA_Risk(Account)

# %%
r.plot_assets_curve().show()

# %% [markdown]
# 试一下2018全年的,还有从10月下旬到19年的

# %% [markdown]
# 可以仿造example中的simplebacktest.py, 改造成函数, 方便回测
#
# 今天就这样吧
