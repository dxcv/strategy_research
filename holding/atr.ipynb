# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import statsmodels.api as sm
import QUANTAXIS as QA
import talib as ta
import datetime #, time

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %%
code = '002366'

# %%
start = '2018-08-01'
end = '2018-12-05'

# %%
data = QA.QA_fetch_get_stock_day('tushare', code, start, end)

# %%
data.head()
# Out:
#                   date    open   close    high     low    volume    code  \
# date
# 2018-08-01  2018-08-01  13.712  13.406  13.999  13.337  104581.0  002366
# 2018-08-02  2018-08-02  13.189  12.843  13.189  12.418  142153.0  002366
# 2018-08-03  2018-08-03  12.813  12.675  12.971  12.537   84200.0  002366
# 2018-08-06  2018-08-06  12.685  12.023  12.685  11.776  122597.0  002366
# 2018-08-07  2018-08-07  12.023  12.457  12.497  11.865  111633.0  002366
#
#               date_stamp fqtype
# date
# 2018-08-01  1.533053e+09    qfq
# 2018-08-02  1.533139e+09    qfq
# 2018-08-03  1.533226e+09    qfq
# 2018-08-06  1.533485e+09    qfq
# 2018-08-07  1.533571e+09    qfq

# %%
high = data.high
low = data.low
close = data.close
atr = ta.ATR(high, low, close, timeperiod=14)

# %%
atr.head()
# Out:
# date
# 2018-08-01   NaN
# 2018-08-02   NaN
# 2018-08-03   NaN
# 2018-08-06   NaN
# 2018-08-07   NaN
# dtype: float64

# %%
plt.plot(atr.index, atr.values, atr.index, );

# %%
atr.tail()
# Out:
# date
# 2018-11-29    0.603822
# 2018-11-30    0.642835
# 2018-12-03    0.659061
# 2018-12-04    0.652699
# 2018-12-05    0.643221
# dtype: float64

# %%
plt.plot(atr.index, atr.rolling(14).mean().values);

# %%
_, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(atr.index, atr.values, 'r-')
ax2.plot(data.index, data.close, 'b-.');
