# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# import tushare as ts
# import wrds
import talib as ta
import datetime, time

from scipy import stats
from dateutil.relativedelta import *
from pandas.tseries.offsets import *

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %%
crsp = pd.read_csv('data/return.zip', 
                   parse_dates=['date'], infer_datetime_format=True)
# Out:
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crsp.head()
# Out:
#    PERMNO       date TICKER                        COMNAM  PERMCO     CUSIP  \
# 0   14403 1973-01-31  AAGIY  ANGLO AMERICAN GOLD INVT LTD       2  03487050
# 1   14403 1973-02-28  AAGIY  ANGLO AMERICAN GOLD INVT LTD       2  03487050
# 2   14403 1973-03-30  AAGIY  ANGLO AMERICAN GOLD INVT LTD       2  03487050
# 3   14403 1973-04-30  AAGIY  ANGLO AMERICAN GOLD INVT LTD       2  03487050
# 4   14403 1973-05-31  AAGIY  ANGLO AMERICAN GOLD INVT LTD       2  03487050
#
#       PRC       RET   SHROUT      RETX
# 0 -27.125  0.179348  21952.0  0.179348
# 1 -30.625  0.157272  21952.0  0.129032
# 2 -35.125  0.146939  21952.0  0.146939
# 3 -36.500  0.039146  21952.0  0.039146
# 4 -42.500  0.164384  21952.0  0.164384

# %%
crsp[crsp.RET=='B'] # or crsp[crsp.RET=='C']
# Out:
#          PERMNO       date TICKER                       COMNAM  PERMCO  \
# 2594      10058 1974-11-29    NaN     A B K C O INDUSTRIES INC      20
# 2595      10058 1974-12-31    NaN     A B K C O INDUSTRIES INC      20
# 4931      10621 1983-04-29    NaN            ACCU TEST SYS INC      34
# 4932      10621 1983-05-31    NaN            ACCU TEST SYS INC      34
# 4933      10621 1983-06-30    NaN            ACCU TEST SYS INC      34
# 4934      10621 1983-07-29    NaN            ACCU TEST SYS INC      34
# 4935      10621 1983-08-31    NaN            ACCU TEST SYS INC      34
# 4936      10621 1983-09-30    NaN            ACCU TEST SYS INC      34
# 4937      10621 1983-10-31    NaN            ACCU TEST SYS INC      34
# 4938      10621 1983-11-30    NaN            ACCU TEST SYS INC      34
# 4939      10621 1983-12-30    NaN            ACCU TEST SYS INC      34
# 4940      10621 1984-01-31    NaN            ACCU TEST SYS INC      34
# 4941      10621 1984-02-29    NaN            ACCU TEST SYS INC      34
# 4942      10621 1984-03-30    NaN            ACCU TEST SYS INC      34
# 4943      10621 1984-04-30    NaN            ACCU TEST SYS INC      34
# 4944      10621 1984-05-31    NaN            ACCU TEST SYS INC      34
# 4945      10621 1984-06-29    NaN            ACCU TEST SYS INC      34
# 4946      10621 1984-07-31    NaN            ACCU TEST SYS INC      34
# 4947      10621 1984-08-31    NaN            ACCU TEST SYS INC      34
# 4948      10621 1984-09-28    NaN            ACCU TEST SYS INC      34
# 4949      10621 1984-10-31    NaN            ACCU TEST SYS INC      34
# 4950      10621 1984-11-30    NaN            ACCU TEST SYS INC      34
# 4951      10621 1984-12-31    NaN            ACCU TEST SYS INC      34
# 4952      10621 1985-01-31    NaN            ACCU TEST SYS INC      34
# 4953      10621 1985-02-28    NaN            ACCU TEST SYS INC      34
# 4954      10621 1985-03-29    NaN            ACCU TEST SYS INC      34
# 4937     69418810  NaN   B   4249.0    B
# 4938     69418810  NaN   B   4249.0    B
# 4939     69418810  NaN   B   4249.0    B
# 4940     69418810  NaN   B   4249.0    B
# 4941     69418810  NaN   B   4249.0    B
# 4942     69418810  NaN   B   4249.0    B
# 4943     69418810  NaN   B   4249.0    B
# 4944     69418810  NaN   B   4249.0    B
# 4945     69418810  NaN   B   4249.0    B
# 4946     69418810  NaN   B   4249.0    B
# 4947     69418810  NaN   B   4249.0    B
# 4948     69418810  NaN   B   4249.0    B
# 4949     69418810  NaN   B   4249.0    B
# 4950     69418810  NaN   B   4249.0    B
# 4951     69418810  NaN   B   4249.0    B
# 4952     69418810  NaN   B   4249.0    B
# 4953     69418810  NaN   B   4249.0    B
# 4954     69418810  NaN   B   4249.0    B
# 4955     69418810  NaN   B   4249.0    B
# 4956     69418810  NaN   B   4249.0    B
# 4957     69418810  NaN   B   4249.0    B
# 4958     69418810  NaN   B   4249.0    B
# ...           ...  ...  ..      ...  ...
# 2888193  92343X10  NaN   B  32187.0    B
# 2888194  92343X10  NaN   B  32187.0    B
# 2888195  92343X10  NaN   B  32187.0    B
# 2888196  92343X10  NaN   B  32187.0    B
# 2888197  92343X10  NaN   B  32187.0    B
# 2888198  92343X10  NaN   B  32187.0    B
# 2888199  92343X10  NaN   B  32187.0    B
# 2888200  92343X10  NaN   B  32187.0    B
# 2888201  92343X10  NaN   B  32187.0    B
# 2926345  68402330  NaN   B  38318.0    B
# 2928164  64960450  NaN   B  18179.0    B
# 2928165  64960450  NaN   B  18179.0    B
# 2928166  64960450  NaN   B  18179.0    B
# 2928167  64960450  NaN   B  18179.0    B
# 2928168  64960450  NaN   B  18179.0    B
# 2928169  64960450  NaN   B  18179.0    B
# 2928170  64960450  NaN   B  18179.0    B
# 2928171  64960450  NaN   B  18179.0    B
# 2928172  64960450  NaN   B  18179.0    B
# 2939087  89255N20  NaN   B  13019.0    B
# 2939088  89255N20  NaN   B  13019.0    B
# 2939089  89255N20  NaN   B  13019.0    B
# 2939090  89255N20  NaN   B  13019.0    B
# 2939091  89255N20  NaN   B  13019.0    B
# 2939092  89255N20  NaN   B  13019.0    B
# 2943812  00439T20  NaN   B  35726.0    B
# 2943813  00439T20  NaN   B  35726.0    B
# 2954072  79379T20  NaN   B   9181.0    B
# 2954073  79379T20  NaN   B   9181.0    B
# 2954074  79379T20  NaN   B   9181.0    B
#
# [49770 rows x 10 columns]

# %%
crsp = pd.read_csv('data/return.zip', 
                   parse_dates=['date'], infer_datetime_format=True)
crsp[['PERMNO', 'PERMCO']] = crsp[['PERMNO', 'PERMCO']].astype(int)
crsp_name = pd.read_csv('data/crsp_name.csv', 
                   parse_dates=['namedt','nameendt'], infer_datetime_format=True)
crsp_name = crsp_name.drop('Unnamed: 0', axis=1)
crsp_name[['permno', 'shrcd', 'exchcd']] = \
crsp_name[['permno', 'shrcd', 'exchcd']].astype(int)

crsp_name['namedt'] = pd.to_datetime(crsp_name['namedt'])
crsp_name['nameendt'] = pd.to_datetime(crsp_name['nameendt'])
# if nameendt is missing then set to today date
crsp_name['nameendt'] = crsp_name['nameendt'].fillna(pd.to_datetime('today'))
crsp_merge = pd.merge(crsp, crsp_name, 'inner', left_on='PERMNO', right_on='permno')
crsp_merge = crsp_merge[(crsp_merge.date <= crsp_merge.nameendt) &
                       (crsp_merge.date >= crsp_merge.namedt)]
crsp_merge.RET = crsp_merge.RET.replace(['B', 'C'], [np.nan, np.nan]).astype(np.float64)
crsp_merge.RETX = crsp_merge.RETX.replace(['B', 'C'], [np.nan, np.nan]).astype(np.float64)

crsp_merge.RET = crsp_merge.RET.fillna(0)
crsp_merge.RETX = crsp_merge.RETX.fillna(0)

crsp_merge = crsp_merge.drop(['permno', 'namedt', 'nameendt'], axis=1)

crsp_merge.columns = [i.lower() for i in crsp_merge.columns]
# Out:
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crsp_merge = crsp_merge[['permno', 'date', 'ticker', 'comnam',  
                         'prc', 'ret', 'shrout', 'retx']]

# %% [markdown]
# ### calculate the mv, ret+1, retx+1

# %%
# calculate the mv, ret+1, retx+1
crsp1 = crsp_merge.assign(mv = crsp_merge.prc.abs() * crsp_merge.shrout,
                         ret_p1 = crsp_merge.ret+1,
                         retx_p1 = crsp_merge.retx+1)

# %%
# resample : use calendar year
def normal_resample(df):
    res = df.resample('Y').apply({'ret_p1':'cumprod', 'retx_p1':'cumprod'})
    res = pd.concat([res, df.mv], axis=1)
    res = res.resample('Y').last()
    return res

# %%
crsp1[crsp1.ticker=='AMER']
# Out:
#          permno       date ticker                        comnam      prc  \
# 4815915   85316 1985-04-30   AMER  AMERICA FIRST FED GTD MTG FD -20.1250
# 4815916   85316 1985-05-31   AMER  AMERICA FIRST FED GTD MTG FD -20.8750
# 4815917   85316 1985-06-28   AMER  AMERICA FIRST FED GTD MTG FD -20.3750
# 4815918   85316 1985-07-31   AMER  AMERICA FIRST FED GTD MTG FD -20.3750
# 4815919   85316 1985-08-30   AMER  AMERICA FIRST FED GTD MTG FD -20.1250
# 4815920   85316 1985-09-30   AMER  AMERICA FIRST FED GTD MTG FD  19.7500
# 4815921   85316 1985-10-31   AMER  AMERICA FIRST FED GTD MTG FD  18.2500
# 4815922   85316 1985-11-29   AMER  AMERICA FIRST FED GTD MTG FD  18.6250
# 4815923   85316 1985-12-31   AMER  AMERICA FIRST FED GTD MTG FD  19.1250
# 4815924   85316 1986-01-31   AMER  AMERICA FIRST FED GTD MTG FD  19.0000
# 4815925   85316 1986-02-28   AMER  AMERICA FIRST FED GTD MTG FD  19.7500
# 4815926   85316 1986-03-31   AMER  AMERICA FIRST FED GTD MTG FD  17.7500
# 4815927   85316 1986-04-30   AMER  AMERICA FIRST FED GTD MTG FD   5.2500
# 4815928   85316 1986-05-30   AMER  AMERICA FIRST FED GTD MTG FD   3.5000
# 4815929   85316 1986-06-30   AMER  AMERICA FIRST FED GTD MTG FD   3.2500
# 4815930   85316 1986-07-31   AMER  AMERICA FIRST FED GTD MTG FD   2.6250
# 1992-04-30 -0.229508  64237.250  0.770492  0.770492
# 1992-05-29  0.063830  68337.500  1.063830  1.063830
# 1992-06-30  0.080000  73993.500  1.080000  1.080000
# 1992-07-31  0.046296  77419.125  1.046296  1.046296

# %%
normal_resample(test)
# Out:
#               ret_p1   retx_p1            mv
# date
# 1992-12-31  1.918033  1.918033  1.678072e+05
# 1993-12-31  2.000764  2.000001  4.111965e+05
# 1994-12-31  1.914528  1.914528  9.291520e+05
# 1995-12-31  2.678568  2.678568  3.246112e+06
# 1996-12-31  0.886665  0.886665  3.104486e+06
# 1997-12-31  2.721810  2.721810  9.313355e+06
# 1998-12-31  6.934765  6.934712  7.106990e+07
# 1999-12-31  1.956485  1.956485  1.696175e+08
# 2000-12-31  0.458649  0.458649  8.087910e+07
# 2001-12-31  0.922413  0.922413  1.365999e+08
# 2002-12-31  0.408099  0.408099  5.631639e+07
# 2003-12-31  1.373283  1.373283  7.826657e+07
# 2004-12-31  1.081156  1.081156  8.575871e+07
# 2005-12-31  0.901661  0.896659  7.979437e+07
# 2006-12-31  1.263697  1.248854  8.652264e+07
# 2007-12-31  0.767318  0.758034  5.967698e+07
# 2008-12-31  0.620778  0.609328  3.608984e+07

# %%
crsp1[crsp1.permno==77418].set_index('date').\
resample('Y').apply({'ret_p1':'cumprod', 'retx_p1':'cumprod'}).resample('Y').last()
# Out:
#               ret_p1   retx_p1
# date
# 1992-12-31  1.918033  1.918033
# 1993-12-31  2.000764  2.000001
# 1994-12-31  1.914528  1.914528
# 1995-12-31  2.678568  2.678568
# 1996-12-31  0.886665  0.886665
# 1997-12-31  2.721810  2.721810
# 1998-12-31  6.934765  6.934712
# 1999-12-31  1.956485  1.956485
# 2000-12-31  0.458649  0.458649
# 2001-12-31  0.922413  0.922413
# 2002-12-31  0.408099  0.408099
# 2003-12-31  1.373283  1.373283
# 2004-12-31  1.081156  1.081156
# 2005-12-31  0.901661  0.896659
# 2006-12-31  1.263697  1.248854
# 2007-12-31  0.767318  0.758034
# 2008-12-31  0.620778  0.609328

# %%
# 验证normal_resample是否能正常运作
test_code_list = crsp1.permno.unique().tolist()[-5:]
test_data = crsp1.set_index('permno').iloc[test_code_list]
test_data = test_data.reset_index().set_index('date')
test_data.groupby('permno').apply(normal_resample)
# Out:
#                      ret_p1   retx_p1          mv
# permno date
# 10234  1974-12-31  1.000000  1.000000         NaN
# 17778  1981-12-31  1.119318  1.119318  485605.000
# 19271  2000-12-31  1.072917  1.072917  137801.125

# %%
tic = time.perf_counter()
crsp2 = crsp1.set_index('date').groupby('permno').apply(normal_resample)
toc = time.perf_counter()
print(toc-tic)
# Out:
# 199.2612253

# %%
crsp2.head()
# Out:
#                      ret_p1   retx_p1          mv
# permno date
# 10000  1986-12-31  0.117857  0.117857  1981.56609
#        1987-12-31  0.424243  0.424243   851.59375
# 10001  1986-12-31  1.217369  1.142857  6937.00000
#        1987-12-31  0.898725  0.839285  5828.00000
#        1988-12-31  1.163160  1.085106  6362.25000

# %% [markdown]
# example : America Online

# %%
code = 77418 # America Online的permno
sample_data = crsp2.loc[(code, slice(None))]

# %%
# calculate the EXF
sample_data = sample_data.assign(
    exf = sample_data.mv - sample_data.mv.shift(1) * sample_data.retx_p1
)

# %%
sample_data
# Out:
#               ret_p1   retx_p1            mv           exf
# date
# 1992-12-31  1.918033  1.918033  1.678072e+05           NaN
# 1993-12-31  2.000764  2.000001  4.111965e+05  7.558184e+04
# 1994-12-31  1.914528  1.914528  9.291520e+05  1.419047e+05
# 1995-12-31  2.678568  2.678568  3.246112e+06  7.573156e+05
# 1996-12-31  0.886665  0.886665  3.104486e+06  2.262706e+05
# 1997-12-31  2.721810  2.721810  9.313355e+06  8.635347e+05
# 1998-12-31  6.934765  6.934712  7.106990e+07  6.484468e+06
# 1999-12-31  1.956485  1.956485  1.696175e+08  3.057033e+07
# 2000-12-31  0.458649  0.458649  8.087910e+07  3.084190e+06
# 2001-12-31  0.922413  0.922413  1.365999e+08  6.199592e+07
# 2002-12-31  0.408099  0.408099  5.631639e+07  5.700648e+05
# 2003-12-31  1.373283  1.373283  7.826657e+07  9.282606e+05
# 2004-12-31  1.081156  1.081156  8.575871e+07  1.140300e+06
# 2005-12-31  0.901661  0.896659  7.979437e+07  2.898036e+06
# 2006-12-31  1.263697  1.248854  8.652264e+07 -1.312886e+07
# 2007-12-31  0.767318  0.758034  5.967698e+07 -5.910087e+06
# 2008-12-31  0.620778  0.609328  3.608984e+07 -2.730212e+05

# %%
mv_2000 = sample_data['2000'].mv.iloc[0]
mv_2001 = sample_data['2001'].mv.iloc[0]
rx_2001 = sample_data['2001'].retx_p1.iloc[0] - 1
exf_2001 = sample_data['2001'].exf.iloc[0]
print(mv_2000, mv_2001, rx_2001, exf_2001)
# Out:
# 80879097.6 136599880.8 -0.0775866884424 61995924.547

# %% [markdown]
# 通过上表,我们可以观察到$MV_{2000}$为80879, $MV_{2001}$为136600(四舍五入),
#
# $rx_{2001}$为-7.76%, $EXF_{2001}$为61996.

# %% [markdown]
# 为了方便计算$WRT_{t+1, t+T}$, 我们需要对normal_resample函数进行改造

# %%
def normal_resample_t(df, period):
    if type(period) is int:
        period = str(period)
#     res = df.rolling(int(period)).apply({'ret_p1':'cumprod', 'retx_p1':'cumprod'})
    ret_rolling = df.ret_p1.rolling(int(period), min_periods=1).\
    apply(pd.Series.cumprod, raw=False)
    retx_rolling = df.retx_p1.rolling(int(period), min_periods=1).\
    apply(pd.Series.cumprod, raw=False)
#     res = pd.concat([ret_rolling, retx_rolling, df.mv], axis=1)
    res = pd.DataFrame({'ret_rolling':ret_rolling,
                       'retx_rolling':retx_rolling,})
#                        'mv':df.mv})
#     res = res.resample(period+'Y').last()
    return res

# %%
test_code_list = crsp1.permno.unique().tolist()[:5]
test_data = crsp2.reset_index().set_index('permno').iloc[test_code_list]
test_data = test_data.reset_index().set_index('date')
test_data.groupby('permno').apply(normal_resample_t, period=5)
# Out:
#             ret_rolling  retx_rolling
# date
# 2005-12-31     1.009105      1.009105
# 1992-12-31     1.400000      1.400000
# 1983-12-31     1.671619      1.641789
# 1991-12-31     0.933669      0.900000
# 1978-12-31     8.599386      8.432429

# %%
tic = time.perf_counter()
crsp3 = crsp2.reset_index().set_index('date')
crsp3 = crsp3.groupby('permno').apply(normal_resample_t, period=5)
toc = time.perf_counter()
print(toc-tic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in f(g)
#     907                     with np.errstate(all='ignore'):
# --> 908                         return func(g, *args, **kwargs)
#     909             else:
#
# <ipython-input-56-9be164825950> in normal_resample_t(df, period)
#       4 #     res = df.rolling(int(period)).apply({'ret_p1':'cumprod', 'retx_p1':'cumprod'})
# ----> 5     ret_rolling = df.ret_p1.rolling(int(period)).apply(pd.Series.cumprod, raw=False)
#       6     retx_rolling = df.retx_p1.rolling(int(period)).apply(pd.Series.cumprod, raw=False)
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in apply(self, func, raw, args, kwargs)
#    1579         return super(Rolling, self).apply(
# -> 1580             func, raw=raw, args=args, kwargs=kwargs)
#    1581
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in apply(self, func, raw, args, kwargs)
#    1002         return self._apply(f, func, args=args, kwargs=kwargs,
# -> 1003                            center=False, raw=raw)
#    1004
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     882                 else:
# --> 883                     result = calc(values)
#     884
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in calc(x)
#     876                     return func(x, window, min_periods=self.min_periods,
# --> 877                                 closed=self.closed)
#     878
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in f(arg, window, min_periods, closed)
#     999                 arg, window, minp, indexi,
# -> 1000                 closed, offset, func, raw, args, kwargs)
#    1001
#
# pandas/_libs/window.pyx in pandas._libs.window.roll_generic()
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\series.py in wrapper(self)
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#
# TypeError: cannot convert the series to <class 'float'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-b9a8d43e9dd4> in <module>()
#       1 tic = time.perf_counter()
#       2 crsp3 = crsp2.reset_index().set_index('date')
# ----> 3 crsp3 = crsp3.groupby('permno').apply(normal_resample_t, period=5)
#       4 toc = time.perf_counter()
#       5 print(toc-tic)
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\groupby\groupby.py in f(g)
#     906                 def f(g):
#     907                     with np.errstate(all='ignore'):
# --> 908                         return func(g, *args, **kwargs)
#     909             else:
#     910                 raise ValueError('func must be a callable if args or '
#
# <ipython-input-56-9be164825950> in normal_resample_t(df, period)
#       3         period = str(period)
#       4 #     res = df.rolling(int(period)).apply({'ret_p1':'cumprod', 'retx_p1':'cumprod'})
# ----> 5     ret_rolling = df.ret_p1.rolling(int(period)).apply(pd.Series.cumprod, raw=False)
#       6     retx_rolling = df.retx_p1.rolling(int(period)).apply(pd.Series.cumprod, raw=False)
#       7     res = pd.concat([ret_rolling, retx_rolling, df.mv], axis=1)
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in apply(self, func, raw, args, kwargs)
#    1578     def apply(self, func, raw=None, args=(), kwargs={}):
#    1579         return super(Rolling, self).apply(
# -> 1580             func, raw=raw, args=args, kwargs=kwargs)
#    1581
#    1582     @Substitution(name='rolling')
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in apply(self, func, raw, args, kwargs)
#    1001
#    1002         return self._apply(f, func, args=args, kwargs=kwargs,
# -> 1003                            center=False, raw=raw)
#    1004
#    1005     def sum(self, *args, **kwargs):
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     881                     result = np.apply_along_axis(calc, self.axis, values)
#     882                 else:
# --> 883                     result = calc(values)
#     884
#     885             if center:
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in calc(x)
#     875                 def calc(x):
#     876                     return func(x, window, min_periods=self.min_periods,
# --> 877                                 closed=self.closed)
#     878
#     879             with np.errstate(all='ignore'):
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\window.py in f(arg, window, min_periods, closed)
#     998             return _window.roll_generic(
#     999                 arg, window, minp, indexi,
# -> 1000                 closed, offset, func, raw, args, kwargs)
#    1001
#    1002         return self._apply(f, func, args=args, kwargs=kwargs,
#
# pandas/_libs/window.pyx in pandas._libs.window.roll_generic()
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>

# %%
crsp3.head()
# Out:
#               ret_p1   retx_p1          mv
# date
# 1986-12-31  0.117857  0.117857  1981.56609
# 1987-12-31  0.424243  0.424243   851.59375
# 1986-12-31  1.217369  1.142857  6937.00000
# 1987-12-31  0.898725  0.839285  5828.00000
# 1988-12-31  1.045361  0.910713  6362.25000

# %%
crsp3.loc[(code, slice(None))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d30fc8e53516> in <module>()
# ----> 1 crsp3.loc[(code, slice(None))]
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     996         for i, key in enumerate(tup):
#     997             if is_label_like(key) or isinstance(key, tuple):
# --> 998                 section = self._getitem_axis(key, axis=i)
#     999
#    1000                 # we have yielded a scalar ?
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1786
#    1787             try:
# -> 1788                 key = self._convert_scalar_indexer(key, axis)
#    1789                 if not ax.contains(key):
#    1790                     error()
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexing.py in _convert_scalar_indexer(self, key, axis)
#     259         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     260         # a scalar
# --> 261         return ax._convert_scalar_indexer(key, kind=self.name)
#     262
#     263     def _convert_slice_indexer(self, key, axis):
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexes\datetimelike.py in _convert_scalar_indexer(self, key, kind)
#     744             is_flt = is_float(key)
#     745             if kind in ['loc'] and (is_int or is_flt):
# --> 746                 self._invalid_indexer('index', key)
#     747             elif kind in ['ix', 'getitem'] and is_flt:
#     748                 self._invalid_indexer('index', key)
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    1861                         "indexers [{key}] of {kind}".format(
#    1862                             form=form, klass=type(self), key=key,
# -> 1863                             kind=type(key)))
#    1864
#    1865     def get_duplicates(self):
#
# TypeError: cannot do index indexing on <class 'pandas.core.indexes.datetimes.DatetimeIndex'> with these indexers [77418] of <class 'int'>

# %% [markdown]
# 我想应该这么处理,
