# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib as ta
import datetime, time
import pickle
from tqdm import tqdm_notebook

import pdblp as pb
import blpapi

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %%
def save_file(dataframe, name):
    
    with open(name, 'wb') as f:
        pickle.dump(dataframe, f)

# %%
con = pb.BCon(port=8194, timeout=5000)
con.start()

# %%
df_code = pd.read_excel('data/etf_pair_code.xlsx', dtype={'symbol':str})

# %%
code_list = df_code.symbol.unique().tolist()

# %%
ticker_list = (df_code.symbol + ' ' + df_code.region).unique().tolist()

# %% [markdown]
# ### test 1

# %%
df = pd.DataFrame()
err_code = []
tic = time.perf_counter()
fields = ['HIGH', 'OPEN', 'LOW', 'CLOSE', 'VOLUME', 'PX_LAST']
cols = ['High', 'Open', 'Low', 'Close', 'Volume', 'Adj Close']
start = '20100101'
end = '20190110'



for i in tqdm_notebook(ticker_list):
    try:
        temp_df = con.bdh(i, fields, start, end)
        temp_df = temp_df.loc[:, i]
        temp_df.columns = cols
        temp_df = temp_df.assign(code=i.split(' ')[0])

        try:
            df = pd.concat([df, temp_df], axis=0)
        except:
            print('concat data has problem, ticker code : %s' % i)

    except:
        print('retrieve %s data, have something wrong' % i)
        err_code.append(i)
toc = time.perf_counter()

print('retrieve data cost time: %s' % (toc-tic))
# Out:
# HBox(children=(IntProgress(value=0, max=925), HTML(value='')))
# retrieve MSFT US Equity data, have something wrong
# retrieve AAPL US Equity data, have something wrong
# retrieve V US Equity data, have something wrong
# retrieve INTC US Equity data, have something wrong
# retrieve CSCO US Equity data, have something wrong
# retrieve MA US Equity data, have something wrong
# retrieve ORCL US Equity data, have something wrong
# retrieve AVGO US Equity data, have something wrong
# retrieve ADBE US Equity data, have something wrong
# retrieve IBM US Equity data, have something wrong
# retrieve PYPL US Equity data, have something wrong
# retrieve CRM US Equity data, have something wrong
# retrieve ACN US Equity data, have something wrong
# retrieve TXN US Equity data, have something wrong
# retrieve NVDA US Equity data, have something wrong
# retrieve QCOM US Equity data, have something wrong
# retrieve ADP US Equity data, have something wrong
# retrieve INTU US Equity data, have something wrong
# retrieve MU US Equity data, have something wrong
# retrieve CTSH US Equity data, have something wrong
# retrieve HPQ US Equity data, have something wrong
# retrieve FIS US Equity data, have something wrong
# retrieve ADI US Equity data, have something wrong
# retrieve AMAT US Equity data, have something wrong
# retrieve RHT US Equity data, have something wrong
# retrieve FISV US Equity data, have something wrong
# retrieve ADSK US Equity data, have something wrong
# retrieve TEL US Equity data, have something wrong
# retrieve GLW US Equity data, have something wrong
# retrieve APH US Equity data, have something wrong
# retrieve XLNX US Equity data, have something wrong
# retrieve LRCX US Equity data, have something wrong
# retrieve PAYX US Equity data, have something wrong
# retrieve MSI US Equity data, have something wrong
# retrieve HPE US Equity data, have something wrong
# retrieve MCHP US Equity data, have something wrong
# retrieve AMD US Equity data, have something wrong
# retrieve VRSN US Equity data, have something wrong
# retrieve GPN US Equity data, have something wrong
# retrieve FLT US Equity data, have something wrong
# retrieve DXC US Equity data, have something wrong
# retrieve NTAP US Equity data, have something wrong
# retrieve MXIM US Equity data, have something wrong
# retrieve KLAC US Equity data, have something wrong
# retrieve CTXS US Equity data, have something wrong
# retrieve TSS US Equity data, have something wrong
# retrieve SYMC US Equity data, have something wrong
# retrieve SNPS US Equity data, have something wrong
# retrieve ANSS US Equity data, have something wrong
# retrieve SWKS US Equity data, have something wrong
# retrieve IT US Equity data, have something wrong
# retrieve CDNS US Equity data, have something wrong
# retrieve KEYS US Equity data, have something wrong
# retrieve WDC US Equity data, have something wrong
# retrieve BR US Equity data, have something wrong
# retrieve AKAM US Equity data, have something wrong
# retrieve ANET US Equity data, have something wrong
# retrieve JKHY US Equity data, have something wrong
# retrieve FFIV US Equity data, have something wrong
# retrieve STX US Equity data, have something wrong
# retrieve FTNT US Equity data, have something wrong
# retrieve JNPR US Equity data, have something wrong
# retrieve WU US Equity data, have something wrong
# retrieve QRVO US Equity data, have something wrong
# retrieve ADS US Equity data, have something wrong
# retrieve FLIR US Equity data, have something wrong
# retrieve XRX US Equity data, have something wrong
# retrieve IPGP US Equity data, have something wrong
# retrieve BKNG US Equity data, have something wrong
# retrieve GOOG US Equity data, have something wrong
# retrieve FB US Equity data, have something wrong
# retrieve AMZN US Equity data, have something wrong
# retrieve NFLX US Equity data, have something wrong
# retrieve AABA US Equity data, have something wrong
# retrieve EQIX US Equity data, have something wrong
# retrieve EBAY US Equity data, have something wrong
# retrieve BIDU US Equity data, have something wrong
# retrieve TWTR US Equity data, have something wrong
# retrieve JD US Equity data, have something wrong
# retrieve NTES US Equity data, have something wrong
# retrieve EXPE US Equity data, have something wrong
# retrieve MELI US Equity data, have something wrong
# retrieve IAC US Equity data, have something wrong
# retrieve CTRP US Equity data, have something wrong
# retrieve CSGP US Equity data, have something wrong
# retrieve GDDY US Equity data, have something wrong
# retrieve YNDX US Equity data, have something wrong
# retrieve TRIP US Equity data, have something wrong
# retrieve ETSY US Equity data, have something wrong
# retrieve OKTA US Equity data, have something wrong
# retrieve SNAP US Equity data, have something wrong
# retrieve NTNX US Equity data, have something wrong
# retrieve ATHM US Equity data, have something wrong
# retrieve NEWR US Equity data, have something wrong
# retrieve TTD US Equity data, have something wrong
# retrieve SINA US Equity data, have something wrong
# retrieve LOGM US Equity data, have something wrong
# retrieve WIX US Equity data, have something wrong
# retrieve WB US Equity data, have something wrong
# retrieve MOMO US Equity data, have something wrong
# retrieve JCOM US Equity data, have something wrong
# retrieve COUP US Equity data, have something wrong
# retrieve CMPR US Equity data, have something wrong
# retrieve TWOU US Equity data, have something wrong
# retrieve YY US Equity data, have something wrong
# retrieve CSOD US Equity data, have something wrong
# retrieve STMP US Equity data, have something wrong
# retrieve MTCH US Equity data, have something wrong
# retrieve ALRM US Equity data, have something wrong
# retrieve FIVN US Equity data, have something wrong
# retrieve P US Equity data, have something wrong
# retrieve ENV US Equity data, have something wrong
# retrieve LEXEA US Equity data, have something wrong
# retrieve CCOI US Equity data, have something wrong
# retrieve MIME US Equity data, have something wrong
# retrieve Z US Equity data, have something wrong
# retrieve GRPN US Equity data, have something wrong
# retrieve APTI US Equity data, have something wrong
# retrieve BNFT US Equity data, have something wrong
# retrieve CRTO US Equity data, have something wrong
# retrieve SE US Equity data, have something wrong
# retrieve MMYT US Equity data, have something wrong
# retrieve BZUN US Equity data, have something wrong
# retrieve SPSC US Equity data, have something wrong
# retrieve SFLY US Equity data, have something wrong
# retrieve NTRI US Equity data, have something wrong
# retrieve BCOR US Equity data, have something wrong
# retrieve LTRPA US Equity data, have something wrong
# retrieve HDP US Equity data, have something wrong
# retrieve SSTK US Equity data, have something wrong
# retrieve GDS US Equity data, have something wrong
# retrieve LPSN US Equity data, have something wrong
# retrieve MB US Equity data, have something wrong
# retrieve EIGI US Equity data, have something wrong
# retrieve TRUE US Equity data, have something wrong
# retrieve APPF US Equity data, have something wrong
# retrieve WIFI US Equity data, have something wrong
# retrieve CARB US Equity data, have something wrong
# retrieve SOHU US Equity data, have something wrong
# retrieve EGOV US Equity data, have something wrong
# retrieve QNST US Equity data, have something wrong
# retrieve TCX US Equity data, have something wrong
# retrieve VNET US Equity data, have something wrong
# retrieve SOGO US Equity data, have something wrong
# retrieve PETS US Equity data, have something wrong
# retrieve IUGXX US Equity data, have something wrong
# retrieve LE US Equity data, have something wrong
# retrieve FLWS US Equity data, have something wrong
# retrieve OSTK US Equity data, have something wrong
# retrieve SWCH US Equity data, have something wrong
# retrieve GOGO US Equity data, have something wrong
# retrieve LLNW US Equity data, have something wrong
# retrieve BCOV US Equity data, have something wrong
# retrieve WBAI US Equity data, have something wrong
# retrieve LQDT US Equity data, have something wrong
# retrieve EGAN US Equity data, have something wrong
# retrieve XNET US Equity data, have something wrong
# retrieve VERI US Equity data, have something wrong
# retrieve INAP US Equity data, have something wrong
# retrieve MARK US Equity data, have something wrong
# retrieve 700 HK Equity data, have something wrong
# retrieve BABA US Equity data, have something wrong
# retrieve WUBA US Equity data, have something wrong
# retrieve 992 HK Equity data, have something wrong
# retrieve 2382 HK Equity data, have something wrong
# retrieve 981 HK Equity data, have something wrong
# retrieve 2018 HK Equity data, have something wrong
# retrieve 522 HK Equity data, have something wrong
# retrieve 696 HK Equity data, have something wrong
# retrieve 148 HK Equity data, have something wrong
# retrieve 268 HK Equity data, have something wrong
# retrieve 3396 HK Equity data, have something wrong
# retrieve 3888 HK Equity data, have something wrong
# retrieve 763 HK Equity data, have something wrong
# retrieve 354 HK Equity data, have something wrong
# retrieve 3969 HK Equity data, have something wrong
# retrieve 968 HK Equity data, have something wrong
# retrieve HOLI US Equity data, have something wrong
# retrieve 1347 HK Equity data, have something wrong
# retrieve 285 HK Equity data, have something wrong
# retrieve 3800 HK Equity data, have something wrong
# retrieve BITA US Equity data, have something wrong
# retrieve 1888 HK Equity data, have something wrong
# retrieve 6088 HK Equity data, have something wrong
# retrieve 8083 HK Equity data, have something wrong
# retrieve 582 HK Equity data, have something wrong
# retrieve 861 HK Equity data, have something wrong
# retrieve 6869 HK Equity data, have something wrong
# retrieve 1357 HK Equity data, have something wrong
# retrieve 2662 HK Equity data, have something wrong
# retrieve 777 HK Equity data, have something wrong
# retrieve 698 HK Equity data, have something wrong
# retrieve 1686 HK Equity data, have something wrong
# retrieve 1089 HK Equity data, have something wrong
# retrieve 327 HK Equity data, have something wrong
# retrieve CYOU US Equity data, have something wrong
# retrieve 2280 HK Equity data, have something wrong
# retrieve JKS US Equity data, have something wrong
# retrieve 1385 HK Equity data, have something wrong
# retrieve 732 HK Equity data, have something wrong
# retrieve SFUN US Equity data, have something wrong
# retrieve CMCM US Equity data, have something wrong
# retrieve 1980 HK Equity data, have something wrong
# retrieve 818 HK Equity data, have something wrong
# retrieve 3336 HK Equity data, have something wrong
# retrieve 3393 HK Equity data, have something wrong
# retrieve 8279 HK Equity data, have something wrong
# retrieve DQ US Equity data, have something wrong
# retrieve 2342 HK Equity data, have something wrong
# retrieve 877 HK Equity data, have something wrong
# retrieve HKD Curncy data, have something wrong
# retrieve YRD US Equity data, have something wrong
# retrieve 31 HK Equity data, have something wrong
# retrieve 8227 HK Equity data, have something wrong
# retrieve 862 HK Equity data, have something wrong
# retrieve FENG US Equity data, have something wrong
# retrieve 434 HK Equity data, have something wrong
# retrieve 85 HK Equity data, have something wrong
# retrieve 633 HK Equity data, have something wrong
# retrieve 2369 HK Equity data, have something wrong
# retrieve RENN US Equity data, have something wrong
# retrieve 885 HK Equity data, have something wrong
# retrieve 1149 HK Equity data, have something wrong
# retrieve 61 HK Equity data, have something wrong
# retrieve 1236 HK Equity data, have something wrong
# retrieve LKM US Equity data, have something wrong
# retrieve GLUU US Equity data, have something wrong
# retrieve 036570 KS Equity data, have something wrong
# retrieve TTWO US Equity data, have something wrong
# retrieve 9766 JP Equity data, have something wrong
# retrieve GME US Equity data, have something wrong
# retrieve 799 HK Equity data, have something wrong
# retrieve ZNGA US Equity data, have something wrong
# retrieve 9697 JP Equity data, have something wrong
# retrieve 263750 KS Equity data, have something wrong
# retrieve 3659 JP Equity data, have something wrong
# retrieve 7974 JP Equity data, have something wrong
# retrieve 3632 JP Equity data, have something wrong
# retrieve UBI FP Equity data, have something wrong
# retrieve 251270 KS Equity data, have something wrong
# retrieve SNE US Equity data, have something wrong
# retrieve 078340 KS Equity data, have something wrong
# retrieve ATVI US Equity data, have something wrong
# retrieve 2377 TT Equity data, have something wrong
# retrieve 069080 KS Equity data, have something wrong
# retrieve 9684 JP Equity data, have something wrong
# retrieve THQNB SS Equity data, have something wrong
# retrieve EA US Equity data, have something wrong
# retrieve AFX GR Equity data, have something wrong
# retrieve 7832 JP Equity data, have something wrong
# retrieve 3635 JP Equity data, have something wrong
# retrieve LOGI US Equity data, have something wrong
# retrieve PDX SS Equity data, have something wrong
# retrieve 2432 JP Equity data, have something wrong
# retrieve 112040 KS Equity data, have something wrong
# retrieve 6460 JP Equity data, have something wrong
# retrieve MTGB SS Equity data, have something wrong
# retrieve 2357 TT Equity data, have something wrong
# retrieve 3765 JP Equity data, have something wrong
# retrieve 2353 TT Equity data, have something wrong
# retrieve GRVY US Equity data, have something wrong
# retrieve 6180 TT Equity data, have something wrong
# retrieve 1337 HK Equity data, have something wrong
# retrieve 7844 JP Equity data, have something wrong
# retrieve SF SS Equity data, have something wrong
# retrieve HEAR US Equity data, have something wrong
# retrieve VUZI US Equity data, have something wrong
# retrieve G5EN SS Equity data, have something wrong
# retrieve 6111 TT Equity data, have something wrong
# retrieve FDEV LN Equity data, have something wrong
# retrieve TOBII SS Equity data, have something wrong
# retrieve 3546 TT Equity data, have something wrong
# retrieve NOD NO Equity data, have something wrong
# retrieve ROVIO FH Equity data, have something wrong
# retrieve FUNCOM NO Equity data, have something wrong
# retrieve TRPXX US Equity data, have something wrong
# retrieve 3903 JP Equity data, have something wrong
# retrieve 095660 KS Equity data, have something wrong
# retrieve 3810 JP Equity data, have something wrong
# retrieve IMMR US Equity data, have something wrong
# retrieve KOPN US Equity data, have something wrong
# retrieve LBRDA US Equity data, have something wrong
# retrieve HSTM US Equity data, have something wrong
# retrieve DATA US Equity data, have something wrong
# retrieve CYBR US Equity data, have something wrong
# retrieve IDCC US Equity data, have something wrong
# retrieve FICO US Equity data, have something wrong
# retrieve TWLO US Equity data, have something wrong
# retrieve SEND US Equity data, have something wrong
# retrieve HUBS US Equity data, have something wrong
# retrieve BAND US Equity data, have something wrong
# retrieve NXGN US Equity data, have something wrong
# retrieve MANH US Equity data, have something wrong
# retrieve SABR US Equity data, have something wrong
# retrieve ALTR US Equity data, have something wrong
# retrieve EPAY US Equity data, have something wrong
# retrieve SCWX US Equity data, have something wrong
# retrieve VMW US Equity data, have something wrong
# retrieve GOOGL US Equity data, have something wrong
# retrieve TDC US Equity data, have something wrong
# retrieve OTEX CN Equity data, have something wrong
# retrieve SAP US Equity data, have something wrong
# retrieve WIT US Equity data, have something wrong
# retrieve CHKP US Equity data, have something wrong
# retrieve NTCT US Equity data, have something wrong
# retrieve IMPV US Equity data, have something wrong
# retrieve FEYE US Equity data, have something wrong
# retrieve 4704 JP Equity data, have something wrong
# retrieve SPLK US Equity data, have something wrong
# retrieve SAIC US Equity data, have something wrong
# retrieve QLYS US Equity data, have something wrong
# retrieve PFPT US Equity data, have something wrong
# retrieve CVLT US Equity data, have something wrong
# retrieve PANW US Equity data, have something wrong
# retrieve CACI US Equity data, have something wrong
# retrieve TENB US Equity data, have something wrong
# retrieve SAIL US Equity data, have something wrong
# retrieve SOPH LN Equity data, have something wrong
# retrieve 2326 JP Equity data, have something wrong
# retrieve ZS US Equity data, have something wrong
# retrieve GTO NA Equity data, have something wrong
# retrieve VRNT US Equity data, have something wrong
# retrieve BAH US Equity data, have something wrong
# retrieve QQ/ LN Equity data, have something wrong
# retrieve RPD US Equity data, have something wrong
# retrieve EVBG US Equity data, have something wrong
# retrieve RDWR US Equity data, have something wrong
# retrieve MANT US Equity data, have something wrong
# retrieve OSPN US Equity data, have something wrong
# retrieve LDOS US Equity data, have something wrong
# retrieve BA/ LN Equity data, have something wrong
# retrieve ULE LN Equity data, have something wrong
# retrieve 3692 JP Equity data, have something wrong
# retrieve VRNS US Equity data, have something wrong
# retrieve FSCT US Equity data, have something wrong
# retrieve CBLK US Equity data, have something wrong
# retrieve KEYW US Equity data, have something wrong
# retrieve ZIXI US Equity data, have something wrong
# retrieve 053800 KS Equity data, have something wrong
# retrieve ATEN US Equity data, have something wrong
# retrieve MOBL US Equity data, have something wrong
# retrieve NCC LN Equity data, have something wrong
# retrieve FSC1V FH Equity data, have something wrong
# retrieve TSM US Equity data, have something wrong
# retrieve NXPI US Equity data, have something wrong
# retrieve ASML US Equity data, have something wrong
# retrieve MRVL US Equity data, have something wrong
# retrieve ON US Equity data, have something wrong
# retrieve IDTI US Equity data, have something wrong
# retrieve TER US Equity data, have something wrong
# retrieve MPWR US Equity data, have something wrong
# retrieve MLNX US Equity data, have something wrong
# retrieve CY US Equity data, have something wrong
# retrieve CREE US Equity data, have something wrong
# retrieve ENTG US Equity data, have something wrong
# retrieve SLAB US Equity data, have something wrong
# retrieve MKSI US Equity data, have something wrong
# retrieve STM US Equity data, have something wrong
# retrieve OLED US Equity data, have something wrong
# retrieve JNJ US Equity data, have something wrong
# retrieve PFE US Equity data, have something wrong
# retrieve UNH US Equity data, have something wrong
# retrieve MRK US Equity data, have something wrong
# retrieve ABBV US Equity data, have something wrong
# retrieve MDT US Equity data, have something wrong
# retrieve AMGN US Equity data, have something wrong
# retrieve ABT US Equity data, have something wrong
# retrieve LLY US Equity data, have something wrong
# retrieve TMO US Equity data, have something wrong
# retrieve CVS US Equity data, have something wrong
# retrieve GILD US Equity data, have something wrong
# retrieve BMY US Equity data, have something wrong
# retrieve ANTM US Equity data, have something wrong
# retrieve BIIB US Equity data, have something wrong
# retrieve DHR US Equity data, have something wrong
# retrieve BDX US Equity data, have something wrong
# retrieve ISRG US Equity data, have something wrong
# retrieve ESRX US Equity data, have something wrong
# retrieve SYK US Equity data, have something wrong
# retrieve CI US Equity data, have something wrong
# retrieve CELG US Equity data, have something wrong
# retrieve AGN US Equity data, have something wrong
# retrieve BSX US Equity data, have something wrong
# retrieve ILMN US Equity data, have something wrong
# retrieve VRTX US Equity data, have something wrong
# retrieve HUM US Equity data, have something wrong
# retrieve ZTS US Equity data, have something wrong
# retrieve HCA US Equity data, have something wrong
# retrieve EW US Equity data, have something wrong
# retrieve BAX US Equity data, have something wrong
# retrieve REGN US Equity data, have something wrong
# retrieve CNC US Equity data, have something wrong
# retrieve ALXN US Equity data, have something wrong
# retrieve MCK US Equity data, have something wrong
# retrieve ZBH US Equity data, have something wrong
# retrieve A US Equity data, have something wrong
# retrieve IQV US Equity data, have something wrong
# retrieve CERN US Equity data, have something wrong
# retrieve IDXX US Equity data, have something wrong
# retrieve RMD US Equity data, have something wrong
# retrieve ALGN US Equity data, have something wrong
# retrieve MYL US Equity data, have something wrong
# retrieve CAH US Equity data, have something wrong
# retrieve MTD US Equity data, have something wrong
# retrieve WAT US Equity data, have something wrong
# retrieve LH US Equity data, have something wrong
# retrieve ABMD US Equity data, have something wrong
# retrieve ABC US Equity data, have something wrong
# retrieve HSIC US Equity data, have something wrong
# retrieve COO US Equity data, have something wrong
# retrieve WCG US Equity data, have something wrong
# retrieve DGX US Equity data, have something wrong
# retrieve INCY US Equity data, have something wrong
# retrieve GVMXX US Equity data, have something wrong
# retrieve HOLX US Equity data, have something wrong
# retrieve VAR US Equity data, have something wrong
# retrieve UHS US Equity data, have something wrong
# retrieve PKI US Equity data, have something wrong
# retrieve XRAY US Equity data, have something wrong
# retrieve DVA US Equity data, have something wrong
# retrieve PRGO US Equity data, have something wrong
# retrieve NKTR US Equity data, have something wrong
# retrieve BMRN US Equity data, have something wrong
# retrieve SHPG US Equity data, have something wrong
# retrieve SGEN US Equity data, have something wrong
# retrieve JAZZ US Equity data, have something wrong
# retrieve SRPT US Equity data, have something wrong
# retrieve ALNY US Equity data, have something wrong
# retrieve IONS US Equity data, have something wrong
# retrieve NBIX US Equity data, have something wrong
# retrieve PRAH US Equity data, have something wrong
# retrieve EXEL US Equity data, have something wrong
# retrieve TECH US Equity data, have something wrong
# retrieve BLUE US Equity data, have something wrong
# retrieve ALKS US Equity data, have something wrong
# retrieve BGNE US Equity data, have something wrong
# retrieve SAGE US Equity data, have something wrong
# retrieve UTHR US Equity data, have something wrong
# retrieve AMRN US Equity data, have something wrong
# retrieve SYNH US Equity data, have something wrong
# retrieve LOXO US Equity data, have something wrong
# retrieve TSRO US Equity data, have something wrong
# retrieve IMMU US Equity data, have something wrong
# retrieve ARRY US Equity data, have something wrong
# retrieve FGEN US Equity data, have something wrong
# retrieve HZNP US Equity data, have something wrong
# retrieve NVCR US Equity data, have something wrong
# retrieve ICPT US Equity data, have something wrong
# retrieve GWPH US Equity data, have something wrong
# retrieve AGIO US Equity data, have something wrong
# retrieve LGND US Equity data, have something wrong
# retrieve CBPO US Equity data, have something wrong
# retrieve AKCA US Equity data, have something wrong
# retrieve GRFS US Equity data, have something wrong
# retrieve ASND US Equity data, have something wrong
# retrieve RGEN US Equity data, have something wrong
# retrieve GHDX US Equity data, have something wrong
# retrieve BPMC US Equity data, have something wrong
# retrieve RARE US Equity data, have something wrong
# retrieve ENDP US Equity data, have something wrong
# retrieve MYGN US Equity data, have something wrong
# retrieve ACAD US Equity data, have something wrong
# retrieve GBT US Equity data, have something wrong
# retrieve HALO US Equity data, have something wrong
# retrieve MYOK US Equity data, have something wrong
# retrieve XLRN US Equity data, have something wrong
# retrieve ARNA US Equity data, have something wrong
# retrieve XNCR US Equity data, have something wrong
# retrieve FOLD US Equity data, have something wrong
# retrieve ECYT US Equity data, have something wrong
# retrieve MEDP US Equity data, have something wrong
# retrieve ATRA US Equity data, have something wrong
# retrieve SUPN US Equity data, have something wrong
# retrieve PCRX US Equity data, have something wrong
# retrieve OPK US Equity data, have something wrong
# retrieve ANAB US Equity data, have something wrong
# retrieve ZGNX US Equity data, have something wrong
# retrieve AERI US Equity data, have something wrong
# retrieve INVA US Equity data, have something wrong
# retrieve PTCT US Equity data, have something wrong
# retrieve IRWD US Equity data, have something wrong
# retrieve RGNX US Equity data, have something wrong
# retrieve CRSP US Equity data, have something wrong
# retrieve ONCE US Equity data, have something wrong
# retrieve TBPH US Equity data, have something wrong
# retrieve ENTA US Equity data, have something wrong
# retrieve RETA US Equity data, have something wrong
# retrieve MDCO US Equity data, have something wrong
# retrieve VNDA US Equity data, have something wrong
# retrieve EDIT US Equity data, have something wrong
# retrieve AIMT US Equity data, have something wrong
# retrieve ESPR US Equity data, have something wrong
# retrieve ARWR US Equity data, have something wrong
# retrieve PTLA US Equity data, have something wrong
# retrieve SPPI US Equity data, have something wrong
# retrieve SGMO US Equity data, have something wrong
# retrieve IOVA US Equity data, have something wrong
# retrieve LMNX US Equity data, have something wrong
# retrieve GTHX US Equity data, have something wrong
# retrieve INSM US Equity data, have something wrong
# retrieve PACB US Equity data, have something wrong
# retrieve GLPG US Equity data, have something wrong
# retrieve CLVS US Equity data, have something wrong
# retrieve QURE US Equity data, have something wrong
# retrieve BOLD US Equity data, have something wrong
# retrieve RTRX US Equity data, have something wrong
# retrieve AMPH US Equity data, have something wrong
# retrieve NVAX US Equity data, have something wrong
# retrieve TXMD US Equity data, have something wrong
# retrieve BCRX US Equity data, have something wrong
# retrieve MNTA US Equity data, have something wrong
# retrieve BRIXX US Equity data, have something wrong
# retrieve PBYI US Equity data, have something wrong
# retrieve ATNX US Equity data, have something wrong
# retrieve IMGN US Equity data, have something wrong
# retrieve LXRX US Equity data, have something wrong
# retrieve ACOR US Equity data, have something wrong
# retrieve ALDR US Equity data, have something wrong
# retrieve CERS US Equity data, have something wrong
# retrieve ITCI US Equity data, have something wrong
# retrieve RVNC US Equity data, have something wrong
# retrieve RDUS US Equity data, have something wrong
# retrieve NTLA US Equity data, have something wrong
# retrieve CTMX US Equity data, have something wrong
# retrieve EGRX US Equity data, have something wrong
# retrieve CHRS US Equity data, have something wrong
# retrieve OMER US Equity data, have something wrong
# retrieve PETQ US Equity data, have something wrong
# retrieve ANIP US Equity data, have something wrong
# retrieve COLL US Equity data, have something wrong
# retrieve KPTI US Equity data, have something wrong
# retrieve AMAG US Equity data, have something wrong
# retrieve MGNX US Equity data, have something wrong
# retrieve CARA US Equity data, have something wrong
# retrieve KURA US Equity data, have something wrong
# retrieve RARX US Equity data, have something wrong
# retrieve AUP CN Equity data, have something wrong
# retrieve CCXI US Equity data, have something wrong
# retrieve FLXN US Equity data, have something wrong
# retrieve NSTG US Equity data, have something wrong
# retrieve VCYT US Equity data, have something wrong
# retrieve PRTA US Equity data, have something wrong
# retrieve EPZM US Equity data, have something wrong
# retrieve RIGL US Equity data, have something wrong
# retrieve GLYC US Equity data, have something wrong
# retrieve INO US Equity data, have something wrong
# retrieve AKBA US Equity data, have something wrong
# retrieve ACHN US Equity data, have something wrong
# retrieve CYTK US Equity data, have something wrong
# retrieve PDLI US Equity data, have something wrong
# retrieve DOVA US Equity data, have something wrong
# retrieve DERM US Equity data, have something wrong
# retrieve DBVT US Equity data, have something wrong
# retrieve PGNX US Equity data, have something wrong
# retrieve CRBP US Equity data, have something wrong
# retrieve INSY US Equity data, have something wrong
# retrieve FPRX US Equity data, have something wrong
# retrieve ADAP US Equity data, have something wrong
# retrieve VYGR US Equity data, have something wrong
# retrieve CLXT US Equity data, have something wrong
# retrieve CNCE US Equity data, have something wrong
# retrieve NERV US Equity data, have something wrong
# retrieve CLLS US Equity data, have something wrong
# retrieve PETX US Equity data, have something wrong
# retrieve ACRS US Equity data, have something wrong
# retrieve SVRA US Equity data, have something wrong
# retrieve MCRB US Equity data, have something wrong
# retrieve ASRT US Equity data, have something wrong
# retrieve MNKD US Equity data, have something wrong
# retrieve ADMS US Equity data, have something wrong
# retrieve GERN US Equity data, have something wrong
# retrieve ABUS US Equity data, have something wrong
# retrieve FOMX US Equity data, have something wrong
# retrieve ADRO US Equity data, have something wrong
# retrieve SBBP US Equity data, have something wrong
# retrieve PRTK US Equity data, have something wrong
# retrieve TOCA US Equity data, have something wrong
# retrieve KALA US Equity data, have something wrong
# retrieve CALA US Equity data, have something wrong
# retrieve BLCM US Equity data, have something wrong
# retrieve CMRX US Equity data, have something wrong
# retrieve CRVS US Equity data, have something wrong
# retrieve MRNS US Equity data, have something wrong
# retrieve ARDX US Equity data, have something wrong
# retrieve NBRV US Equity data, have something wrong
# retrieve AXON US Equity data, have something wrong
# retrieve JNCE US Equity data, have something wrong
# retrieve SNDX US Equity data, have something wrong
# retrieve MRSN US Equity data, have something wrong
# retrieve NK US Equity data, have something wrong
# retrieve AVDL US Equity data, have something wrong
# retrieve TLGT US Equity data, have something wrong
# retrieve TTPH US Equity data, have something wrong
# retrieve AKAO US Equity data, have something wrong
# retrieve SNNA US Equity data, have something wrong
# retrieve NH US Equity data, have something wrong
# retrieve NEOS US Equity data, have something wrong
# retrieve NLNK US Equity data, have something wrong
# retrieve CLDX US Equity data, have something wrong
# retrieve CRIS US Equity data, have something wrong
# retrieve SGYP US Equity data, have something wrong
# retrieve VTL US Equity data, have something wrong
# retrieve BA US Equity data, have something wrong
# retrieve UTX US Equity data, have something wrong
# retrieve LMT US Equity data, have something wrong
# retrieve RTN US Equity data, have something wrong
# retrieve GD US Equity data, have something wrong
# retrieve NOC US Equity data, have something wrong
# retrieve TDG US Equity data, have something wrong
# retrieve HRS US Equity data, have something wrong
# retrieve LLL US Equity data, have something wrong
# retrieve TXT US Equity data, have something wrong
# retrieve ARNC US Equity data, have something wrong
# retrieve HII US Equity data, have something wrong
# retrieve SPR US Equity data, have something wrong
# retrieve TDY US Equity data, have something wrong
# retrieve ESL US Equity data, have something wrong
# retrieve HXL US Equity data, have something wrong
# retrieve HEI/A US Equity data, have something wrong
# retrieve CW US Equity data, have something wrong
# retrieve nan data, have something wrong
# retrieve HEI US Equity data, have something wrong
# retrieve BWXT US Equity data, have something wrong
# retrieve AJRD US Equity data, have something wrong
# retrieve MOG/A US Equity data, have something wrong
# retrieve MRCY US Equity data, have something wrong
# retrieve AAXN US Equity data, have something wrong
# retrieve CUB US Equity data, have something wrong
# retrieve KTOS US Equity data, have something wrong
# retrieve AIR US Equity data, have something wrong
# retrieve AVAV US Equity data, have something wrong
# retrieve RGR US Equity data, have something wrong
# retrieve ATRO US Equity data, have something wrong
# retrieve NPK US Equity data, have something wrong
# retrieve AOBC US Equity data, have something wrong
# retrieve EGL US Equity data, have something wrong
# retrieve WAIR US Equity data, have something wrong
# retrieve TGI US Equity data, have something wrong
# retrieve PG US Equity data, have something wrong
# retrieve KO US Equity data, have something wrong
# retrieve PEP US Equity data, have something wrong
# retrieve WMT US Equity data, have something wrong
# retrieve PM US Equity data, have something wrong
# retrieve WBA US Equity data, have something wrong
# retrieve MDLZ US Equity data, have something wrong
# retrieve COST US Equity data, have something wrong
# retrieve MO US Equity data, have something wrong
# retrieve CL US Equity data, have something wrong
# retrieve KMB US Equity data, have something wrong
# retrieve SYY US Equity data, have something wrong
# retrieve STZ US Equity data, have something wrong
# retrieve EL US Equity data, have something wrong
# retrieve KHC US Equity data, have something wrong
# retrieve ADM US Equity data, have something wrong
# retrieve KR US Equity data, have something wrong
# retrieve GIS US Equity data, have something wrong
# retrieve MNST US Equity data, have something wrong
# retrieve CLX US Equity data, have something wrong
# retrieve MKC US Equity data, have something wrong
# retrieve CHD US Equity data, have something wrong
# retrieve TSN US Equity data, have something wrong
# retrieve K US Equity data, have something wrong
# retrieve HSY US Equity data, have something wrong
# retrieve CAG US Equity data, have something wrong
# retrieve HRL US Equity data, have something wrong
# retrieve TAP US Equity data, have something wrong
# retrieve SJM US Equity data, have something wrong
# retrieve LW US Equity data, have something wrong
# retrieve BF/B US Equity data, have something wrong
# retrieve CPB US Equity data, have something wrong
# retrieve HD US Equity data, have something wrong
# retrieve MCD US Equity data, have something wrong
# retrieve NKE US Equity data, have something wrong
# retrieve SBUX US Equity data, have something wrong
# retrieve LOW US Equity data, have something wrong
# retrieve TJX US Equity data, have something wrong
# retrieve GM US Equity data, have something wrong
# retrieve TGT US Equity data, have something wrong
# retrieve F US Equity data, have something wrong
# retrieve MAR US Equity data, have something wrong
# retrieve ROST US Equity data, have something wrong
# retrieve YUM US Equity data, have something wrong
# retrieve ORLY US Equity data, have something wrong
# retrieve DG US Equity data, have something wrong
# retrieve VFC US Equity data, have something wrong
# retrieve CCL US Equity data, have something wrong
# retrieve AZO US Equity data, have something wrong
# retrieve HLT US Equity data, have something wrong
# retrieve DLTR US Equity data, have something wrong
# retrieve RCL US Equity data, have something wrong
# retrieve APTV US Equity data, have something wrong
# retrieve GPC US Equity data, have something wrong
# retrieve ULTA US Equity data, have something wrong
# retrieve MGM US Equity data, have something wrong
# retrieve BBY US Equity data, have something wrong
# retrieve DRI US Equity data, have something wrong
# retrieve DHI US Equity data, have something wrong
# retrieve AAP US Equity data, have something wrong
# retrieve LEN US Equity data, have something wrong
# retrieve CMG US Equity data, have something wrong
# retrieve KMX US Equity data, have something wrong
# retrieve TSCO US Equity data, have something wrong
# retrieve NCLH US Equity data, have something wrong
# retrieve WYNN US Equity data, have something wrong
# retrieve KSS US Equity data, have something wrong
# retrieve TPR US Equity data, have something wrong
# retrieve HAS US Equity data, have something wrong
# retrieve NWL US Equity data, have something wrong
# retrieve M US Equity data, have something wrong
# retrieve TIF US Equity data, have something wrong
# retrieve LKQ US Equity data, have something wrong
# retrieve GRMN US Equity data, have something wrong
# retrieve MHK US Equity data, have something wrong
# retrieve WHR US Equity data, have something wrong
# retrieve BWA US Equity data, have something wrong
# retrieve PVH US Equity data, have something wrong
# retrieve LB US Equity data, have something wrong
# retrieve PHM US Equity data, have something wrong
# retrieve KORS US Equity data, have something wrong
# retrieve HOG US Equity data, have something wrong
# retrieve RL US Equity data, have something wrong
# retrieve FL US Equity data, have something wrong
# retrieve GPS US Equity data, have something wrong
# retrieve JWN US Equity data, have something wrong
# retrieve HRB US Equity data, have something wrong
# retrieve GT US Equity data, have something wrong
# retrieve LEG US Equity data, have something wrong
# retrieve HBI US Equity data, have something wrong
# retrieve MAT US Equity data, have something wrong
# retrieve UAA US Equity data, have something wrong
# retrieve UA US Equity data, have something wrong
# retrieve CME US Equity data, have something wrong
# retrieve ICE US Equity data, have something wrong
# retrieve GS US Equity data, have something wrong
# retrieve MS US Equity data, have something wrong
# retrieve SCHW US Equity data, have something wrong
# retrieve AMTD US Equity data, have something wrong
# retrieve MKTX US Equity data, have something wrong
# retrieve CBOE US Equity data, have something wrong
# retrieve NDAQ US Equity data, have something wrong
# retrieve ETFC US Equity data, have something wrong
# retrieve RJF US Equity data, have something wrong
# retrieve LPLA US Equity data, have something wrong
# retrieve IBKR US Equity data, have something wrong
# retrieve LAZ US Equity data, have something wrong
# retrieve SF US Equity data, have something wrong
# retrieve VIRT US Equity data, have something wrong
# retrieve EVR US Equity data, have something wrong
# retrieve ITG US Equity data, have something wrong
# retrieve HLI US Equity data, have something wrong
# retrieve MC US Equity data, have something wrong
# retrieve PJC US Equity data, have something wrong
# retrieve BGCP US Equity data, have something wrong
# retrieve PJT US Equity data, have something wrong
# retrieve DHIL US Equity data, have something wrong
# retrieve INTL US Equity data, have something wrong
# retrieve COWN US Equity data, have something wrong
# retrieve GHL US Equity data, have something wrong
# retrieve XOM US Equity data, have something wrong
# retrieve CVX US Equity data, have something wrong
# retrieve COP US Equity data, have something wrong
# retrieve SLB US Equity data, have something wrong
# retrieve EOG US Equity data, have something wrong
# retrieve OXY US Equity data, have something wrong
# retrieve MPC US Equity data, have something wrong
# retrieve PSX US Equity data, have something wrong
# retrieve VLO US Equity data, have something wrong
# retrieve KMI US Equity data, have something wrong
# retrieve WMB US Equity data, have something wrong
# retrieve HAL US Equity data, have something wrong
# retrieve APC US Equity data, have something wrong
# retrieve CXO US Equity data, have something wrong
# retrieve OKE US Equity data, have something wrong
# retrieve PXD US Equity data, have something wrong
# retrieve FANG US Equity data, have something wrong
# retrieve HES US Equity data, have something wrong
# retrieve MRO US Equity data, have something wrong
# retrieve DVN US Equity data, have something wrong
# retrieve APA US Equity data, have something wrong
# retrieve LNG US Equity data, have something wrong
# retrieve NOV US Equity data, have something wrong
# retrieve BHGE US Equity data, have something wrong
# retrieve NBL US Equity data, have something wrong
# retrieve COG US Equity data, have something wrong
# retrieve HFC US Equity data, have something wrong
# retrieve TRGP US Equity data, have something wrong
# retrieve FTI US Equity data, have something wrong
# retrieve XEC US Equity data, have something wrong
# retrieve HP US Equity data, have something wrong
# retrieve WPX US Equity data, have something wrong
# retrieve MUR US Equity data, have something wrong
# retrieve PE US Equity data, have something wrong
# retrieve ETRN US Equity data, have something wrong
# retrieve EQT US Equity data, have something wrong
# retrieve PBF US Equity data, have something wrong
# retrieve CLR US Equity data, have something wrong
# retrieve RIG US Equity data, have something wrong
# retrieve CLB US Equity data, have something wrong
# retrieve RRC US Equity data, have something wrong
# retrieve TPL US Equity data, have something wrong
# retrieve NFX US Equity data, have something wrong
# retrieve PAGP US Equity data, have something wrong
# retrieve TGE US Equity data, have something wrong
# retrieve DK US Equity data, have something wrong
# retrieve PTEN US Equity data, have something wrong
# retrieve SWN US Equity data, have something wrong
# retrieve WLL US Equity data, have something wrong
# retrieve AR US Equity data, have something wrong
# retrieve CHK US Equity data, have something wrong
# retrieve APY US Equity data, have something wrong
# retrieve ESV US Equity data, have something wrong
# retrieve BTU US Equity data, have something wrong
# retrieve CDEV US Equity data, have something wrong
# retrieve MTDR US Equity data, have something wrong
# retrieve CNX US Equity data, have something wrong
# retrieve PDCE US Equity data, have something wrong
# retrieve SM US Equity data, have something wrong
# retrieve CPE US Equity data, have something wrong
# retrieve OAS US Equity data, have something wrong
# retrieve QEP US Equity data, have something wrong
# retrieve INT US Equity data, have something wrong
# retrieve RDC US Equity data, have something wrong
# retrieve OII US Equity data, have something wrong
# retrieve MDR US Equity data, have something wrong
# retrieve CRZO US Equity data, have something wrong
# retrieve ARCH US Equity data, have something wrong
# retrieve DRQ US Equity data, have something wrong
# retrieve SRCI US Equity data, have something wrong
# retrieve GPOR US Equity data, have something wrong
# retrieve AROC US Equity data, have something wrong
# retrieve KOS US Equity data, have something wrong
# retrieve OIS US Equity data, have something wrong
# retrieve PUMP US Equity data, have something wrong
# retrieve HLX US Equity data, have something wrong
# retrieve CVI US Equity data, have something wrong
# retrieve UNT US Equity data, have something wrong
# retrieve AMGP US Equity data, have something wrong
# retrieve SLCA US Equity data, have something wrong
# retrieve NBR US Equity data, have something wrong
# retrieve CRC US Equity data, have something wrong
# retrieve CJ US Equity data, have something wrong
# retrieve GTE US Equity data, have something wrong
# retrieve DNR US Equity data, have something wrong
# retrieve NE US Equity data, have something wrong
# retrieve SEMG US Equity data, have something wrong
# retrieve REGI US Equity data, have something wrong
# retrieve DO US Equity data, have something wrong
# retrieve EEQ US Equity data, have something wrong
# retrieve RES US Equity data, have something wrong
# retrieve SPN US Equity data, have something wrong
# retrieve CEIX US Equity data, have something wrong
# retrieve TDW US Equity data, have something wrong
# retrieve EXTN US Equity data, have something wrong
# retrieve ENLC US Equity data, have something wrong
# retrieve LPI US Equity data, have something wrong
# retrieve CKH US Equity data, have something wrong
# retrieve REN US Equity data, have something wrong
# retrieve NR US Equity data, have something wrong
# retrieve GPRE US Equity data, have something wrong
# retrieve JAG US Equity data, have something wrong
# retrieve TELL US Equity data, have something wrong
# retrieve XOG US Equity data, have something wrong
# retrieve FI US Equity data, have something wrong
# retrieve WFT US Equity data, have something wrong
# retrieve PVAC US Equity data, have something wrong
# retrieve WTI US Equity data, have something wrong
# retrieve MTRX US Equity data, have something wrong
# retrieve FRAC US Equity data, have something wrong
# retrieve PARR US Equity data, have something wrong
# retrieve FET US Equity data, have something wrong
# retrieve WRD US Equity data, have something wrong
# retrieve TALO US Equity data, have something wrong
# retrieve BCEI US Equity data, have something wrong
# retrieve REI US Equity data, have something wrong
# retrieve KLXE US Equity data, have something wrong
# retrieve REX US Equity data, have something wrong
# retrieve HPR US Equity data, have something wrong
# retrieve INSW US Equity data, have something wrong
# retrieve HK US Equity data, have something wrong
# retrieve NINE US Equity data, have something wrong
# retrieve CLNE US Equity data, have something wrong
# retrieve SMHI US Equity data, have something wrong
# retrieve TTI US Equity data, have something wrong
# retrieve RNET US Equity data, have something wrong
# retrieve TUSK US Equity data, have something wrong
# retrieve SD US Equity data, have something wrong
# retrieve FTSI US Equity data, have something wrong
# retrieve UPL US Equity data, have something wrong
# retrieve CVIA US Equity data, have something wrong
# retrieve BRS US Equity data, have something wrong
# retrieve SBOW US Equity data, have something wrong
# retrieve NOG US Equity data, have something wrong
# retrieve MPO US Equity data, have something wrong
# retrieve ECR US Equity data, have something wrong
# retrieve BAS US Equity data, have something wrong
# retrieve NCSM US Equity data, have something wrong
# retrieve SN US Equity data, have something wrong
# retrieve KEG US Equity data, have something wrong
# retrieve EGN US Equity data, have something wrong
# retrieve JONE US Equity data, have something wrong
# retrieve SND US Equity data, have something wrong
# retrieve DWDP US Equity data, have something wrong
# retrieve LIN US Equity data, have something wrong
# retrieve ECL US Equity data, have something wrong
# retrieve SHW US Equity data, have something wrong
# retrieve APD US Equity data, have something wrong
# retrieve PPG US Equity data, have something wrong
# retrieve LYB US Equity data, have something wrong
# retrieve NEM US Equity data, have something wrong
# retrieve NUE US Equity data, have something wrong
# retrieve IP US Equity data, have something wrong
# retrieve BLL US Equity data, have something wrong
# retrieve FCX US Equity data, have something wrong
# retrieve IFF US Equity data, have something wrong
# retrieve VMC US Equity data, have something wrong
# retrieve MLM US Equity data, have something wrong
# retrieve MOS US Equity data, have something wrong
# retrieve FMC US Equity data, have something wrong
# retrieve WRK US Equity data, have something wrong
# retrieve EMN US Equity data, have something wrong
# retrieve CF US Equity data, have something wrong
# retrieve ALB US Equity data, have something wrong
# retrieve PKG US Equity data, have something wrong
# retrieve AVY US Equity data, have something wrong
# retrieve SEE US Equity data, have something wrong
#
# retrieve data cost time: 846.3338306120004

# %%
df = pd.DataFrame()
start = '20100101'
end = '20190110'
fields = ['HIGH', 'OPEN', 'LOW', 'CLOSE', 'VOLUME', 'PX_LAST']
cols = ['High', 'Open', 'Low', 'Close', 'Volume', 'Adj Close']
code = ticker_list[0]
temp_df = temp_df.loc[:, i]
temp_df.columns = cols
temp_df = con.bdh(code, fields, start, end)
df = pd.concat([df, temp_df], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e4b465d0433c> in <module>()
#       5 cols = ['High', 'Open', 'Low', 'Close', 'Volume', 'Adj Close']
#       6 code = ticker_list[0]
# ----> 7 temp_df = temp_df.loc[:, i]
#       8 temp_df.columns = cols
#       9 temp_df = con.bdh(code, fields, start, end)
#
# NameError: name 'temp_df' is not defined

# %%
df = pd.DataFrame()
start = '20100101'
end = '20190110'
fields = ['HIGH', 'OPEN', 'LOW', 'CLOSE', 'VOLUME', 'PX_LAST']
cols = ['High', 'Open', 'Low', 'Close', 'Volume', 'Adj Close']
code = ticker_list[0]
temp_df = con.bdh(code, fields, start, end)
temp_df = temp_df.loc[:, i]
temp_df.columns = cols
df = pd.concat([df, temp_df], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9bd9d9811b9b> in <module>()
#       5 cols = ['High', 'Open', 'Low', 'Close', 'Volume', 'Adj Close']
#       6 code = ticker_list[0]
# ----> 7 temp_df = con.bdh(code, fields, start, end)
#       8 temp_df = temp_df.loc[:, i]
#       9 temp_df.columns = cols
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdblp\pdblp.py in bdh(self, tickers, flds, start_date, end_date, elms, ovrds, longdata)
#     259
#     260         data = self._bdh_list(tickers, flds, start_date, end_date,
# --> 261                               elms, ovrds)
#     262
#     263         df = pd.DataFrame(data, columns=["date", "ticker", "field", "value"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pdblp\pdblp.py in _bdh_list(self, tickers, flds, start_date, end_date, elms, ovrds)
#     296                                    .numValues() > 0)
#     297             if has_security_error or has_field_exception:
# --> 298                 raise ValueError(msg)
#     299             ticker = (msg.getElement('securityData')
#     300                       .getElement('security').getValue())
#
# ValueError: HistoricalDataResponse = {
#     securityData = {
#         security = "MSFT US Equity"
#         eidData[] = {
#         }
#         sequenceNumber = 0
#         fieldExceptions[] = {
#             fieldExceptions = {
#                 fieldId = "CLOSE"
#                 errorInfo = {
#                     source = "3922::bbdbh4"
#                     code = 1
#                     category = "BAD_FLD"
#                     message = "Invalid field"
#                     subcategory = "NOT_APPLICABLE_TO_HIST_DATA"
#                 }
#             }
#         }
#         fieldData[] = {
#             fieldData = {
#                 date = 2010-01-04
#                 HIGH = 24.840700
#                 OPEN = 24.457300
#                 LOW = 24.433400
#                 VOLUME = 38414185.000000
#                 PX_LAST = 24.720900
#             }
#             fieldData = {
#                 date = 2010-01-05
#                 HIGH = 24.840700
#                 OPEN = 24.641000
#                 LOW = 24.473300
#                 VOLUME = 49758862.000000
#                 PX_LAST = 24.728900
#             }
#             fieldData = {
#                 date = 2010-01-06
#                 HIGH = 24.824700
#                 OPEN = 24.665000
#                 LOW = 24.377500
#                 VOLUME = 58182332.000000
#                 PX_LAST = 24.577100
#             }
#             fieldData = {
#                 date = 2010-01-07
#                 HIGH = 24.521200
#                 OPEN = 24.465300
#                 LOW = 24.113900
#                 VOLUME = 50564285.000000
#                 PX_LAST = 24.323100
#             }
#             fieldData = {
#                 date = 2010-01-08
#                 HIGH = 24.665000
#                 OPEN = 24.185800
#                 LOW = 24.153800
#                 VOLUME = 51201289.000000
#                 PX_LAST = 24.489300
#             }
#             fieldData = {
#                 date = 2010-01-11
#                 HIGH = 24.569100
#                 OPEN = 24.529200
#                 LOW = 24.058000
#                 VOLUME = 68754648.000000
#                 PX_LAST = 24.177800
#             }
#             fieldData = {
#                 date = 2010-01-12
#                 HIGH = 24.281600
#                 OPEN = 24.081900
#                 LOW = 23.890200
#                 VOLUME = 65913228.000000
#                 PX_LAST = 24.018000
#             }
#             fieldData = {
#                 date = 2010-01-13
#                 HIGH = 24.377500
#                 OPEN = 24.169800
#                 LOW = 23.970100
#                 VOLUME = 51863463.000000
#                 PX_LAST = 24.241700
#             }
#             fieldData = {
#                 date = 2010-01-14
#                 HIGH = 24.840700
#                 OPEN = 24.209700
#                 LOW = 24.169800
#                 VOLUME = 63244767.000000
#                 PX_LAST = 24.728900
#             }
#             fieldData = {
#                 date = 2010-01-15
#                 HIGH = 24.952500
#                 OPEN = 24.824700
#                 LOW = 24.529200
#                 VOLUME = 79915648.000000
#                 PX_LAST = 24.649000
#             }
#             fieldData = {
#                 date = 2010-01-19
#                 HIGH = 24.952500
#                 OPEN = 24.561200
#                 LOW = 24.505300
#                 VOLUME = 46582886.000000
#                 PX_LAST = 24.840700
#             }
#             fieldData = {
#                 date = 2010-01-20
#                 HIGH = 24.712900
#                 OPEN = 24.609100
#                 LOW = 24.209700
#                 VOLUME = 54857912.000000
#                 PX_LAST = 24.429400
#             }
#             fieldData = {
#                 date = 2010-01-21
#                 HIGH = 24.537200
#                 OPEN = 24.449300
#                 LOW = 23.962100
#                 VOLUME = 73086701.000000
#                 PX_LAST = 23.970100
#             }
#             fieldData = {
#                 date = 2010-01-22
#                 HIGH = 24.121900
#                 OPEN = 23.962100
#                 LOW = 23.035600
#                 VOLUME = 102004573.000000
#                 PX_LAST = 23.131400
#             }
#             fieldData = {
#                 date = 2010-01-25
#                 HIGH = 23.690500
#                 OPEN = 23.355100
#                 LOW = 23.243200
#                 VOLUME = 63381173.000000
#                 PX_LAST = 23.419000
#             }
#             fieldData = {
#                 date = 2010-01-26
#                 HIGH = 23.842300
#                 OPEN = 23.323100
#                 LOW = 23.235300
#                 VOLUME = 66647676.000000
#                 PX_LAST = 23.562700
#             }
#             fieldData = {
#                 date = 2010-01-27
#                 HIGH = 23.818300
#                 OPEN = 23.442900
#                 LOW = 23.179300
#                 VOLUME = 63949492.000000
#                 PX_LAST = 23.698500
#             }
#             fieldData = {
#                 date = 2010-01-28
#                 HIGH = 23.858300
#                 OPEN = 23.834300
#                 LOW = 23.075500
#                 VOLUME = 117513692.000000
#                 PX_LAST = 23.291200
#             }
#             fieldData = {
#                 date = 2010-01-29
#                 HIGH = 23.898200
#                 OPEN = 23.882200
#                 LOW = 22.093100
#                 VOLUME = 193888424.000000
#                 PX_LAST = 22.508400
#             }
#             fieldData = {
#                 date = 2010-02-01
#                 HIGH = 22.748000
#                 OPEN = 22.676100
#                 LOW = 22.300700
#                 VOLUME = 85931099.000000
#                 PX_LAST = 22.692100
#             }
#             fieldData = {
#                 date = 2010-02-02
#                 HIGH = 22.764000
#                 OPEN = 22.660200
#                 LOW = 22.476500
#                 VOLUME = 54413654.000000
#                 PX_LAST = 22.732100
#             }
#             fieldData = {
#                 date = 2010-02-03
#                 HIGH = 22.995600
#                 OPEN = 22.572300
#                 LOW = 22.460500
#                 VOLUME = 61397848.000000
#                 PX_LAST = 22.867800
#             }
#             fieldData = {
#                 date = 2010-02-04
#                 HIGH = 22.764000
#                 OPEN = 22.668200
#                 LOW = 22.212900
#                 VOLUME = 77849968.000000
#                 PX_LAST = 22.236800
#             }
#             fieldData = {
#                 date = 2010-02-05
#                 HIGH = 22.588300
#                 OPEN = 22.364600
#                 LOW = 22.021200
#                 VOLUME = 80960063.000000
#                 PX_LAST = 22.380600
#             }
#             fieldData = {
#                 date = 2010-02-08
#                 HIGH = 22.428500
#                 OPEN = 22.372600
#                 LOW = 22.021200
#                 VOLUME = 52826474.000000
#                 PX_LAST = 22.141000
#             }
#             fieldData = {
#                 date = 2010-02-09
#                 HIGH = 22.636200
#                 OPEN = 22.340700
#                 LOW = 22.165000
#                 VOLUME = 59195742.000000
#                 PX_LAST = 22.372600
#             }
#             fieldData = {
#                 date = 2010-02-10
#                 HIGH = 22.556300
#                 OPEN = 22.388600
#                 LOW = 22.236800
#                 VOLUME = 48591246.000000
#                 PX_LAST = 22.356600
#             }
#             fieldData = {
#                 date = 2010-02-11
#                 HIGH = 22.684100
#                 OPEN = 22.308700
#                 LOW = 22.125000
#                 VOLUME = 65995913.000000
#                 PX_LAST = 22.460500
#             }
#             fieldData = {
#                 date = 2010-02-12
#                 HIGH = 22.412600
#                 OPEN = 22.212900
#                 LOW = 22.029200
#                 VOLUME = 81121515.000000
#                 PX_LAST = 22.308700
#             }
#             fieldData = {
#                 date = 2010-02-16
#                 HIGH = 22.766100
#                 OPEN = 22.573500
#                 LOW = 22.485300
#                 VOLUME = 51938098.000000
#                 PX_LAST = 22.750100
#             }
#             fieldData = {
#                 date = 2010-02-17
#                 HIGH = 22.990800
#                 OPEN = 22.894500
#                 LOW = 22.758100
#                 VOLUME = 45882842.000000
#                 PX_LAST = 22.942700
#             }
#             fieldData = {
#                 date = 2010-02-18
#                 HIGH = 23.295800
#                 OPEN = 22.942700
#                 LOW = 22.878500
#                 VOLUME = 42856501.000000
#                 PX_LAST = 23.246800
#             }
#             fieldData = {
#                 date = 2010-02-19
#                 HIGH = 23.207500
#                 OPEN = 23.103200
#                 LOW = 23.022900
#                 VOLUME = 44461634.000000
#                 PX_LAST = 23.087100
#             }
#             fieldData = {
#                 date = 2010-02-22
#                 HIGH = 23.223500
#                 OPEN = 23.143300
#                 LOW = 22.990800
#                 VOLUME = 36710350.000000
#                 PX_LAST = 23.055000
#             }
#             fieldData = {
#                 date = 2010-02-23
#                 HIGH = 23.135300
#                 OPEN = 23.014900
#                 LOW = 22.541400
#                 VOLUME = 52270044.000000
#                 PX_LAST = 22.734000
#             }
#             fieldData = {
#                 date = 2010-02-24
#                 HIGH = 23.103200
#                 OPEN = 22.886500
#                 LOW = 22.774200
#                 VOLUME = 43166875.000000
#                 PX_LAST = 22.974800
#             }
#             fieldData = {
#                 date = 2010-02-25
#                 HIGH = 22.990800
#                 OPEN = 22.685900
#                 LOW = 22.485300
#                 VOLUME = 48735294.000000
#                 PX_LAST = 22.950700
#             }
#             fieldData = {
#                 date = 2010-02-26
#                 HIGH = 23.151300
#                 OPEN = 22.990800
#                 LOW = 22.878500
#                 VOLUME = 40372889.000000
#                 PX_LAST = 23.006900
#             }
#             fieldData = {
#                 date = 2010-03-01
#                 HIGH = 23.311800
#                 OPEN = 23.087100
#                 LOW = 22.894500
#                 VOLUME = 43805302.000000
#                 PX_LAST = 23.287700
#             }
#             fieldData = {
#                 date = 2010-03-02
#                 HIGH = 23.512400
#                 OPEN = 23.335900
#                 LOW = 22.661800
#                 VOLUME = 93129838.000000
#                 PX_LAST = 22.838400
#             }
#             fieldData = {
#                 date = 2010-03-03
#                 HIGH = 22.958700
#                 OPEN = 22.878500
#                 LOW = 22.750100
#                 VOLUME = 48442081.000000
#                 PX_LAST = 22.838400
#             }
#             fieldData = {
#                 date = 2010-03-04
#                 HIGH = 22.990800
#                 OPEN = 22.838400
#                 LOW = 22.685900
#                 VOLUME = 42894184.000000
#                 PX_LAST = 22.974800
#             }
#             fieldData = {
#                 date = 2010-03-05
#                 HIGH = 23.014900
#                 OPEN = 22.998900
#                 LOW = 22.806300
#                 VOLUME = 56005054.000000
#                 PX_LAST = 22.940700
#             }
#             fieldData = {
#                 date = 2010-03-08
#                 HIGH = 23.215500
#                 OPEN = 22.886500
#                 LOW = 22.870500
#                 VOLUME = 39421396.000000
#                 PX_LAST = 22.974800
#             }
#             fieldData = {
#                 date = 2010-03-09
#                 HIGH = 23.360000
#                 OPEN = 22.918600
#                 LOW = 22.910600
#                 VOLUME = 50278457.000000
#                 PX_LAST = 23.111200
#             }
#             fieldData = {
#                 date = 2010-03-10
#                 HIGH = 23.360000
#                 OPEN = 23.159300
#                 LOW = 23.111200
#                 VOLUME = 44898608.000000
#                 PX_LAST = 23.247600
#             }
#             fieldData = {
#                 date = 2010-03-11
#                 HIGH = 23.424200
#                 OPEN = 23.183400
#                 LOW = 23.151300
#                 VOLUME = 35353651.000000
#                 PX_LAST = 23.416100
#             }
#             fieldData = {
#                 date = 2010-03-12
#                 HIGH = 23.576600
#                 OPEN = 23.528500
#                 LOW = 23.303800
#                 VOLUME = 31709321.000000
#                 PX_LAST = 23.488400
#             }
#             fieldData = {
#                 date = 2010-03-15
#                 HIGH = 23.568600
#                 OPEN = 23.416100
#                 LOW = 23.279700
#                 VOLUME = 37516750.000000
#                 PX_LAST = 23.504400
#             }
#             fieldData = {
#                 date = 2010-03-16
#                 HIGH = 23.664900
#                 OPEN = 23.608700
#                 LOW = 23.432200
#                 VOLUME = 36730009.000000
#                 PX_LAST = 23.568600
#             }
#             fieldData = {
#                 date = 2010-03-17
#                 HIGH = 23.969800
#                 OPEN = 23.672900
#                 LOW = 23.592700
#                 VOLUME = 50386698.000000
#                 PX_LAST = 23.777200
#             }
#             fieldData = {
#                 date = 2010-03-18
#                 HIGH = 23.849500
#                 OPEN = 23.775200
#                 LOW = 23.672900
#                 VOLUME = 43845199.000000
#                 PX_LAST = 23.761200
#             }
#             fieldData = {
#                 date = 2010-03-19
#                 HIGH = 23.993900
#                 OPEN = 23.881600
#                 LOW = 23.552600
#                 VOLUME = 81341090.000000
#                 PX_LAST = 23.745100
#             }
#             fieldData = {
#                 date = 2010-03-22
#                 HIGH = 23.833400
#                 OPEN = 23.672900
#                 LOW = 23.584700
#                 VOLUME = 37709017.000000
#                 PX_LAST = 23.753200
#             }
#             fieldData = {
#                 date = 2010-03-23
#                 HIGH = 23.993900
#                 OPEN = 23.745100
#                 LOW = 23.600700
#                 VOLUME = 42026555.000000
#                 PX_LAST = 23.977900
#             }
#             fieldData = {
#                 date = 2010-03-24
#                 HIGH = 23.953800
#                 OPEN = 23.849500
#                 LOW = 23.753200
#                 VOLUME = 33993584.000000
#                 PX_LAST = 23.793300
#             }
#             fieldData = {
#                 date = 2010-03-25
#                 HIGH = 24.531600
#                 OPEN = 23.937700
#                 LOW = 23.913700
#                 VOLUME = 73176624.000000
#                 PX_LAST = 24.082200
#             }
#             fieldData = {
#                 date = 2010-03-26
#                 HIGH = 24.234700
#                 OPEN = 24.146400
#                 LOW = 23.745100
#                 VOLUME = 55604731.000000
#                 PX_LAST = 23.801300
#             }
#             fieldData = {
#                 date = 2010-03-29
#                 HIGH = 23.929700
#                 OPEN = 23.841400
#                 LOW = 23.713100
#                 VOLUME = 33340722.000000
#                 PX_LAST = 23.745100
#             }
#             fieldData = {
#                 date = 2010-03-30
#                 HIGH = 23.961800
#                 OPEN = 23.777200
#                 LOW = 23.672900
#                 VOLUME = 34955871.000000
#                 PX_LAST = 23.889600
#             }
#             fieldData = {
#                 date = 2010-03-31
#                 HIGH = 23.849500
#                 OPEN = 23.785300
#                 LOW = 23.408100
#                 VOLUME = 63762620.000000
#                 PX_LAST = 23.502400
#             }
#             fieldData = {
#                 date = 2010-04-01
#                 HIGH = 23.705000
#                 OPEN = 23.552600
#                 LOW = 22.966800
#                 VOLUME = 74768063.000000
#                 PX_LAST = 23.400100
#             }
#             fieldData = {
#                 date = 2010-04-05
#                 HIGH = 23.612700
#                 OPEN = 23.376000
#                 LOW = 23.295800
#                 VOLUME = 34338235.000000
#                 PX_LAST = 23.488400
#             }
#             fieldData = {
#                 date = 2010-04-06
#                 HIGH = 23.737100
#                 OPEN = 23.392100
#                 LOW = 23.255600
#                 VOLUME = 47366786.000000
#                 PX_LAST = 23.528500
#             }
#             fieldData = {
#                 date = 2010-04-07
#                 HIGH = 23.721100
#                 OPEN = 23.400100
#                 LOW = 23.384000
#                 VOLUME = 58320552.000000
#                 PX_LAST = 23.552600
#             }
#             fieldData = {
#                 date = 2010-04-08
#                 HIGH = 24.054100
#                 OPEN = 23.528500
#                 LOW = 23.512400
#                 VOLUME = 63713716.000000
#                 PX_LAST = 24.010000
#             }
#             fieldData = {
#                 date = 2010-04-09
#                 HIGH = 24.403200
#                 OPEN = 24.034000
#                 LOW = 23.989900
#                 VOLUME = 54755457.000000
#                 PX_LAST = 24.347000
#             }
#             fieldData = {
#                 date = 2010-04-12
#                 HIGH = 24.467400
#                 OPEN = 24.274800
#                 LOW = 24.238700
#                 VOLUME = 37074279.000000
#                 PX_LAST = 24.331000
#             }
#             fieldData = {
#                 date = 2010-04-13
#                 HIGH = 24.475400
#                 OPEN = 24.194500
#                 LOW = 24.178500
#                 VOLUME = 41369986.000000
#                 PX_LAST = 24.435300
#             }
#             fieldData = {
#                 date = 2010-04-14
#                 HIGH = 24.876600
#                 OPEN = 24.708100
#                 LOW = 24.603800
#                 VOLUME = 68942686.000000
#                 PX_LAST = 24.732200
#             }
#             fieldData = {
#                 date = 2010-04-15
#                 HIGH = 24.836500
#                 OPEN = 24.732200
#                 LOW = 24.643900
#                 VOLUME = 52748075.000000
#                 PX_LAST = 24.772300
#             }
#             fieldData = {
#                 date = 2010-04-16
#                 HIGH = 24.860600
#                 OPEN = 24.708100
#                 LOW = 24.555600
#                 VOLUME = 88707802.000000
#                 PX_LAST = 24.611800
#             }
#             fieldData = {
#                 date = 2010-04-19
#                 HIGH = 25.077300
#                 OPEN = 24.692100
#                 LOW = 24.684000
#                 VOLUME = 64970248.000000
#                 PX_LAST = 24.907900
#             }
#             fieldData = {
#                 date = 2010-04-20
#                 HIGH = 25.229700
#                 OPEN = 25.053200
#                 LOW = 24.981000
#                 VOLUME = 52206093.000000
#                 PX_LAST = 25.165500
#             }
#             fieldData = {
#                 date = 2010-04-21
#                 HIGH = 25.277900
#                 OPEN = 25.141500
#                 LOW = 25.061200
#                 VOLUME = 55343086.000000
#                 PX_LAST = 25.143100
#             }
#             fieldData = {
#                 date = 2010-04-22
#                 HIGH = 25.301900
#                 OPEN = 24.908700
#                 LOW = 24.796400
#                 VOLUME = 84847551.000000
#                 PX_LAST = 25.189600
#             }
#             fieldData = {
#                 date = 2010-04-23
#                 HIGH = 25.342100
#                 OPEN = 24.972900
#                 LOW = 24.595800
#                 VOLUME = 126766583.000000
#                 PX_LAST = 24.844500
#             }
#             fieldData = {
#                 date = 2010-04-26
#                 HIGH = 25.097300
#                 OPEN = 24.876600
#                 LOW = 24.764300
#                 VOLUME = 63652231.000000
#                 PX_LAST = 24.964900
#             }
#             fieldData = {
#                 date = 2010-04-27
#                 HIGH = 25.077300
#                 OPEN = 24.836500
#                 LOW = 24.675500
#                 VOLUME = 68732315.000000
#                 PX_LAST = 24.752300
#             }
#             fieldData = {
#                 date = 2010-04-28
#                 HIGH = 24.876600
#                 OPEN = 24.812400
#                 LOW = 24.571700
#                 VOLUME = 64557901.000000
#                 PX_LAST = 24.804400
#             }
#             fieldData = {
#                 date = 2010-04-29
#                 HIGH = 25.224400
#                 OPEN = 24.820500
#                 LOW = 24.611800
#                 VOLUME = 52671781.000000
#                 PX_LAST = 24.879000
#             }
#             fieldData = {
#                 date = 2010-04-30
#                 HIGH = 24.940800
#                 OPEN = 24.932800
#                 LOW = 24.491400
#                 VOLUME = 63220209.000000
#                 PX_LAST = 24.503500
#             }
#             fieldData = {
#                 date = 2010-05-03
#                 HIGH = 24.925300
#                 OPEN = 24.611800
#                 LOW = 24.539600
#                 VOLUME = 43990036.000000
#                 PX_LAST = 24.764300
#             }
#             fieldData = {
#                 date = 2010-05-04
#                 HIGH = 24.515500
#                 OPEN = 24.491400
#                 LOW = 23.873500
#                 VOLUME = 82085579.000000
#                 PX_LAST = 24.178500
#             }
#             fieldData = {
#                 date = 2010-05-05
#                 HIGH = 24.146400
#                 OPEN = 23.889600
#                 LOW = 23.825400
#                 VOLUME = 66833778.000000
#                 PX_LAST = 23.953800
#             }
#             fieldData = {
#                 date = 2010-05-06
#                 HIGH = 23.977900
#                 OPEN = 23.745100
#                 LOW = 22.397000
#                 VOLUME = 128612951.000000
#                 PX_LAST = 23.255600
#             }
#             fieldData = {
#                 date = 2010-05-07
#                 HIGH = 23.231600
#                 OPEN = 23.215500
#                 LOW = 21.923500
#                 VOLUME = 173718024.000000
#                 PX_LAST = 22.637700
#             }
#             fieldData = {
#                 date = 2010-05-10
#                 HIGH = 23.656900
#                 OPEN = 23.279700
#                 LOW = 23.039000
#                 VOLUME = 86656268.000000
#                 PX_LAST = 23.223500
#             }
#             fieldData = {
#                 date = 2010-05-11
#                 HIGH = 23.793300
#                 OPEN = 23.014900
#                 LOW = 22.926600
#                 VOLUME = 63803037.000000
#                 PX_LAST = 23.175400
#             }
#             fieldData = {
#                 date = 2010-05-12
#                 HIGH = 23.737100
#                 OPEN = 23.255600
#                 LOW = 23.207500
#                 VOLUME = 47152462.000000
#                 PX_LAST = 23.624800
#             }
#             fieldData = {
#                 date = 2010-05-13
#                 HIGH = 23.857500
#                 OPEN = 23.480300
#                 LOW = 23.416100
#                 VOLUME = 45291598.000000
#                 PX_LAST = 23.464300
#             }
#             fieldData = {
#                 date = 2010-05-14
#                 HIGH = 23.440200
#                 OPEN = 23.432200
#                 LOW = 22.982800
#                 VOLUME = 63333959.000000
#                 PX_LAST = 23.215500
#             }
#             fieldData = {
#                 date = 2010-05-17
#                 HIGH = 23.456300
#                 OPEN = 23.368000
#                 LOW = 22.830300
#                 VOLUME = 46055496.000000
#                 PX_LAST = 23.223500
#             }
#             fieldData = {
#                 date = 2010-05-18
#                 HIGH = 23.376700
#                 OPEN = 23.271900
#                 LOW = 22.893000
#                 VOLUME = 52772107.000000
#                 PX_LAST = 23.052200
#             }
#             fieldData = {
#                 date = 2010-05-19
#                 HIGH = 23.126800
#                 OPEN = 22.989800
#                 LOW = 22.401300
#                 VOLUME = 61754173.000000
#                 PX_LAST = 22.764100
#             }
#             fieldData = {
#                 date = 2010-05-20
#                 HIGH = 22.441600
#                 OPEN = 22.288500
#                 LOW = 21.796800
#                 VOLUME = 87991056.000000
#                 PX_LAST = 21.853200
#             }
#             fieldData = {
#                 date = 2010-05-21
#                 HIGH = 21.853200
#                 OPEN = 21.466300
#                 LOW = 21.313100
#                 VOLUME = 117600229.000000
#                 PX_LAST = 21.635500
#             }
#             fieldData = {
#                 date = 2010-05-24
#                 HIGH = 21.651700
#                 OPEN = 21.643600
#                 LOW = 21.168000
#                 VOLUME = 73712018.000000
#                 PX_LAST = 21.176100
#             }
#             fieldData = {
#                 date = 2010-05-25
#                 HIGH = 21.224400
#                 OPEN = 20.676300
#                 LOW = 20.458600
#                 VOLUME = 98373509.000000
#                 PX_LAST = 21.014800
#             }
#             fieldData = {
#                 date = 2010-05-26
#                 HIGH = 21.446100
#                 OPEN = 21.143800
#                 LOW = 19.797600
#                 VOLUME = 176684012.000000
#                 PX_LAST = 20.160400
#             }
#             fieldData = {
#                 date = 2010-05-27
#                 HIGH = 21.248600
#                 OPEN = 20.740800
#                 LOW = 20.736700
#                 VOLUME = 136434525.000000
#                 PX_LAST = 20.958400
#             }
#             fieldData = {
#                 date = 2010-05-28
#                 HIGH = 21.055200
#                 OPEN = 20.829400
#                 LOW = 20.684300
#                 VOLUME = 67502221.000000
#                 PX_LAST = 20.797200
#             }
#             fieldData = {
#                 date = 2010-06-01
#                 HIGH = 21.208300
#                 OPEN = 20.579600
#                 LOW = 20.571500
#                 VOLUME = 76155453.000000
#                 PX_LAST = 20.869700
#             }
#             fieldData = {
#                 date = 2010-06-02
#                 HIGH = 21.345300
#                 OPEN = 21.006800
#                 LOW = 20.740800
#                 VOLUME = 65718772.000000
#                 PX_LAST = 21.329200
#             }
#             fieldData = {
#                 date = 2010-06-03
#                 HIGH = 21.708100
#                 OPEN = 21.401800
#                 LOW = 21.288900
#                 VOLUME = 67839372.000000
#                 PX_LAST = 21.651700
#             }
#             fieldData = {
#                 date = 2010-06-04
#                 HIGH = 21.417900
#                 OPEN = 21.039000
#                 LOW = 20.652100
#                 VOLUME = 89833275.000000
#                 PX_LAST = 20.789100
#             }
#             fieldData = {
#                 date = 2010-06-07
#                 HIGH = 20.821400
#                 OPEN = 20.813300
#                 LOW = 20.345800
#                 VOLUME = 80456154.000000
#                 PX_LAST = 20.386100
#             }
#             fieldData = {
#                 date = 2010-06-08
#                 HIGH = 20.361900
#                 OPEN = 20.353800
#                 LOW = 19.870200
#                 VOLUME = 87354921.000000
#                 PX_LAST = 20.241000
#             }
#             fieldData = {
#                 date = 2010-06-09
#                 HIGH = 20.571500
#                 OPEN = 20.329700
#                 LOW = 19.950800
#                 VOLUME = 87808432.000000
#                 PX_LAST = 19.983000
#             }
#             fieldData = {
#                 date = 2010-06-10
#                 HIGH = 20.273200
#                 OPEN = 20.257100
#                 LOW = 19.975000
#                 VOLUME = 78950407.000000
#                 PX_LAST = 20.152300
#             }
#             fieldData = {
#                 date = 2010-06-11
#                 HIGH = 20.732700
#                 OPEN = 20.184600
#                 LOW = 19.966900
#                 VOLUME = 68057774.000000
#                 PX_LAST = 20.684300
#             }
#             fieldData = {
#                 date = 2010-06-14
#                 HIGH = 20.926200
#                 OPEN = 20.845600
#                 LOW = 20.531200
#                 VOLUME = 50972363.000000
#                 PX_LAST = 20.551300
#             }
#             fieldData = {
#                 date = 2010-06-15
#                 HIGH = 21.482400
#                 OPEN = 20.756900
#                 LOW = 20.748800
#                 VOLUME = 81644277.000000
#                 PX_LAST = 21.428000
#             }
#             fieldData = {
#                 date = 2010-06-16
#                 HIGH = 21.426000
#                 OPEN = 21.337300
#                 LOW = 21.143800
#                 VOLUME = 48699364.000000
#                 PX_LAST = 21.216400
#             }
#             fieldData = {
#                 date = 2010-06-17
#                 HIGH = 21.498500
#                 OPEN = 21.409800
#                 LOW = 20.990700
#                 VOLUME = 47998692.000000
#                 PX_LAST = 21.256700
#             }
#             fieldData = {
#                 date = 2010-06-18
#                 HIGH = 21.385600
#                 OPEN = 21.256700
#                 LOW = 21.095500
#                 VOLUME = 52079257.000000
#                 PX_LAST = 21.313100
#             }
#             fieldData = {
#                 date = 2010-06-21
#                 HIGH = 21.675800
#                 OPEN = 21.587200
#                 LOW = 20.869700
#                 VOLUME = 54625218.000000
#                 PX_LAST = 20.918100
#             }
#             fieldData = {
#                 date = 2010-06-22
#                 HIGH = 21.321200
#                 OPEN = 21.087400
#                 LOW = 20.765000
#                 VOLUME = 55986386.000000
#                 PX_LAST = 20.773000
#             }
#             fieldData = {
#                 date = 2010-06-23
#                 HIGH = 20.781100
#                 OPEN = 20.781100
#                 LOW = 20.329700
#                 VOLUME = 61468282.000000
#                 PX_LAST = 20.400600
#             }
#             fieldData = {
#                 date = 2010-06-24
#                 HIGH = 20.732700
#                 OPEN = 20.523100
#                 LOW = 20.095900
#                 VOLUME = 85252196.000000
#                 PX_LAST = 20.152300
#             }
#             fieldData = {
#                 date = 2010-06-25
#                 HIGH = 20.241000
#                 OPEN = 20.192600
#                 LOW = 19.596100
#                 VOLUME = 156256672.000000
#                 PX_LAST = 19.775500
#             }
#             fieldData = {
#                 date = 2010-06-28
#                 HIGH = 19.838000
#                 OPEN = 19.757300
#                 LOW = 19.443000
#                 VOLUME = 73787879.000000
#                 PX_LAST = 19.596100
#             }
#             fieldData = {
#                 date = 2010-06-29
#                 HIGH = 19.507500
#                 OPEN = 19.451000
#                 LOW = 18.628800
#                 VOLUME = 119885791.000000
#                 PX_LAST = 18.790000
#             }
#             fieldData = {
#                 date = 2010-06-30
#                 HIGH = 19.088300
#                 OPEN = 18.782000
#                 LOW = 18.499800
#                 VOLUME = 81057995.000000
#                 PX_LAST = 18.548200
#             }
#             fieldData = {
#                 date = 2010-07-01
#                 HIGH = 18.798100
#                 OPEN = 18.612700
#                 LOW = 18.322500
#                 VOLUME = 92239399.000000
#                 PX_LAST = 18.669100
#             }
#             fieldData = {
#                 date = 2010-07-02
#                 HIGH = 18.927100
#                 OPEN = 18.830300
#                 LOW = 18.580400
#                 VOLUME = 62489452.000000
#                 PX_LAST = 18.757800
#             }
#             fieldData = {
#                 date = 2010-07-06
#                 HIGH = 19.418800
#                 OPEN = 19.104400
#                 LOW = 19.010900
#                 VOLUME = 73594554.000000
#                 PX_LAST = 19.201100
#             }
#             fieldData = {
#                 date = 2010-07-07
#                 HIGH = 19.604200
#                 OPEN = 19.201100
#                 LOW = 19.031900
#                 VOLUME = 81967278.000000
#                 PX_LAST = 19.588100
#             }
#             fieldData = {
#                 date = 2010-07-08
#                 HIGH = 19.846000
#                 OPEN = 19.829900
#                 LOW = 19.323600
#                 VOLUME = 50768072.000000
#                 PX_LAST = 19.676300
#             }
#             fieldData = {
#                 date = 2010-07-09
#                 HIGH = 19.676700
#                 OPEN = 19.612200
#                 LOW = 19.467100
#                 VOLUME = 53811348.000000
#                 PX_LAST = 19.563900
#             }
#             fieldData = {
#                 date = 2010-07-12
#                 HIGH = 20.063700
#                 OPEN = 19.692900
#                 LOW = 19.684800
#                 VOLUME = 49862201.000000
#                 PX_LAST = 20.015300
#             }
#             fieldData = {
#                 date = 2010-07-13
#                 HIGH = 20.394200
#                 OPEN = 20.265200
#                 LOW = 20.071700
#                 VOLUME = 61928666.000000
#                 PX_LAST = 20.257100
#             }
#             fieldData = {
#                 date = 2010-07-14
#                 HIGH = 20.644000
#                 OPEN = 20.555400
#                 LOW = 20.249100
#                 VOLUME = 72808022.000000
#                 PX_LAST = 20.507000
#             }
#             fieldData = {
#                 date = 2010-07-15
#                 HIGH = 20.627900
#                 OPEN = 20.555400
#                 LOW = 20.136200
#                 VOLUME = 56934631.000000
#                 PX_LAST = 20.563400
#             }
#             fieldData = {
#                 date = 2010-07-16
#                 HIGH = 20.668200
#                 OPEN = 20.563400
#                 LOW = 20.055600
#                 VOLUME = 65064760.000000
#                 PX_LAST = 20.063700
#             }
#             fieldData = {
#                 date = 2010-07-19
#                 HIGH = 20.394200
#                 OPEN = 20.120100
#                 LOW = 20.079800
#                 VOLUME = 38181760.000000
#                 PX_LAST = 20.337700
#             }
#             fieldData = {
#                 date = 2010-07-20
#                 HIGH = 20.539300
#                 OPEN = 20.039500
#                 LOW = 19.910500
#                 VOLUME = 45530162.000000
#                 PX_LAST = 20.539300
#             }
#             fieldData = {
#                 date = 2010-07-21
#                 HIGH = 20.676300
#                 OPEN = 20.636000
#                 LOW = 20.132200
#                 VOLUME = 73297593.000000
#                 PX_LAST = 20.249100
#             }
#             fieldData = {
#                 date = 2010-07-22
#                 HIGH = 20.950400
#                 OPEN = 20.563400
#                 LOW = 20.531200
#                 VOLUME = 73016369.000000
#                 PX_LAST = 20.829400
#             }
#             fieldData = {
#                 date = 2010-07-23
#                 HIGH = 20.974500
#                 OPEN = 20.829400
#                 LOW = 20.353800
#                 VOLUME = 108520012.000000
#                 PX_LAST = 20.805300
#             }
#             fieldData = {
#                 date = 2010-07-26
#                 HIGH = 21.119600
#                 OPEN = 20.845600
#                 LOW = 20.797200
#                 VOLUME = 67249812.000000
#                 PX_LAST = 21.039000
#             }
#             fieldData = {
#                 date = 2010-07-27
#                 HIGH = 21.151900
#                 OPEN = 21.071300
#                 LOW = 20.926200
#                 VOLUME = 60682484.000000
#                 PX_LAST = 21.087400
#             }
#             fieldData = {
#                 date = 2010-07-28
#                 HIGH = 21.111600
#                 OPEN = 21.014800
#                 LOW = 20.821400
#                 VOLUME = 69704731.000000
#                 PX_LAST = 20.918100
#             }
#             fieldData = {
#                 date = 2010-07-29
#                 HIGH = 21.288900
#                 OPEN = 21.063200
#                 LOW = 20.636000
#                 VOLUME = 69446188.000000
#                 PX_LAST = 20.982600
#             }
#             fieldData = {
#                 date = 2010-07-30
#                 HIGH = 20.829400
#                 OPEN = 20.756900
#                 LOW = 20.434500
#                 VOLUME = 83534777.000000
#                 PX_LAST = 20.805300
#             }
#             fieldData = {
#                 date = 2010-08-02
#                 HIGH = 21.264700
#                 OPEN = 20.950400
#                 LOW = 20.756900
#                 VOLUME = 55044515.000000
#                 PX_LAST = 21.224400
#             }
#             fieldData = {
#                 date = 2010-08-03
#                 HIGH = 21.240600
#                 OPEN = 21.119600
#                 LOW = 20.934200
#                 VOLUME = 56877663.000000
#                 PX_LAST = 21.087400
#             }
#             fieldData = {
#                 date = 2010-08-04
#                 HIGH = 21.151900
#                 OPEN = 21.079300
#                 LOW = 20.507000
#                 VOLUME = 78531804.000000
#                 PX_LAST = 20.740800
#             }
#             fieldData = {
#                 date = 2010-08-05
#                 HIGH = 20.619900
#                 OPEN = 20.547300
#                 LOW = 20.321600
#                 VOLUME = 64922012.000000
#                 PX_LAST = 20.450600
#             }
#             fieldData = {
#                 date = 2010-08-06
#                 HIGH = 20.603700
#                 OPEN = 20.297400
#                 LOW = 20.168400
#                 VOLUME = 55985489.000000
#                 PX_LAST = 20.595700
#             }
#             fieldData = {
#                 date = 2010-08-09
#                 HIGH = 20.740800
#                 OPEN = 20.595700
#                 LOW = 20.450600
#                 VOLUME = 57102542.000000
#                 PX_LAST = 20.644000
#             }
#             fieldData = {
#                 date = 2010-08-10
#                 HIGH = 20.426400
#                 OPEN = 20.418300
#                 LOW = 20.055600
#                 VOLUME = 87257683.000000
#                 PX_LAST = 20.208800
#             }
#             fieldData = {
#                 date = 2010-08-11
#                 HIGH = 20.071700
#                 OPEN = 19.894400
#                 LOW = 19.797600
#                 VOLUME = 76745824.000000
#                 PX_LAST = 20.039500
#             }
#             fieldData = {
#                 date = 2010-08-12
#                 HIGH = 19.896400
#                 OPEN = 19.684800
#                 LOW = 19.636400
#                 VOLUME = 70240460.000000
#                 PX_LAST = 19.741200
#             }
#             fieldData = {
#                 date = 2010-08-13
#                 HIGH = 19.886300
#                 OPEN = 19.628400
#                 LOW = 19.539700
#                 VOLUME = 45263430.000000
#                 PX_LAST = 19.668700
#             }
#             fieldData = {
#                 date = 2010-08-16
#                 HIGH = 19.838000
#                 OPEN = 19.636400
#                 LOW = 19.588100
#                 VOLUME = 40968392.000000
#                 PX_LAST = 19.749300
#             }
#             fieldData = {
#                 date = 2010-08-17
#                 HIGH = 20.227400
#                 OPEN = 20.024800
#                 LOW = 19.935700
#                 VOLUME = 52935026.000000
#                 PX_LAST = 20.024800
#             }
#             fieldData = {
#                 date = 2010-08-18
#                 HIGH = 20.219300
#                 OPEN = 20.000500
#                 LOW = 19.781700
#                 VOLUME = 46818826.000000
#                 PX_LAST = 20.114000
#             }
#             fieldData = {
#                 date = 2010-08-19
#                 HIGH = 20.049100
#                 OPEN = 19.951900
#                 LOW = 19.619600
#                 VOLUME = 54069035.000000
#                 PX_LAST = 19.806000
#             }
#             fieldData = {
#                 date = 2010-08-20
#                 HIGH = 19.773600
#                 OPEN = 19.700700
#                 LOW = 19.611500
#                 VOLUME = 49565732.000000
#                 PX_LAST = 19.635800
#             }
#             fieldData = {
#                 date = 2010-08-23
#                 HIGH = 19.968300
#                 OPEN = 19.806000
#                 LOW = 19.643900
#                 VOLUME = 51728126.000000
#                 PX_LAST = 19.676300
#             }
#             fieldData = {
#                 date = 2010-08-24
#                 HIGH = 19.733100
#                 OPEN = 19.522400
#                 LOW = 19.449400
#                 VOLUME = 66532358.000000
#                 PX_LAST = 19.481800
#             }
#             fieldData = {
#                 date = 2010-08-25
#                 HIGH = 19.627700
#                 OPEN = 19.449400
#                 LOW = 19.344100
#                 VOLUME = 47404767.000000
#                 PX_LAST = 19.530500
#             }
#             fieldData = {
#                 date = 2010-08-26
#                 HIGH = 19.603400
#                 OPEN = 19.522400
#                 LOW = 19.279300
#                 VOLUME = 49105276.000000
#                 PX_LAST = 19.303600
#             }
#             fieldData = {
#                 date = 2010-08-27
#                 HIGH = 19.465600
#                 OPEN = 19.352200
#                 LOW = 19.052300
#                 VOLUME = 60944493.000000
#                 PX_LAST = 19.392700
#             }
#             fieldData = {
#                 date = 2010-08-30
#                 HIGH = 19.303600
#                 OPEN = 19.238700
#                 LOW = 19.125300
#                 VOLUME = 45453037.000000
#                 PX_LAST = 19.157700
#             }
#             fieldData = {
#                 date = 2010-08-31
#                 HIGH = 19.230600
#                 OPEN = 19.125300
#                 LOW = 18.898400
#                 VOLUME = 66083495.000000
#                 PX_LAST = 19.015900
#             }
#             fieldData = {
#                 date = 2010-09-01
#                 HIGH = 19.408900
#                 OPEN = 19.182000
#                 LOW = 19.076700
#                 VOLUME = 65235852.000000
#                 PX_LAST = 19.368400
#             }
#             fieldData = {
#                 date = 2010-09-02
#                 HIGH = 19.408800
#                 OPEN = 19.352200
#                 LOW = 19.214400
#                 VOLUME = 48837044.000000
#                 PX_LAST = 19.400800
#             }
#             fieldData = {
#                 date = 2010-09-03
#                 HIGH = 19.814100
#                 OPEN = 19.643900
#                 LOW = 19.611500
#                 VOLUME = 64189016.000000
#                 PX_LAST = 19.684400
#             }
#             fieldData = {
#                 date = 2010-09-07
#                 HIGH = 19.692600
#                 OPEN = 19.530500
#                 LOW = 19.384600
#                 VOLUME = 51928618.000000
#                 PX_LAST = 19.417000
#             }
#             fieldData = {
#                 date = 2010-09-08
#                 HIGH = 19.611500
#                 OPEN = 19.506200
#                 LOW = 19.238700
#                 VOLUME = 65512329.000000
#                 PX_LAST = 19.392700
#             }
#             fieldData = {
#                 date = 2010-09-09
#                 HIGH = 19.619600
#                 OPEN = 19.603400
#                 LOW = 19.441300
#                 VOLUME = 46028831.000000
#                 PX_LAST = 19.457500
#             }
#             fieldData = {
#                 date = 2010-09-10
#                 HIGH = 19.473700
#                 OPEN = 19.433200
#                 LOW = 19.279300
#                 VOLUME = 58293790.000000
#                 PX_LAST = 19.327900
#             }
#             fieldData = {
#                 date = 2010-09-13
#                 HIGH = 20.494800
#                 OPEN = 19.611500
#                 LOW = 19.522400
#                 VOLUME = 114680387.000000
#                 PX_LAST = 20.349000
#             }
#             fieldData = {
#                 date = 2010-09-14
#                 HIGH = 20.543500
#                 OPEN = 20.292200
#                 LOW = 20.170700
#                 VOLUME = 87160392.000000
#                 PX_LAST = 20.284100
#             }
#             fieldData = {
#                 date = 2010-09-15
#                 HIGH = 20.438100
#                 OPEN = 20.340900
#                 LOW = 20.195000
#                 VOLUME = 56204376.000000
#                 PX_LAST = 20.353000
#             }
#             fieldData = {
#                 date = 2010-09-16
#                 HIGH = 20.559700
#                 OPEN = 20.308500
#                 LOW = 20.300300
#                 VOLUME = 44548260.000000
#                 PX_LAST = 20.527300
#             }
#             fieldData = {
#                 date = 2010-09-17
#                 HIGH = 20.689300
#                 OPEN = 20.584000
#                 LOW = 20.324700
#                 VOLUME = 70341518.000000
#                 PX_LAST = 20.438100
#             }
#             fieldData = {
#                 date = 2010-09-20
#                 HIGH = 20.681200
#                 OPEN = 20.486700
#                 LOW = 20.349000
#                 VOLUME = 49877219.000000
#                 PX_LAST = 20.608300
#             }
#             fieldData = {
#                 date = 2010-09-21
#                 HIGH = 20.600200
#                 OPEN = 20.600200
#                 LOW = 20.324700
#                 VOLUME = 52924157.000000
#                 PX_LAST = 20.381400
#             }
#             fieldData = {
#                 date = 2010-09-22
#                 HIGH = 20.235500
#                 OPEN = 20.170700
#                 LOW = 19.741200
#                 VOLUME = 94299353.000000
#                 PX_LAST = 19.943800
#             }
#             fieldData = {
#                 date = 2010-09-23
#                 HIGH = 19.927600
#                 OPEN = 19.862700
#                 LOW = 19.741200
#                 VOLUME = 46210109.000000
#                 PX_LAST = 19.797900
#             }
#             fieldData = {
#                 date = 2010-09-24
#                 HIGH = 20.097700
#                 OPEN = 19.968100
#                 LOW = 19.919500
#                 VOLUME = 51948788.000000
#                 PX_LAST = 20.077500
#             }
#             fieldData = {
#                 date = 2010-09-27
#                 HIGH = 20.251700
#                 OPEN = 20.138300
#                 LOW = 19.927600
#                 VOLUME = 43732859.000000
#                 PX_LAST = 20.043000
#             }
#             fieldData = {
#                 date = 2010-09-28
#                 HIGH = 20.178800
#                 OPEN = 20.097700
# ...
#                 PX_LAST = 111.777100
#             }
#             fieldData = {
#                 date = 2018-10-10
#                 HIGH = 111.020400
#                 OPEN = 110.761500
#                 LOW = 105.334900
#                 VOLUME = 61376315.000000
#                 PX_LAST = 105.703400
#             }
#             fieldData = {
#                 date = 2018-10-11
#                 HIGH = 108.461400
#                 OPEN = 104.896800
#                 LOW = 103.751800
#                 VOLUME = 63904282.000000
#                 PX_LAST = 105.454400
#             }
#             fieldData = {
#                 date = 2018-10-12
#                 HIGH = 110.761500
#                 OPEN = 108.541100
#                 LOW = 106.659200
#                 VOLUME = 47742109.000000
#                 PX_LAST = 109.098700
#             }
#             fieldData = {
#                 date = 2018-10-15
#                 HIGH = 109.009100
#                 OPEN = 108.441500
#                 LOW = 106.486800
#                 VOLUME = 32068103.000000
#                 PX_LAST = 107.137200
#             }
#             fieldData = {
#                 date = 2018-10-16
#                 HIGH = 110.930800
#                 OPEN = 109.068800
#                 LOW = 108.481400
#                 VOLUME = 31610164.000000
#                 PX_LAST = 110.522500
#             }
#             fieldData = {
#                 date = 2018-10-17
#                 HIGH = 111.329000
#                 OPEN = 111.199600
#                 LOW = 109.077000
#                 VOLUME = 26548243.000000
#                 PX_LAST = 110.233800
#             }
#             fieldData = {
#                 date = 2018-10-18
#                 HIGH = 110.054600
#                 OPEN = 109.626400
#                 LOW = 107.366200
#                 VOLUME = 32506192.000000
#                 PX_LAST = 108.033300
#             }
#             fieldData = {
#                 date = 2018-10-19
#                 HIGH = 110.383100
#                 OPEN = 108.461400
#                 LOW = 107.744500
#                 VOLUME = 32785475.000000
#                 PX_LAST = 108.192600
#             }
#             fieldData = {
#                 date = 2018-10-22
#                 HIGH = 110.064500
#                 OPEN = 108.849800
#                 LOW = 107.774400
#                 VOLUME = 26545607.000000
#                 PX_LAST = 109.158400
#             }
#             fieldData = {
#                 date = 2018-10-23
#                 HIGH = 108.501300
#                 OPEN = 107.306400
#                 LOW = 104.657900
#                 VOLUME = 43770429.000000
#                 PX_LAST = 107.635000
#             }
#             fieldData = {
#                 date = 2018-10-24
#                 HIGH = 108.023300
#                 OPEN = 107.943700
#                 LOW = 101.153100
#                 VOLUME = 63897759.000000
#                 PX_LAST = 101.879900
#             }
#             fieldData = {
#                 date = 2018-10-25
#                 HIGH = 108.800000
#                 OPEN = 106.091700
#                 LOW = 105.693400
#                 VOLUME = 61646819.000000
#                 PX_LAST = 107.834100
#             }
#             fieldData = {
#                 date = 2018-10-26
#                 HIGH = 108.282200
#                 OPEN = 105.235400
#                 LOW = 104.309400
#                 VOLUME = 55523104.000000
#                 PX_LAST = 106.499900
#             }
#             fieldData = {
#                 date = 2018-10-29
#                 HIGH = 108.232400
#                 OPEN = 107.640000
#                 LOW = 101.192800
#                 VOLUME = 55162001.000000
#                 PX_LAST = 103.403300
#             }
#             fieldData = {
#                 date = 2018-10-30
#                 HIGH = 103.931000
#                 OPEN = 103.214100
#                 LOW = 99.679400
#                 VOLUME = 65350878.000000
#                 PX_LAST = 103.283800
#             }
#             fieldData = {
#                 date = 2018-10-31
#                 HIGH = 107.674800
#                 OPEN = 104.981500
#                 LOW = 104.936700
#                 VOLUME = 51062383.000000
#                 PX_LAST = 106.350600
#             }
#             fieldData = {
#                 date = 2018-11-01
#                 HIGH = 106.858400
#                 OPEN = 106.589500
#                 LOW = 105.076100
#                 VOLUME = 33384201.000000
#                 PX_LAST = 105.464400
#             }
#             fieldData = {
#                 date = 2018-11-02
#                 HIGH = 106.858400
#                 OPEN = 106.022000
#                 LOW = 104.523500
#                 VOLUME = 37680194.000000
#                 PX_LAST = 105.703400
#             }
#             fieldData = {
#                 date = 2018-11-05
#                 HIGH = 107.276600
#                 OPEN = 105.912400
#                 LOW = 105.444500
#                 VOLUME = 27922144.000000
#                 PX_LAST = 107.047500
#             }
#             fieldData = {
#                 date = 2018-11-06
#                 HIGH = 108.371800
#                 OPEN = 106.918100
#                 LOW = 105.822800
#                 VOLUME = 24340248.000000
#                 PX_LAST = 107.256600
#             }
#             fieldData = {
#                 date = 2018-11-07
#                 HIGH = 111.757200
#                 OPEN = 108.969200
#                 LOW = 108.929400
#                 VOLUME = 37901704.000000
#                 PX_LAST = 111.478400
#             }
#             fieldData = {
#                 date = 2018-11-08
#                 HIGH = 111.727300
#                 OPEN = 111.319100
#                 LOW = 110.432900
#                 VOLUME = 25644105.000000
#                 PX_LAST = 111.269300
#             }
#             fieldData = {
#                 date = 2018-11-09
#                 HIGH = 110.970600
#                 OPEN = 110.373200
#                 LOW = 108.292200
#                 VOLUME = 32039223.000000
#                 PX_LAST = 109.098700
#             }
#             fieldData = {
#                 date = 2018-11-12
#                 HIGH = 109.487000
#                 OPEN = 108.949300
#                 LOW = 105.643600
#                 VOLUME = 33621807.000000
#                 PX_LAST = 106.410300
#             }
#             fieldData = {
#                 date = 2018-11-13
#                 HIGH = 108.272300
#                 OPEN = 107.087400
#                 LOW = 106.181300
#                 VOLUME = 35374583.000000
#                 PX_LAST = 106.480000
#             }
#             fieldData = {
#                 date = 2018-11-14
#                 HIGH = 108.260000
#                 OPEN = 108.100000
#                 LOW = 104.470000
#                 VOLUME = 39495141.000000
#                 PX_LAST = 104.970000
#             }
#             fieldData = {
#                 date = 2018-11-15
#                 HIGH = 107.800000
#                 OPEN = 104.990000
#                 LOW = 103.910000
#                 VOLUME = 38505165.000000
#                 PX_LAST = 107.280000
#             }
#             fieldData = {
#                 date = 2018-11-16
#                 HIGH = 108.880000
#                 OPEN = 107.080000
#                 LOW = 106.800000
#                 VOLUME = 33502121.000000
#                 PX_LAST = 108.290000
#             }
#             fieldData = {
#                 date = 2018-11-19
#                 HIGH = 108.560000
#                 OPEN = 108.270000
#                 LOW = 103.550000
#                 VOLUME = 44773899.000000
#                 PX_LAST = 104.620000
#             }
#             fieldData = {
#                 date = 2018-11-20
#                 HIGH = 102.970000
#                 OPEN = 101.800000
#                 LOW = 99.352800
#                 VOLUME = 64052457.000000
#                 PX_LAST = 101.710000
#             }
#             fieldData = {
#                 date = 2018-11-21
#                 HIGH = 104.430000
#                 OPEN = 103.600000
#                 LOW = 102.240000
#                 VOLUME = 28130621.000000
#                 PX_LAST = 103.110000
#             }
#             fieldData = {
#                 date = 2018-11-23
#                 HIGH = 103.809900
#                 OPEN = 102.170000
#                 LOW = 102.000000
#                 VOLUME = 13823099.000000
#                 PX_LAST = 103.070000
#             }
#             fieldData = {
#                 date = 2018-11-26
#                 HIGH = 106.630000
#                 OPEN = 104.790000
#                 LOW = 104.580000
#                 VOLUME = 32336165.000000
#                 PX_LAST = 106.470000
#             }
#             fieldData = {
#                 date = 2018-11-27
#                 HIGH = 107.330000
#                 OPEN = 106.270000
#                 LOW = 105.360000
#                 VOLUME = 29124486.000000
#                 PX_LAST = 107.140000
#             }
#             fieldData = {
#                 date = 2018-11-28
#                 HIGH = 111.330000
#                 OPEN = 107.890000
#                 LOW = 107.860000
#                 VOLUME = 46788461.000000
#                 PX_LAST = 111.120000
#             }
#             fieldData = {
#                 date = 2018-11-29
#                 HIGH = 111.115000
#                 OPEN = 110.330000
#                 LOW = 109.030000
#                 VOLUME = 28123195.000000
#                 PX_LAST = 110.190000
#             }
#             fieldData = {
#                 date = 2018-11-30
#                 HIGH = 110.970000
#                 OPEN = 110.700000
#                 LOW = 109.360000
#                 VOLUME = 33665624.000000
#                 PX_LAST = 110.890000
#             }
#             fieldData = {
#                 date = 2018-12-03
#                 HIGH = 113.420000
#                 OPEN = 113.000000
#                 LOW = 110.730000
#                 VOLUME = 34732772.000000
#                 PX_LAST = 112.090000
#             }
#             fieldData = {
#                 date = 2018-12-04
#                 HIGH = 112.637300
#                 OPEN = 111.940000
#                 LOW = 108.211500
#                 VOLUME = 45196984.000000
#                 PX_LAST = 108.520000
#             }
#             fieldData = {
#                 date = 2018-12-06
#                 HIGH = 109.240000
#                 OPEN = 105.820000
#                 LOW = 105.000000
#                 VOLUME = 49107431.000000
#                 PX_LAST = 109.190000
#             }
#             fieldData = {
#                 date = 2018-12-07
#                 HIGH = 109.450000
#                 OPEN = 108.380000
#                 LOW = 104.300000
#                 VOLUME = 45044937.000000
#                 PX_LAST = 104.820000
#             }
#             fieldData = {
#                 date = 2018-12-10
#                 HIGH = 107.980000
#                 OPEN = 104.800000
#                 LOW = 103.890000
#                 VOLUME = 40801525.000000
#                 PX_LAST = 107.590000
#             }
#             fieldData = {
#                 date = 2018-12-11
#                 HIGH = 110.950000
#                 OPEN = 109.800000
#                 LOW = 107.440000
#                 VOLUME = 42381947.000000
#                 PX_LAST = 108.590000
#             }
#             fieldData = {
#                 date = 2018-12-12
#                 HIGH = 111.270000
#                 OPEN = 110.890000
#                 LOW = 109.040000
#                 VOLUME = 36183020.000000
#                 PX_LAST = 109.080000
#             }
#             fieldData = {
#                 date = 2018-12-13
#                 HIGH = 110.870000
#                 OPEN = 109.580000
#                 LOW = 108.630000
#                 VOLUME = 31333362.000000
#                 PX_LAST = 109.450000
#             }
#             fieldData = {
#                 date = 2018-12-14
#                 HIGH = 109.260000
#                 OPEN = 108.250000
#                 LOW = 105.500000
#                 VOLUME = 47043136.000000
#                 PX_LAST = 106.030000
#             }
#             fieldData = {
#                 date = 2018-12-17
#                 HIGH = 105.800000
#                 OPEN = 105.410000
#                 LOW = 101.710000
#                 VOLUME = 56957314.000000
#                 PX_LAST = 102.890000
#             }
#             fieldData = {
#                 date = 2018-12-18
#                 HIGH = 104.510000
#                 OPEN = 103.750000
#                 LOW = 102.520000
#                 VOLUME = 49319196.000000
#                 PX_LAST = 103.970000
#             }
#             fieldData = {
#                 date = 2018-12-19
#                 HIGH = 106.880000
#                 OPEN = 103.650000
#                 LOW = 101.350000
#                 VOLUME = 68198186.000000
#                 PX_LAST = 103.690000
#             }
#             fieldData = {
#                 date = 2018-12-20
#                 HIGH = 104.310000
#                 OPEN = 103.050000
#                 LOW = 98.780000
#                 VOLUME = 70334184.000000
#                 PX_LAST = 101.510000
#             }
#             fieldData = {
#                 date = 2018-12-21
#                 HIGH = 103.000000
#                 OPEN = 101.630000
#                 LOW = 97.460000
#                 VOLUME = 111242070.000000
#                 PX_LAST = 98.230000
#             }
#             fieldData = {
#                 date = 2018-12-24
#                 HIGH = 97.970000
#                 OPEN = 97.680000
#                 LOW = 93.980000
#                 VOLUME = 43935192.000000
#                 PX_LAST = 94.130000
#             }
#             fieldData = {
#                 date = 2018-12-26
#                 HIGH = 100.690000
#                 OPEN = 95.140000
#                 LOW = 93.960000
#                 VOLUME = 51634793.000000
#                 PX_LAST = 100.560000
#             }
#             fieldData = {
#                 date = 2018-12-27
#                 HIGH = 101.190000
#                 OPEN = 99.300000
#                 LOW = 96.400000
#                 VOLUME = 49498509.000000
#                 PX_LAST = 101.180000
#             }
#             fieldData = {
#                 date = 2018-12-28
#                 HIGH = 102.410000
#                 OPEN = 102.090000
#                 LOW = 99.520000
#                 VOLUME = 38169312.000000
#                 PX_LAST = 100.390000
#             }
#             fieldData = {
#                 date = 2018-12-31
#                 HIGH = 102.400000
#                 OPEN = 101.290000
#                 LOW = 100.440000
#                 VOLUME = 33173765.000000
#                 PX_LAST = 101.570000
#             }
#             fieldData = {
#                 date = 2019-01-02
#                 HIGH = 101.750000
#                 OPEN = 99.550000
#                 LOW = 98.940000
#                 VOLUME = 35329345.000000
#                 PX_LAST = 101.120000
#             }
#             fieldData = {
#                 date = 2019-01-03
#                 HIGH = 100.185000
#                 OPEN = 100.100000
#                 LOW = 97.200000
#                 VOLUME = 42578410.000000
#                 PX_LAST = 97.400000
#             }
#             fieldData = {
#                 date = 2019-01-04
#                 HIGH = 102.510000
#                 OPEN = 99.720000
#                 LOW = 98.930000
#                 VOLUME = 44060620.000000
#                 PX_LAST = 101.930000
#             }
#             fieldData = {
#                 date = 2019-01-07
#                 HIGH = 103.268100
#                 OPEN = 101.640000
#                 LOW = 100.980000
#                 VOLUME = 35656136.000000
#                 PX_LAST = 102.060000
#             }
#             fieldData = {
#                 date = 2019-01-08
#                 HIGH = 103.970000
#                 OPEN = 103.040000
#                 LOW = 101.713400
#                 VOLUME = 31514415.000000
#                 PX_LAST = 102.800000
#             }
#             fieldData = {
#                 date = 2019-01-09
#                 HIGH = 104.880000
#                 OPEN = 103.860000
#                 LOW = 103.244500
#                 VOLUME = 32280840.000000
#                 PX_LAST = 104.270000
#             }
#             fieldData = {
#                 date = 2019-01-10
#                 HIGH = 103.750000
#                 OPEN = 103.220000
#                 LOW = 102.380000
#                 VOLUME = 30067556.000000
#                 PX_LAST = 103.600000
#             }
#         }
#     }
# }

# %%
df = pd.DataFrame()
start = '20100101'
end = '20190110'
fields = ['HIGH', 'OPEN', 'LOW', 'VOLUME', 'PX_LAST']
cols = ['High', 'Open', 'Low', 'Volume', 'Adj Close']
code = ticker_list[0]
temp_df = con.bdh(code, fields, start, end)
temp_df = temp_df.loc[:, i]
temp_df.columns = cols
df = pd.concat([df, temp_df], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [SEE US Equity] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-63bcc5d0443f> in <module>()
#       6 code = ticker_list[0]
#       7 temp_df = con.bdh(code, fields, start, end)
# ----> 8 temp_df = temp_df.loc[:, i]
#       9 temp_df.columns = cols
#      10 df = pd.concat([df, temp_df], axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     977         # we may have a nested tuples indexer here
#     978         if self._is_nested_tuple_indexer(tup):
# --> 979             return self._getitem_nested_tuple(tup)
#     980
#     981         # we maybe be using a tuple to represent multiple dimensions here
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_nested_tuple(self, tup)
#    1056
#    1057             current_ndim = obj.ndim
# -> 1058             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1059             axis += 1
#    1060
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [SEE US Equity] is not in the [columns]'

# %%
temp_df = temp_df.loc[:, code]
temp_df.columns = cols
df = pd.concat([df, temp_df], axis=0)

# %%
df.head()
# Out:
#                High     Open      Low      Volume  Adj Close
# date
# 2010-01-04  24.8407  24.4573  24.4334  38414185.0    24.7209
# 2010-01-05  24.8407  24.6410  24.4733  49758862.0    24.7289
# 2010-01-06  24.8247  24.6650  24.3775  58182332.0    24.5771
# 2010-01-07  24.5212  24.4653  24.1139  50564285.0    24.3231
# 2010-01-08  24.6650  24.1858  24.1538  51201289.0    24.4893

# %%
df.tail()
# Out:
#                 High    Open       Low      Volume  Adj Close
# date
# 2019-01-04  102.5100   99.72   98.9300  44060620.0     101.93
# 2019-01-07  103.2681  101.64  100.9800  35656136.0     102.06
# 2019-01-08  103.9700  103.04  101.7134  31514415.0     102.80
# 2019-01-09  104.8800  103.86  103.2445  32280840.0     104.27
# 2019-01-10  103.7500  103.22  102.3800  30067556.0     103.60

# %%
df.to_csv('data/data.csv')

# %%
from utils import *

# %%
result = calc_pair_trading('SMH', 
                           data_source='ol',
                           method='rolling', 
                           period=245, 
                           is_saving=True, 
                           save_name='rsi_sample')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-323c32c25d24> in <module>()
#       4                            period=245,
#       5                            is_saving=True,
# ----> 6                            save_name='rsi_sample')
#
# ~\utils.py in calc_pair_trading(symbol, data_source, is_saving, save_name, method, period, rsi_period, upper, lower, show_bar)
#     463         data = hk_data
#     464     elif data_source == 'ol':
# --> 465         data = ol_data
#     466
#     467
#
# NameError: name 'ol_data' is not defined

# %% [markdown]
# 如果上述代码没有问题，可以尝试以下代码

# %% [markdown]
# ### test 2

# %%
tic = time.perf_counter()

df = con.bdh(ticker_list, fields, start, end)

df = pd.concat([df[x].assign(code=x.split(' ')[0]).groupby(level=0, axis=1).first() for x in df.columns.levels[0]], 
          axis=0,sort=False).reset_index().set_index(['date', 'code'])
df.columns = cols

toc = time.perf_counter()

print('retrieve data cost time: %s' % (toc-tic))

# %%
df.to_csv('data/data.csv')

# %%
result = calc_pair_trading('SMH', 
                           data_source='ol',
                           method='rolling', 
                           period=245, 
                           is_saving=True, 
                           save_name='rsi_sample')
