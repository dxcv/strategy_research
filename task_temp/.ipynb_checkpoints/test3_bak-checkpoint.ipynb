# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib as ta
import datetime, time
import pickle
from tqdm import tqdm_notebook

# import pdblp as pb
# import blpapi

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %%
def save_file(dataframe, name):
    
    with open(name, 'wb') as f:
        pickle.dump(dataframe, f)

# %%
con = pb.BCon(port=8194, timeout=5000)
# con.start()

# %%
df_code = pd.read_excel('data/etf_pair_code.xlsx', dtype={'symbol':str})

# %%
code_list = df_code.symbol.unique().tolist()

# %%
ticker_list = (df_code.symbol + ' ' + df_code.region).unique().tolist()

# %%
lens = len(code_list)

# %%
for i,ind in tqdm_notebook(enumerate(ticker_list[:10])):
    print(i, ind)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 0 MSFT US Equity
# 1 AAPL US Equity
# 2 V US Equity
# 3 INTC US Equity
# 4 CSCO US Equity
# 5 MA US Equity
# 6 ORCL US Equity
# 7 AVGO US Equity
# 8 ADBE US Equity
# 9 IBM US Equity

# %% [markdown]
# ### test 1

# %%
err_code = []
tic = time.perf_counter()
fields = ['HIGH', 'OPEN', 'LOW', 'CLOSE', 'VOLUME', 'PX_CLOSE']
cols = ['High', 'Open', 'Low', 'Close', 'Volume', 'Adj Close']
start = '20100101'
end = '20190110'

for i,ind in tqdm_notebook(enumerate(ticker_list)):
    try:
        temp_df = con.bdh(i, fields, start, end)
        temp_df = temp_df.loc[:, i]
        temp_df.columns = cols
        temp_df = temp_df.assign(code=ind)
        
        try:
            df = pd.concat([df, temp_df], axis=0)
        except:
            print('concat data has problem, ticker code : %s' % i)
        
    except:
        print('retrieve %s data, have something wrong' % i)
        err_code.append(i)
toc = time.perf_counter()

print('retrieve data cost time: %s' % (toc-tic))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# retrieve 0 data, have something wrong
# retrieve 1 data, have something wrong
# retrieve 2 data, have something wrong
# retrieve 3 data, have something wrong
# retrieve 4 data, have something wrong
# retrieve 5 data, have something wrong
# retrieve 6 data, have something wrong
# retrieve 7 data, have something wrong
# retrieve 8 data, have something wrong
# retrieve 9 data, have something wrong
# retrieve 10 data, have something wrong
# retrieve 11 data, have something wrong
# retrieve 12 data, have something wrong
# retrieve 13 data, have something wrong
# retrieve 14 data, have something wrong
# retrieve 15 data, have something wrong
# retrieve 16 data, have something wrong
# retrieve 17 data, have something wrong
# retrieve 18 data, have something wrong
# retrieve 19 data, have something wrong
# retrieve 20 data, have something wrong
# retrieve 21 data, have something wrong
# retrieve 22 data, have something wrong
# retrieve 23 data, have something wrong
# retrieve 24 data, have something wrong
# retrieve 25 data, have something wrong
# retrieve 26 data, have something wrong
# retrieve 27 data, have something wrong
# retrieve 28 data, have something wrong
# retrieve 29 data, have something wrong
# retrieve 30 data, have something wrong
# retrieve 31 data, have something wrong
# retrieve 32 data, have something wrong
# retrieve 33 data, have something wrong
# retrieve 34 data, have something wrong
# retrieve 35 data, have something wrong
# retrieve 36 data, have something wrong
# retrieve 37 data, have something wrong
# retrieve 38 data, have something wrong
# retrieve 39 data, have something wrong
# retrieve 40 data, have something wrong
# retrieve 41 data, have something wrong
# retrieve 42 data, have something wrong
# retrieve 43 data, have something wrong
# retrieve 44 data, have something wrong
# retrieve 45 data, have something wrong
# retrieve 46 data, have something wrong
# retrieve 47 data, have something wrong
# retrieve 48 data, have something wrong
# retrieve 49 data, have something wrong
# retrieve 50 data, have something wrong
# retrieve 51 data, have something wrong
# retrieve 52 data, have something wrong
# retrieve 53 data, have something wrong
# retrieve 54 data, have something wrong
# retrieve 55 data, have something wrong
# retrieve 56 data, have something wrong
# retrieve 57 data, have something wrong
# retrieve 58 data, have something wrong
# retrieve 59 data, have something wrong
# retrieve 60 data, have something wrong
# retrieve 61 data, have something wrong
# retrieve 62 data, have something wrong
# retrieve 63 data, have something wrong
# retrieve 64 data, have something wrong
# retrieve 65 data, have something wrong
# retrieve 66 data, have something wrong
# retrieve 67 data, have something wrong
# retrieve 68 data, have something wrong
# retrieve 69 data, have something wrong
# retrieve 70 data, have something wrong
# retrieve 71 data, have something wrong
# retrieve 72 data, have something wrong
# retrieve 73 data, have something wrong
# retrieve 74 data, have something wrong
# retrieve 75 data, have something wrong
# retrieve 76 data, have something wrong
# retrieve 77 data, have something wrong
# retrieve 78 data, have something wrong
# retrieve 79 data, have something wrong
# retrieve 80 data, have something wrong
# retrieve 81 data, have something wrong
# retrieve 82 data, have something wrong
# retrieve 83 data, have something wrong
# retrieve 84 data, have something wrong
# retrieve 85 data, have something wrong
# retrieve 86 data, have something wrong
# retrieve 87 data, have something wrong
# retrieve 88 data, have something wrong
# retrieve 89 data, have something wrong
# retrieve 90 data, have something wrong
# retrieve 91 data, have something wrong
# retrieve 92 data, have something wrong
# retrieve 93 data, have something wrong
# retrieve 94 data, have something wrong
# retrieve 95 data, have something wrong
# retrieve 96 data, have something wrong
# retrieve 97 data, have something wrong
# retrieve 98 data, have something wrong
# retrieve 99 data, have something wrong
# retrieve 100 data, have something wrong
# retrieve 101 data, have something wrong
# retrieve 102 data, have something wrong
# retrieve 103 data, have something wrong
# retrieve 104 data, have something wrong
# retrieve 105 data, have something wrong
# retrieve 106 data, have something wrong
# retrieve 107 data, have something wrong
# retrieve 108 data, have something wrong
# retrieve 109 data, have something wrong
# retrieve 110 data, have something wrong
# retrieve 111 data, have something wrong
# retrieve 112 data, have something wrong
# retrieve 113 data, have something wrong
# retrieve 114 data, have something wrong
# retrieve 115 data, have something wrong
# retrieve 116 data, have something wrong
# retrieve 117 data, have something wrong
# retrieve 118 data, have something wrong
# retrieve 119 data, have something wrong
# retrieve 120 data, have something wrong
# retrieve 121 data, have something wrong
# retrieve 122 data, have something wrong
# retrieve 123 data, have something wrong
# retrieve 124 data, have something wrong
# retrieve 125 data, have something wrong
# retrieve 126 data, have something wrong
# retrieve 127 data, have something wrong
# retrieve 128 data, have something wrong
# retrieve 129 data, have something wrong
# retrieve 130 data, have something wrong
# retrieve 131 data, have something wrong
# retrieve 132 data, have something wrong
# retrieve 133 data, have something wrong
# retrieve 134 data, have something wrong
# retrieve 135 data, have something wrong
# retrieve 136 data, have something wrong
# retrieve 137 data, have something wrong
# retrieve 138 data, have something wrong
# retrieve 139 data, have something wrong
# retrieve 140 data, have something wrong
# retrieve 141 data, have something wrong
# retrieve 142 data, have something wrong
# retrieve 143 data, have something wrong
# retrieve 144 data, have something wrong
# retrieve 145 data, have something wrong
# retrieve 146 data, have something wrong
# retrieve 147 data, have something wrong
# retrieve 148 data, have something wrong
# retrieve 149 data, have something wrong
# retrieve 150 data, have something wrong
# retrieve 151 data, have something wrong
# retrieve 152 data, have something wrong
# retrieve 153 data, have something wrong
# retrieve 154 data, have something wrong
# retrieve 155 data, have something wrong
# retrieve 156 data, have something wrong
# retrieve 157 data, have something wrong
# retrieve 158 data, have something wrong
# retrieve 159 data, have something wrong
# retrieve 160 data, have something wrong
# retrieve 161 data, have something wrong
# retrieve 162 data, have something wrong
# retrieve 163 data, have something wrong
# retrieve 164 data, have something wrong
# retrieve 165 data, have something wrong
# retrieve 166 data, have something wrong
# retrieve 167 data, have something wrong
# retrieve 168 data, have something wrong
# retrieve 169 data, have something wrong
# retrieve 170 data, have something wrong
# retrieve 171 data, have something wrong
# retrieve 172 data, have something wrong
# retrieve 173 data, have something wrong
# retrieve 174 data, have something wrong
# retrieve 175 data, have something wrong
# retrieve 176 data, have something wrong
# retrieve 177 data, have something wrong
# retrieve 178 data, have something wrong
# retrieve 179 data, have something wrong
# retrieve 180 data, have something wrong
# retrieve 181 data, have something wrong
# retrieve 182 data, have something wrong
# retrieve 183 data, have something wrong
# retrieve 184 data, have something wrong
# retrieve 185 data, have something wrong
# retrieve 186 data, have something wrong
# retrieve 187 data, have something wrong
# retrieve 188 data, have something wrong
# retrieve 189 data, have something wrong
# retrieve 190 data, have something wrong
# retrieve 191 data, have something wrong
# retrieve 192 data, have something wrong
# retrieve 193 data, have something wrong
# retrieve 194 data, have something wrong
# retrieve 195 data, have something wrong
# retrieve 196 data, have something wrong
# retrieve 197 data, have something wrong
# retrieve 198 data, have something wrong
# retrieve 199 data, have something wrong
# retrieve 200 data, have something wrong
# retrieve 201 data, have something wrong
# retrieve 202 data, have something wrong
# retrieve 203 data, have something wrong
# retrieve 204 data, have something wrong
# retrieve 205 data, have something wrong
# retrieve 206 data, have something wrong
# retrieve 207 data, have something wrong
# retrieve 208 data, have something wrong
# retrieve 209 data, have something wrong
# retrieve 210 data, have something wrong
# retrieve 211 data, have something wrong
# retrieve 212 data, have something wrong
# retrieve 213 data, have something wrong
# retrieve 214 data, have something wrong
# retrieve 215 data, have something wrong
# retrieve 216 data, have something wrong
# retrieve 217 data, have something wrong
# retrieve 218 data, have something wrong
# retrieve 219 data, have something wrong
# retrieve 220 data, have something wrong
# retrieve 221 data, have something wrong
# retrieve 222 data, have something wrong
# retrieve 223 data, have something wrong
# retrieve 224 data, have something wrong
# retrieve 225 data, have something wrong
# retrieve 226 data, have something wrong
# retrieve 227 data, have something wrong
# retrieve 228 data, have something wrong
# retrieve 229 data, have something wrong
# retrieve 230 data, have something wrong
# retrieve 231 data, have something wrong
# retrieve 232 data, have something wrong
# retrieve 233 data, have something wrong
# retrieve 234 data, have something wrong
# retrieve 235 data, have something wrong
# retrieve 236 data, have something wrong
# retrieve 237 data, have something wrong
# retrieve 238 data, have something wrong
# retrieve 239 data, have something wrong
# retrieve 240 data, have something wrong
# retrieve 241 data, have something wrong
# retrieve 242 data, have something wrong
# retrieve 243 data, have something wrong
# retrieve 244 data, have something wrong
# retrieve 245 data, have something wrong
# retrieve 246 data, have something wrong
# retrieve 247 data, have something wrong
# retrieve 248 data, have something wrong
# retrieve 249 data, have something wrong
# retrieve 250 data, have something wrong
# retrieve 251 data, have something wrong
# retrieve 252 data, have something wrong
# retrieve 253 data, have something wrong
# retrieve 254 data, have something wrong
# retrieve 255 data, have something wrong
# retrieve 256 data, have something wrong
# retrieve 257 data, have something wrong
# retrieve 258 data, have something wrong
# retrieve 259 data, have something wrong
# retrieve 260 data, have something wrong
# retrieve 261 data, have something wrong
# retrieve 262 data, have something wrong
# retrieve 263 data, have something wrong
# retrieve 264 data, have something wrong
# retrieve 265 data, have something wrong
# retrieve 266 data, have something wrong
# retrieve 267 data, have something wrong
# retrieve 268 data, have something wrong
# retrieve 269 data, have something wrong
# retrieve 270 data, have something wrong
# retrieve 271 data, have something wrong
# retrieve 272 data, have something wrong
# retrieve 273 data, have something wrong
# retrieve 274 data, have something wrong
# retrieve 275 data, have something wrong
# retrieve 276 data, have something wrong
# retrieve 277 data, have something wrong
# retrieve 278 data, have something wrong
# retrieve 279 data, have something wrong
# retrieve 280 data, have something wrong
# retrieve 281 data, have something wrong
# retrieve 282 data, have something wrong
# retrieve 283 data, have something wrong
# retrieve 284 data, have something wrong
# retrieve 285 data, have something wrong
# retrieve 286 data, have something wrong
# retrieve 287 data, have something wrong
# retrieve 288 data, have something wrong
# retrieve 289 data, have something wrong
# retrieve 290 data, have something wrong
# retrieve 291 data, have something wrong
# retrieve 292 data, have something wrong
# retrieve 293 data, have something wrong
# retrieve 294 data, have something wrong
# retrieve 295 data, have something wrong
# retrieve 296 data, have something wrong
# retrieve 297 data, have something wrong
# retrieve 298 data, have something wrong
# retrieve 299 data, have something wrong
# retrieve 300 data, have something wrong
# retrieve 301 data, have something wrong
# retrieve 302 data, have something wrong
# retrieve 303 data, have something wrong
# retrieve 304 data, have something wrong
# retrieve 305 data, have something wrong
# retrieve 306 data, have something wrong
# retrieve 307 data, have something wrong
# retrieve 308 data, have something wrong
# retrieve 309 data, have something wrong
# retrieve 310 data, have something wrong
# retrieve 311 data, have something wrong
# retrieve 312 data, have something wrong
# retrieve 313 data, have something wrong
# retrieve 314 data, have something wrong
# retrieve 315 data, have something wrong
# retrieve 316 data, have something wrong
# retrieve 317 data, have something wrong
# retrieve 318 data, have something wrong
# retrieve 319 data, have something wrong
# retrieve 320 data, have something wrong
# retrieve 321 data, have something wrong
# retrieve 322 data, have something wrong
# retrieve 323 data, have something wrong
# retrieve 324 data, have something wrong
# retrieve 325 data, have something wrong
# retrieve 326 data, have something wrong
# retrieve 327 data, have something wrong
# retrieve 328 data, have something wrong
# retrieve 329 data, have something wrong
# retrieve 330 data, have something wrong
# retrieve 331 data, have something wrong
# retrieve 332 data, have something wrong
# retrieve 333 data, have something wrong
# retrieve 334 data, have something wrong
# retrieve 335 data, have something wrong
# retrieve 336 data, have something wrong
# retrieve 337 data, have something wrong
# retrieve 338 data, have something wrong
# retrieve 339 data, have something wrong
# retrieve 340 data, have something wrong
# retrieve 341 data, have something wrong
# retrieve 342 data, have something wrong
# retrieve 343 data, have something wrong
# retrieve 344 data, have something wrong
# retrieve 345 data, have something wrong
# retrieve 346 data, have something wrong
# retrieve 347 data, have something wrong
# retrieve 348 data, have something wrong
# retrieve 349 data, have something wrong
# retrieve 350 data, have something wrong
# retrieve 351 data, have something wrong
# retrieve 352 data, have something wrong
# retrieve 353 data, have something wrong
# retrieve 354 data, have something wrong
# retrieve 355 data, have something wrong
# retrieve 356 data, have something wrong
# retrieve 357 data, have something wrong
# retrieve 358 data, have something wrong
# retrieve 359 data, have something wrong
# retrieve 360 data, have something wrong
# retrieve 361 data, have something wrong
# retrieve 362 data, have something wrong
# retrieve 363 data, have something wrong
# retrieve 364 data, have something wrong
# retrieve 365 data, have something wrong
# retrieve 366 data, have something wrong
# retrieve 367 data, have something wrong
# retrieve 368 data, have something wrong
# retrieve 369 data, have something wrong
# retrieve 370 data, have something wrong
# retrieve 371 data, have something wrong
# retrieve 372 data, have something wrong
# retrieve 373 data, have something wrong
# retrieve 374 data, have something wrong
# retrieve 375 data, have something wrong
# retrieve 376 data, have something wrong
# retrieve 377 data, have something wrong
# retrieve 378 data, have something wrong
# retrieve 379 data, have something wrong
# retrieve 380 data, have something wrong
# retrieve 381 data, have something wrong
# retrieve 382 data, have something wrong
# retrieve 383 data, have something wrong
# retrieve 384 data, have something wrong
# retrieve 385 data, have something wrong
# retrieve 386 data, have something wrong
# retrieve 387 data, have something wrong
# retrieve 388 data, have something wrong
# retrieve 389 data, have something wrong
# retrieve 390 data, have something wrong
# retrieve 391 data, have something wrong
# retrieve 392 data, have something wrong
# retrieve 393 data, have something wrong
# retrieve 394 data, have something wrong
# retrieve 395 data, have something wrong
# retrieve 396 data, have something wrong
# retrieve 397 data, have something wrong
# retrieve 398 data, have something wrong
# retrieve 399 data, have something wrong
# retrieve 400 data, have something wrong
# retrieve 401 data, have something wrong
# retrieve 402 data, have something wrong
# retrieve 403 data, have something wrong
# retrieve 404 data, have something wrong
# retrieve 405 data, have something wrong
# retrieve 406 data, have something wrong
# retrieve 407 data, have something wrong
# retrieve 408 data, have something wrong
# retrieve 409 data, have something wrong
# retrieve 410 data, have something wrong
# retrieve 411 data, have something wrong
# retrieve 412 data, have something wrong
# retrieve 413 data, have something wrong
# retrieve 414 data, have something wrong
# retrieve 415 data, have something wrong
# retrieve 416 data, have something wrong
# retrieve 417 data, have something wrong
# retrieve 418 data, have something wrong
# retrieve 419 data, have something wrong
# retrieve 420 data, have something wrong
# retrieve 421 data, have something wrong
# retrieve 422 data, have something wrong
# retrieve 423 data, have something wrong
# retrieve 424 data, have something wrong
# retrieve 425 data, have something wrong
# retrieve 426 data, have something wrong
# retrieve 427 data, have something wrong
# retrieve 428 data, have something wrong
# retrieve 429 data, have something wrong
# retrieve 430 data, have something wrong
# retrieve 431 data, have something wrong
# retrieve 432 data, have something wrong
# retrieve 433 data, have something wrong
# retrieve 434 data, have something wrong
# retrieve 435 data, have something wrong
# retrieve 436 data, have something wrong
# retrieve 437 data, have something wrong
# retrieve 438 data, have something wrong
# retrieve 439 data, have something wrong
# retrieve 440 data, have something wrong
# retrieve 441 data, have something wrong
# retrieve 442 data, have something wrong
# retrieve 443 data, have something wrong
# retrieve 444 data, have something wrong
# retrieve 445 data, have something wrong
# retrieve 446 data, have something wrong
# retrieve 447 data, have something wrong
# retrieve 448 data, have something wrong
# retrieve 449 data, have something wrong
# retrieve 450 data, have something wrong
# retrieve 451 data, have something wrong
# retrieve 452 data, have something wrong
# retrieve 453 data, have something wrong
# retrieve 454 data, have something wrong
# retrieve 455 data, have something wrong
# retrieve 456 data, have something wrong
# retrieve 457 data, have something wrong
# retrieve 458 data, have something wrong
# retrieve 459 data, have something wrong
# retrieve 460 data, have something wrong
# retrieve 461 data, have something wrong
# retrieve 462 data, have something wrong
# retrieve 463 data, have something wrong
# retrieve 464 data, have something wrong
# retrieve 465 data, have something wrong
# retrieve 466 data, have something wrong
# retrieve 467 data, have something wrong
# retrieve 468 data, have something wrong
# retrieve 469 data, have something wrong
# retrieve 470 data, have something wrong
# retrieve 471 data, have something wrong
# retrieve 472 data, have something wrong
# retrieve 473 data, have something wrong
# retrieve 474 data, have something wrong
# retrieve 475 data, have something wrong
# retrieve 476 data, have something wrong
# retrieve 477 data, have something wrong
# retrieve 478 data, have something wrong
# retrieve 479 data, have something wrong
# retrieve 480 data, have something wrong
# retrieve 481 data, have something wrong
# retrieve 482 data, have something wrong
# retrieve 483 data, have something wrong
# retrieve 484 data, have something wrong
# retrieve 485 data, have something wrong
# retrieve 486 data, have something wrong
# retrieve 487 data, have something wrong
# retrieve 488 data, have something wrong
# retrieve 489 data, have something wrong
# retrieve 490 data, have something wrong
# retrieve 491 data, have something wrong
# retrieve 492 data, have something wrong
# retrieve 493 data, have something wrong
# retrieve 494 data, have something wrong
# retrieve 495 data, have something wrong
# retrieve 496 data, have something wrong
# retrieve 497 data, have something wrong
# retrieve 498 data, have something wrong
# retrieve 499 data, have something wrong
# retrieve 500 data, have something wrong
# retrieve 501 data, have something wrong
# retrieve 502 data, have something wrong
# retrieve 503 data, have something wrong
# retrieve 504 data, have something wrong
# retrieve 505 data, have something wrong
# retrieve 506 data, have something wrong
# retrieve 507 data, have something wrong
# retrieve 508 data, have something wrong
# retrieve 509 data, have something wrong
# retrieve 510 data, have something wrong
# retrieve 511 data, have something wrong
# retrieve 512 data, have something wrong
# retrieve 513 data, have something wrong
# retrieve 514 data, have something wrong
# retrieve 515 data, have something wrong
# retrieve 516 data, have something wrong
# retrieve 517 data, have something wrong
# retrieve 518 data, have something wrong
# retrieve 519 data, have something wrong
# retrieve 520 data, have something wrong
# retrieve 521 data, have something wrong
# retrieve 522 data, have something wrong
# retrieve 523 data, have something wrong
# retrieve 524 data, have something wrong
# retrieve 525 data, have something wrong
# retrieve 526 data, have something wrong
# retrieve 527 data, have something wrong
# retrieve 528 data, have something wrong
# retrieve 529 data, have something wrong
# retrieve 530 data, have something wrong
# retrieve 531 data, have something wrong
# retrieve 532 data, have something wrong
# retrieve 533 data, have something wrong
# retrieve 534 data, have something wrong
# retrieve 535 data, have something wrong
# retrieve 536 data, have something wrong
# retrieve 537 data, have something wrong
# retrieve 538 data, have something wrong
# retrieve 539 data, have something wrong
# retrieve 540 data, have something wrong
# retrieve 541 data, have something wrong
# retrieve 542 data, have something wrong
# retrieve 543 data, have something wrong
# retrieve 544 data, have something wrong
# retrieve 545 data, have something wrong
# retrieve 546 data, have something wrong
# retrieve 547 data, have something wrong
# retrieve 548 data, have something wrong
# retrieve 549 data, have something wrong
# retrieve 550 data, have something wrong
# retrieve 551 data, have something wrong
# retrieve 552 data, have something wrong
# retrieve 553 data, have something wrong
# retrieve 554 data, have something wrong
# retrieve 555 data, have something wrong
# retrieve 556 data, have something wrong
# retrieve 557 data, have something wrong
# retrieve 558 data, have something wrong
# retrieve 559 data, have something wrong
# retrieve 560 data, have something wrong
# retrieve 561 data, have something wrong
# retrieve 562 data, have something wrong
# retrieve 563 data, have something wrong
# retrieve 564 data, have something wrong
# retrieve 565 data, have something wrong
# retrieve 566 data, have something wrong
# retrieve 567 data, have something wrong
# retrieve 568 data, have something wrong
# retrieve 569 data, have something wrong
# retrieve 570 data, have something wrong
# retrieve 571 data, have something wrong
# retrieve 572 data, have something wrong
# retrieve 573 data, have something wrong
# retrieve 574 data, have something wrong
# retrieve 575 data, have something wrong
# retrieve 576 data, have something wrong
# retrieve 577 data, have something wrong
# retrieve 578 data, have something wrong
# retrieve 579 data, have something wrong
# retrieve 580 data, have something wrong
# retrieve 581 data, have something wrong
# retrieve 582 data, have something wrong
# retrieve 583 data, have something wrong
# retrieve 584 data, have something wrong
# retrieve 585 data, have something wrong
# retrieve 586 data, have something wrong
# retrieve 587 data, have something wrong
# retrieve 588 data, have something wrong
# retrieve 589 data, have something wrong
# retrieve 590 data, have something wrong
# retrieve 591 data, have something wrong
# retrieve 592 data, have something wrong
# retrieve 593 data, have something wrong
# retrieve 594 data, have something wrong
# retrieve 595 data, have something wrong
# retrieve 596 data, have something wrong
# retrieve 597 data, have something wrong
# retrieve 598 data, have something wrong
# retrieve 599 data, have something wrong
# retrieve 600 data, have something wrong
# retrieve 601 data, have something wrong
# retrieve 602 data, have something wrong
# retrieve 603 data, have something wrong
# retrieve 604 data, have something wrong
# retrieve 605 data, have something wrong
# retrieve 606 data, have something wrong
# retrieve 607 data, have something wrong
# retrieve 608 data, have something wrong
# retrieve 609 data, have something wrong
# retrieve 610 data, have something wrong
# retrieve 611 data, have something wrong
# retrieve 612 data, have something wrong
# retrieve 613 data, have something wrong
# retrieve 614 data, have something wrong
# retrieve 615 data, have something wrong
# retrieve 616 data, have something wrong
# retrieve 617 data, have something wrong
# retrieve 618 data, have something wrong
# retrieve 619 data, have something wrong
# retrieve 620 data, have something wrong
# retrieve 621 data, have something wrong
# retrieve 622 data, have something wrong
# retrieve 623 data, have something wrong
# retrieve 624 data, have something wrong
# retrieve 625 data, have something wrong
# retrieve 626 data, have something wrong
# retrieve 627 data, have something wrong
# retrieve 628 data, have something wrong
# retrieve 629 data, have something wrong
# retrieve 630 data, have something wrong
# retrieve 631 data, have something wrong
# retrieve 632 data, have something wrong
# retrieve 633 data, have something wrong
# retrieve 634 data, have something wrong
# retrieve 635 data, have something wrong
# retrieve 636 data, have something wrong
# retrieve 637 data, have something wrong
# retrieve 638 data, have something wrong
# retrieve 639 data, have something wrong
# retrieve 640 data, have something wrong
# retrieve 641 data, have something wrong
# retrieve 642 data, have something wrong
# retrieve 643 data, have something wrong
# retrieve 644 data, have something wrong
# retrieve 645 data, have something wrong
# retrieve 646 data, have something wrong
# retrieve 647 data, have something wrong
# retrieve 648 data, have something wrong
# retrieve 649 data, have something wrong
# retrieve 650 data, have something wrong
# retrieve 651 data, have something wrong
# retrieve 652 data, have something wrong
# retrieve 653 data, have something wrong
# retrieve 654 data, have something wrong
# retrieve 655 data, have something wrong
# retrieve 656 data, have something wrong
# retrieve 657 data, have something wrong
# retrieve 658 data, have something wrong
# retrieve 659 data, have something wrong
# retrieve 660 data, have something wrong
# retrieve 661 data, have something wrong
# retrieve 662 data, have something wrong
# retrieve 663 data, have something wrong
# retrieve 664 data, have something wrong
# retrieve 665 data, have something wrong
# retrieve 666 data, have something wrong
# retrieve 667 data, have something wrong
# retrieve 668 data, have something wrong
# retrieve 669 data, have something wrong
# retrieve 670 data, have something wrong
# retrieve 671 data, have something wrong
# retrieve 672 data, have something wrong
# retrieve 673 data, have something wrong
# retrieve 674 data, have something wrong
# retrieve 675 data, have something wrong
# retrieve 676 data, have something wrong
# retrieve 677 data, have something wrong
# retrieve 678 data, have something wrong
# retrieve 679 data, have something wrong
# retrieve 680 data, have something wrong
# retrieve 681 data, have something wrong
# retrieve 682 data, have something wrong
# retrieve 683 data, have something wrong
# retrieve 684 data, have something wrong
# retrieve 685 data, have something wrong
# retrieve 686 data, have something wrong
# retrieve 687 data, have something wrong
# retrieve 688 data, have something wrong
# retrieve 689 data, have something wrong
# retrieve 690 data, have something wrong
# retrieve 691 data, have something wrong
# retrieve 692 data, have something wrong
# retrieve 693 data, have something wrong
# retrieve 694 data, have something wrong
# retrieve 695 data, have something wrong
# retrieve 696 data, have something wrong
# retrieve 697 data, have something wrong
# retrieve 698 data, have something wrong
# retrieve 699 data, have something wrong
# retrieve 700 data, have something wrong
# retrieve 701 data, have something wrong
# retrieve 702 data, have something wrong
# retrieve 703 data, have something wrong
# retrieve 704 data, have something wrong
# retrieve 705 data, have something wrong
# retrieve 706 data, have something wrong
# retrieve 707 data, have something wrong
# retrieve 708 data, have something wrong
# retrieve 709 data, have something wrong
# retrieve 710 data, have something wrong
# retrieve 711 data, have something wrong
# retrieve 712 data, have something wrong
# retrieve 713 data, have something wrong
# retrieve 714 data, have something wrong
# retrieve 715 data, have something wrong
# retrieve 716 data, have something wrong
# retrieve 717 data, have something wrong
# retrieve 718 data, have something wrong
# retrieve 719 data, have something wrong
# retrieve 720 data, have something wrong
# retrieve 721 data, have something wrong
# retrieve 722 data, have something wrong
# retrieve 723 data, have something wrong
# retrieve 724 data, have something wrong
# retrieve 725 data, have something wrong
# retrieve 726 data, have something wrong
# retrieve 727 data, have something wrong
# retrieve 728 data, have something wrong
# retrieve 729 data, have something wrong
# retrieve 730 data, have something wrong
# retrieve 731 data, have something wrong
# retrieve 732 data, have something wrong
# retrieve 733 data, have something wrong
# retrieve 734 data, have something wrong
# retrieve 735 data, have something wrong
# retrieve 736 data, have something wrong
# retrieve 737 data, have something wrong
# retrieve 738 data, have something wrong
# retrieve 739 data, have something wrong
# retrieve 740 data, have something wrong
# retrieve 741 data, have something wrong
# retrieve 742 data, have something wrong
# retrieve 743 data, have something wrong
# retrieve 744 data, have something wrong
# retrieve 745 data, have something wrong
# retrieve 746 data, have something wrong
# retrieve 747 data, have something wrong
# retrieve 748 data, have something wrong
# retrieve 749 data, have something wrong
# retrieve 750 data, have something wrong
# retrieve 751 data, have something wrong
# retrieve 752 data, have something wrong
# retrieve 753 data, have something wrong
# retrieve 754 data, have something wrong
# retrieve 755 data, have something wrong
# retrieve 756 data, have something wrong
# retrieve 757 data, have something wrong
# retrieve 758 data, have something wrong
# retrieve 759 data, have something wrong
# retrieve 760 data, have something wrong
# retrieve 761 data, have something wrong
# retrieve 762 data, have something wrong
# retrieve 763 data, have something wrong
# retrieve 764 data, have something wrong
# retrieve 765 data, have something wrong
# retrieve 766 data, have something wrong
# retrieve 767 data, have something wrong
# retrieve 768 data, have something wrong
# retrieve 769 data, have something wrong
# retrieve 770 data, have something wrong
# retrieve 771 data, have something wrong
# retrieve 772 data, have something wrong
# retrieve 773 data, have something wrong
# retrieve 774 data, have something wrong
# retrieve 775 data, have something wrong
# retrieve 776 data, have something wrong
# retrieve 777 data, have something wrong
# retrieve 778 data, have something wrong
# retrieve 779 data, have something wrong
# retrieve 780 data, have something wrong
# retrieve 781 data, have something wrong
# retrieve 782 data, have something wrong
# retrieve 783 data, have something wrong
# retrieve 784 data, have something wrong
# retrieve 785 data, have something wrong
# retrieve 786 data, have something wrong
# retrieve 787 data, have something wrong
# retrieve 788 data, have something wrong
# retrieve 789 data, have something wrong
# retrieve 790 data, have something wrong
# retrieve 791 data, have something wrong
# retrieve 792 data, have something wrong
# retrieve 793 data, have something wrong
# retrieve 794 data, have something wrong
# retrieve 795 data, have something wrong
# retrieve 796 data, have something wrong
# retrieve 797 data, have something wrong
# retrieve 798 data, have something wrong
# retrieve 799 data, have something wrong
# retrieve 800 data, have something wrong
# retrieve 801 data, have something wrong
# retrieve 802 data, have something wrong
# retrieve 803 data, have something wrong
# retrieve 804 data, have something wrong
# retrieve 805 data, have something wrong
# retrieve 806 data, have something wrong
# retrieve 807 data, have something wrong
# retrieve 808 data, have something wrong
# retrieve 809 data, have something wrong
# retrieve 810 data, have something wrong
# retrieve 811 data, have something wrong
# retrieve 812 data, have something wrong
# retrieve 813 data, have something wrong
# retrieve 814 data, have something wrong
# retrieve 815 data, have something wrong
# retrieve 816 data, have something wrong
# retrieve 817 data, have something wrong
# retrieve 818 data, have something wrong
# retrieve 819 data, have something wrong
# retrieve 820 data, have something wrong
# retrieve 821 data, have something wrong
# retrieve 822 data, have something wrong
# retrieve 823 data, have something wrong
# retrieve 824 data, have something wrong
# retrieve 825 data, have something wrong
# retrieve 826 data, have something wrong
# retrieve 827 data, have something wrong
# retrieve 828 data, have something wrong
# retrieve 829 data, have something wrong
# retrieve 830 data, have something wrong
# retrieve 831 data, have something wrong
# retrieve 832 data, have something wrong
# retrieve 833 data, have something wrong
# retrieve 834 data, have something wrong
# retrieve 835 data, have something wrong
# retrieve 836 data, have something wrong
# retrieve 837 data, have something wrong
# retrieve 838 data, have something wrong
# retrieve 839 data, have something wrong
# retrieve 840 data, have something wrong
# retrieve 841 data, have something wrong
# retrieve 842 data, have something wrong
# retrieve 843 data, have something wrong
# retrieve 844 data, have something wrong
# retrieve 845 data, have something wrong
# retrieve 846 data, have something wrong
# retrieve 847 data, have something wrong
# retrieve 848 data, have something wrong
# retrieve 849 data, have something wrong
# retrieve 850 data, have something wrong
# retrieve 851 data, have something wrong
# retrieve 852 data, have something wrong
# retrieve 853 data, have something wrong
# retrieve 854 data, have something wrong
# retrieve 855 data, have something wrong
# retrieve 856 data, have something wrong
# retrieve 857 data, have something wrong
# retrieve 858 data, have something wrong
# retrieve 859 data, have something wrong
# retrieve 860 data, have something wrong
# retrieve 861 data, have something wrong
# retrieve 862 data, have something wrong
# retrieve 863 data, have something wrong
# retrieve 864 data, have something wrong
# retrieve 865 data, have something wrong
# retrieve 866 data, have something wrong
# retrieve 867 data, have something wrong
# retrieve 868 data, have something wrong
# retrieve 869 data, have something wrong
# retrieve 870 data, have something wrong
# retrieve 871 data, have something wrong
# retrieve 872 data, have something wrong
# retrieve 873 data, have something wrong
# retrieve 874 data, have something wrong
# retrieve 875 data, have something wrong
# retrieve 876 data, have something wrong
# retrieve 877 data, have something wrong
# retrieve 878 data, have something wrong
# retrieve 879 data, have something wrong
# retrieve 880 data, have something wrong
# retrieve 881 data, have something wrong
# retrieve 882 data, have something wrong
# retrieve 883 data, have something wrong
# retrieve 884 data, have something wrong
# retrieve 885 data, have something wrong
# retrieve 886 data, have something wrong
# retrieve 887 data, have something wrong
# retrieve 888 data, have something wrong
# retrieve 889 data, have something wrong
# retrieve 890 data, have something wrong
# retrieve 891 data, have something wrong
# retrieve 892 data, have something wrong
# retrieve 893 data, have something wrong
# retrieve 894 data, have something wrong
# retrieve 895 data, have something wrong
# retrieve 896 data, have something wrong
# retrieve 897 data, have something wrong
# retrieve 898 data, have something wrong
# retrieve 899 data, have something wrong
# retrieve 900 data, have something wrong
# retrieve 901 data, have something wrong
# retrieve 902 data, have something wrong
# retrieve 903 data, have something wrong
# retrieve 904 data, have something wrong
# retrieve 905 data, have something wrong
# retrieve 906 data, have something wrong
# retrieve 907 data, have something wrong
# retrieve 908 data, have something wrong
# retrieve 909 data, have something wrong
# retrieve 910 data, have something wrong
# retrieve 911 data, have something wrong
# retrieve 912 data, have something wrong
# retrieve 913 data, have something wrong
# retrieve 914 data, have something wrong
# retrieve 915 data, have something wrong
# retrieve 916 data, have something wrong
# retrieve 917 data, have something wrong
# retrieve 918 data, have something wrong
# retrieve 919 data, have something wrong
# retrieve 920 data, have something wrong
# retrieve 921 data, have something wrong
# retrieve 922 data, have something wrong
# retrieve 923 data, have something wrong
# retrieve 924 data, have something wrong
#
# retrieve data cost time: 223.50085859299998

# %%
set(df_code.symbol.unique().tolist()) - set(df.index.levels[1].tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0ff001054d51> in <module>()
# ----> 1 set(df_code.symbol.unique().tolist()) - set(df.index.levels[1].tolist())
#
# NameError: name 'df' is not defined

# %%
df.to_csv('data/data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-cf550ab47d00> in <module>()
# ----> 1 df.to_csv('data/data.csv')
#
# NameError: name 'df' is not defined

# %%
from utils import *

# %%
result = calc_pair_trading('SMH', 
                           data_source='ol',
                           method='rolling',
                           period=245, 
                           is_saving=True, 
                           save_name='rsi_sample')
# Out:
#   File "<ipython-input-14-c4bd4d83ca26>", line 3
#     method='rolling',
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 如果上述代码没有问题，可以尝试以下代码

# %% [markdown]
# ### test 2

# %%
tic = time.perf_counter()

df = con.bdh(ticker_list, fields, start, end)

df = pd.concat([df[x].assign(code=x.split(' ')[0]).groupby(level=0, axis=1).first() for x in df.columns.levels[0]], 
          axis=0,sort=False).reset_index().set_index(['date', 'code'])
df.columns = cols

toc = time.perf_counter()

print('retrieve data cost time: %s' % (toc-tic))

# %%
set(df_code.symbol.unique().tolist()) - set(df.index.levels[1].tolist())

# %%
df.to_csv('data/data.csv')

# %%
result = calc_pair_trading('SMH', 
                           data_source='ol'
                           method='rolling', 
                           period=245, 
                           is_saving=True, 
                           save_name='rsi_sample')
