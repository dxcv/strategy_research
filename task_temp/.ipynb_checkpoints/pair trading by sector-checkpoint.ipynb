# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import statsmodels.api as sm
# import tushare as ts
import QUANTAXIS as QA
import talib as ta
import datetime

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %%
us_data = pd.read_csv('data/us_data.csv')
us_data.columns = ['date', 'high', 'low', 'open', 'close', 'volume', 'Adj Close', 'code']
us_data = us_data.set_index(['date', 'code'])
us_data = QA.QA_DataStruct_Stock_day(us_data)
us_data.data.head()
# Out:
#                       high        low       open      close      volume  \
# date       code
# 2009-12-31 A     22.725323  22.124464  22.203148  22.224607   5224600.0
#            AABA  16.959999  16.770000  16.920000  16.780001   9515600.0
#            AAP   41.110001  40.480000  41.110001  40.480000    894500.0
#            AAPL  30.478571  30.080000  30.447144  30.104286  88102700.0
#            AAXN   4.430000   4.320000   4.400000   4.380000    400400.0
#
#                  Adj Close
# date       code
# 2009-12-31 A     20.562288
#            AABA  16.780001
#            AAP   39.562489
#            AAPL  20.159719
#            AAXN   4.380000

# %%
code_list_by_sector = pd.read_excel('data/etf_pair_code.xlsx', dtype={'symbol':str})

# %%
code_list_by_sector.head()
# Out:
#   symbol     region etf_symbol    sector
# 0   MSFT  US Equity        XLK  Hardware
# 1   AAPL  US Equity        XLK  Hardware
# 2      V  US Equity        XLK  Hardware
# 3   INTC  US Equity        XLK  Hardware
# 4   CSCO  US Equity        XLK  Hardware

# %%
sector_list = code_list_by_sector.sector.unique().tolist()
sector_list
# Out:
# ['Hardware',
#  'Internet',
#  'China Internet',
#  'Online Gaming',
#  'Software/ Cloud Computing',
#  'Cloud Computing',
#  'Network/Security',
#  'ePayment',
#  'Semiconductor',
#  'Medical',
#  'Biotech/ Pharma',
#  'Health Care Services',
#  'Defense',
#  'Consumer',
#  'Financials',
#  'Energy',
#  'Others']

# %%
region_list = code_list_by_sector.region.unique().tolist()
region_list
# Out:
# ['US Equity',
#  'HK Equity',
#  'HKD Curncy',
#  'KS Equity',
#  'JP Equity',
#  'FP Equity',
#  'TT Equity',
#  'SS Equity',
#  'GR Equity',
#  'LN Equity',
#  'NO Equity',
#  'FH Equity',
#  'CN Equity',
#  'NA Equity',
#  'ita']

# %%
code_list_by_sector.query('sector=="%s"' %\
                          (sector_list[0]))#.symbol.tolist()
# Out:
#    symbol     region etf_symbol    sector
# 0    MSFT  US Equity        XLK  Hardware
# 1    AAPL  US Equity        XLK  Hardware
# 2       V  US Equity        XLK  Hardware
# 3    INTC  US Equity        XLK  Hardware
# 4    CSCO  US Equity        XLK  Hardware
# 5      MA  US Equity        XLK  Hardware
# 6    ORCL  US Equity        XLK  Hardware
# 7    AVGO  US Equity        XLK  Hardware
# 8    ADBE  US Equity        XLK  Hardware
# 9     IBM  US Equity        XLK  Hardware
# 10   PYPL  US Equity        XLK  Hardware
# 11    CRM  US Equity        XLK  Hardware
# 12    ACN  US Equity        XLK  Hardware
# 13    TXN  US Equity        XLK  Hardware
# 14   NVDA  US Equity        XLK  Hardware
# 15   QCOM  US Equity        XLK  Hardware
# 16    ADP  US Equity        XLK  Hardware
# 17   INTU  US Equity        XLK  Hardware
# 18     MU  US Equity        XLK  Hardware
# 19   CTSH  US Equity        XLK  Hardware
# 20    HPQ  US Equity        XLK  Hardware
# 21    FIS  US Equity        XLK  Hardware
# 22    ADI  US Equity        XLK  Hardware
# 23   AMAT  US Equity        XLK  Hardware
# 24    RHT  US Equity        XLK  Hardware
# 25   FISV  US Equity        XLK  Hardware
# 26   ADSK  US Equity        XLK  Hardware
# 27    TEL  US Equity        XLK  Hardware
# 28    GLW  US Equity        XLK  Hardware
# 29    APH  US Equity        XLK  Hardware
# ..    ...        ...        ...       ...
# 38    GPN  US Equity        XLK  Hardware
# 39    FLT  US Equity        XLK  Hardware
# 40    DXC  US Equity        XLK  Hardware
# 41   NTAP  US Equity        XLK  Hardware
# 42   MXIM  US Equity        XLK  Hardware
# 43   KLAC  US Equity        XLK  Hardware
# 44   CTXS  US Equity        XLK  Hardware
# 45    TSS  US Equity        XLK  Hardware
# 46   SYMC  US Equity        XLK  Hardware
# 47   SNPS  US Equity        XLK  Hardware
# 48   ANSS  US Equity        XLK  Hardware
# 49   SWKS  US Equity        XLK  Hardware
# 50     IT  US Equity        XLK  Hardware
# 51   CDNS  US Equity        XLK  Hardware
# 52   KEYS  US Equity        XLK  Hardware
# 53    WDC  US Equity        XLK  Hardware
# 54     BR  US Equity        XLK  Hardware
# 55   AKAM  US Equity        XLK  Hardware
# 56   ANET  US Equity        XLK  Hardware
# 57   JKHY  US Equity        XLK  Hardware
# 58   FFIV  US Equity        XLK  Hardware
# 59    STX  US Equity        XLK  Hardware
# 60   FTNT  US Equity        XLK  Hardware
# 61   JNPR  US Equity        XLK  Hardware
# 62     WU  US Equity        XLK  Hardware
# 63   QRVO  US Equity        XLK  Hardware
# 64    ADS  US Equity        XLK  Hardware
# 65   FLIR  US Equity        XLK  Hardware
# 66    XRX  US Equity        XLK  Hardware
# 67   IPGP  US Equity        XLK  Hardware
#
# [68 rows x 4 columns]

# %%
code_list_by_sector.query('sector=="%s" & region=="%s"' %\
                          (sector_list[0], 'US Equity'))#.symbol.tolist()
# Out:
#    symbol     region etf_symbol    sector
# 0    MSFT  US Equity        XLK  Hardware
# 1    AAPL  US Equity        XLK  Hardware
# 2       V  US Equity        XLK  Hardware
# 3    INTC  US Equity        XLK  Hardware
# 4    CSCO  US Equity        XLK  Hardware
# 5      MA  US Equity        XLK  Hardware
# 6    ORCL  US Equity        XLK  Hardware
# 7    AVGO  US Equity        XLK  Hardware
# 8    ADBE  US Equity        XLK  Hardware
# 9     IBM  US Equity        XLK  Hardware
# 10   PYPL  US Equity        XLK  Hardware
# 11    CRM  US Equity        XLK  Hardware
# 12    ACN  US Equity        XLK  Hardware
# 13    TXN  US Equity        XLK  Hardware
# 14   NVDA  US Equity        XLK  Hardware
# 15   QCOM  US Equity        XLK  Hardware
# 16    ADP  US Equity        XLK  Hardware
# 17   INTU  US Equity        XLK  Hardware
# 18     MU  US Equity        XLK  Hardware
# 19   CTSH  US Equity        XLK  Hardware
# 20    HPQ  US Equity        XLK  Hardware
# 21    FIS  US Equity        XLK  Hardware
# 22    ADI  US Equity        XLK  Hardware
# 23   AMAT  US Equity        XLK  Hardware
# 24    RHT  US Equity        XLK  Hardware
# 25   FISV  US Equity        XLK  Hardware
# 26   ADSK  US Equity        XLK  Hardware
# 27    TEL  US Equity        XLK  Hardware
# 28    GLW  US Equity        XLK  Hardware
# 29    APH  US Equity        XLK  Hardware
# ..    ...        ...        ...       ...
# 38    GPN  US Equity        XLK  Hardware
# 39    FLT  US Equity        XLK  Hardware
# 40    DXC  US Equity        XLK  Hardware
# 41   NTAP  US Equity        XLK  Hardware
# 42   MXIM  US Equity        XLK  Hardware
# 43   KLAC  US Equity        XLK  Hardware
# 44   CTXS  US Equity        XLK  Hardware
# 45    TSS  US Equity        XLK  Hardware
# 46   SYMC  US Equity        XLK  Hardware
# 47   SNPS  US Equity        XLK  Hardware
# 48   ANSS  US Equity        XLK  Hardware
# 49   SWKS  US Equity        XLK  Hardware
# 50     IT  US Equity        XLK  Hardware
# 51   CDNS  US Equity        XLK  Hardware
# 52   KEYS  US Equity        XLK  Hardware
# 53    WDC  US Equity        XLK  Hardware
# 54     BR  US Equity        XLK  Hardware
# 55   AKAM  US Equity        XLK  Hardware
# 56   ANET  US Equity        XLK  Hardware
# 57   JKHY  US Equity        XLK  Hardware
# 58   FFIV  US Equity        XLK  Hardware
# 59    STX  US Equity        XLK  Hardware
# 60   FTNT  US Equity        XLK  Hardware
# 61   JNPR  US Equity        XLK  Hardware
# 62     WU  US Equity        XLK  Hardware
# 63   QRVO  US Equity        XLK  Hardware
# 64    ADS  US Equity        XLK  Hardware
# 65   FLIR  US Equity        XLK  Hardware
# 66    XRX  US Equity        XLK  Hardware
# 67   IPGP  US Equity        XLK  Hardware
#
# [68 rows x 4 columns]

# %%
def get_code_list_by_sector(code_list_df, sector, region):
    if region = 'all':
        df = code_list_df.('sector=="%s"' % (sector_list[0]))
    
    return

# %%
# Out:
#                       high        low       open      close      volume  \
# date       code
# 2009-12-31 A     22.725323  22.124464  22.203148  22.224607   5224600.0
#            AABA  16.959999  16.770000  16.920000  16.780001   9515600.0
#            AAP   41.110001  40.480000  41.110001  40.480000    894500.0
#            AAPL  30.478571  30.080000  30.447144  30.104286  88102700.0
#            AAXN   4.430000   4.320000   4.400000   4.380000    400400.0
#
#                  Adj Close
# date       code
# 2009-12-31 A     20.562288
#            AABA  16.780001
#            AAP   39.562489
#            AAPL  20.159719
#            AAXN   4.380000
